# %% [markdown]
# # GloVE
#
# Let's work on implementation of GloVE.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Load data

# %%
from nltk.corpus import brown

brown.categories()
corpus = brown.sents(categories="news")
corpus
# Out:
# [['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.'], ['The', 'jury', 'further', 'said', 'in', 'term-end', 'presentments', 'that', 'the', 'City', 'Executive', 'Committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'City', 'of', 'Atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.'], ...]

# %%
#get word sequences and unique words
flatten = lambda l: [item for sublist in l for item in sublist]
vocab = list(set(flatten(corpus)))
vocab
# Out:
# ['chien',
#  "conference's",
#  'Well-wishers',
#  'While',
#  'patrons',
#  'Navigation',
#  'motels',
#  'testing',
#  'petty',
#  '$90',
#  'Given',
#  'Sanger-Harris',
#  'scoreless',
#  'Outside',
#  'Atty.',
#  'spongy',
#  'Are',
#  'negotiations',
#  'Hord',
#  'washed-out',
#  'courtroom',
#  'contrasting',
#  'Gotham',
#  'Charitable',
#  'Antone',
#  'meter',
#  'maker',
#  'SMU',
#  'book-selection',
#  'instructed',
#  'Seidel',
#  'ball-hawking',
#  'fearing',
#  '108',
#  'picking',
#  'U-2',
#  'self-sacrifice',
#  "'52",
#  'alternatives',
#  "isn't",
#  'queen',
#  'area',
#  'Hall',
#  "he'll",
#  'mall',
#  'combination',
#  'Red',
#  'honeymoon',
#  'masterful',
#  'feted',
#  'Librarians',
#  'highway',
#  'Frick',
#  'clocking',
#  'exploring',
#  'Anaconda',
#  'consequences',
#  'hood',
#  'valuation',
#  '375',
#  'staggered',
#  'Shelby',
#  'Shipman',
#  'Italy',
#  'Vegas',
#  'undergone',
#  'enterprisingly',
#  'closing',
#  'colonies',
#  'best',
#  'streak',
#  'terminated',
#  'machine',
#  'Players',
#  'presiding',
#  'walloping',
#  'dwindled',
#  'warless',
#  'obtained',
#  'missed',
#  "Tennessee's",
#  'successes',
#  'Annamorena',
#  'reforms',
#  'shrink',
#  'junior',
#  'breakups',
#  'Beadles',
#  'secretarial',
#  'nor',
#  'label',
#  'vouchers',
#  'Macon',
#  '255',
#  'loaded',
#  'Casey',
#  'Mana',
#  'invoked',
#  'Fonta',
#  'slums',
#  'dynamic',
#  'teen-age',
#  'Laotian',
#  'upturn',
#  'Bundle',
#  'Bimini',
#  'scoop',
#  'specialized',
#  'Class',
#  'Works',
#  'champions',
#  'improving',
#  'Milties',
#  'line',
#  "we've",
#  'budgets',
#  'Auditorium',
#  'granted',
#  'greeting',
#  'react',
#  'casuals',
#  '4,500',
#  'Water',
#  'toy',
#  'sirens',
#  'goal',
#  'across',
#  "Mays'",
#  'someone',
#  'ballots',
#  'firmer',
#  'approximately',
#  'paid-for',
#  'strange',
#  '62-year-old',
#  'Pinsk',
#  'Darrow',
#  'mobile',
#  'filing',
#  'two-family',
#  'team',
#  'orientation',
#  'Lavaughn',
#  'radioactive',
#  'beardown',
#  '10-hour',
#  'stewardesses',
#  'learning',
#  'book',
#  'marriages',
#  'discharging',
#  'Iran',
#  'Inaugural',
#  'Rte.',
#  'Smithfield',
#  'maintaining',
#  'of',
#  'headboard',
#  'contendere',
#  'canvass',
#  'pretenses',
#  'captain',
#  'prevailed',
#  'potatoes',
#  'among',
#  "Meyner's",
#  'maintain',
#  'seize',
#  'Cardinals',
#  'productive',
#  'secrets',
#  'bolted',
#  'Felske',
#  'cleared',
#  'enthralling',
#  'son',
#  'despair',
#  'mushrooms',
#  'alive',
#  'Hit',
#  'exclusively',
#  'Stickney',
#  'secessionist',
#  'Liberals',
#  '22111',
#  'unhappy',
#  'labeled',
#  "you're",
#  'Windsor',
#  'tape',
#  'citation',
#  'rather',
#  '116',
#  'compared',
#  'Wert',
#  'agricultural',
#  'fertilizer',
#  '675',
#  'lieutenants',
#  'enact',
#  'Adjusted',
#  'Insuring',
#  'Fortin',
#  'motion',
#  'alike',
#  'mine',
#  'cloture',
#  'certain',
#  'Kader',
#  'care',
#  'collaborators',
#  'Composite',
#  'recently',
#  'moment',
#  'racial',
#  "farmers'",
#  'policy',
#  'baseballight',
#  'SEATO',
#  'great',
#  '300-450',
#  '100,000',
#  'survival',
#  'fighting',
#  'Toronto',
#  'blow',
#  'called',
#  "Purdue's",
#  're-arguing',
#  'Publishing',
#  'annual',
#  'sort',
#  'various',
#  '64',
#  'tentative',
#  'contaminating',
#  'Long',
#  'members',
#  'propaganda',
#  'Thus',
#  'language',
#  'split',
#  'Vietnam',
#  'high-ceilinged',
#  'registration',
#  'front',
#  'Eastern',
#  'emphasis',
#  'varied',
#  'segregationist',
#  'model',
#  'Winston',
#  'Volume',
#  'Curry',
#  "Denver's",
#  "fall's",
#  'fell',
#  '$77,389,000',
#  'so-called',
#  'See-through',
#  'Joey',
#  'King',
#  'a',
#  'cool',
#  'eight-year',
#  '354',
#  'cellist',
#  'Spangled',
#  'singers',
#  'precisely',
#  'clears',
#  'Master',
#  'spun',
#  'Bake',
#  '1948',
#  'knees',
#  'wheat',
#  'Mayor',
#  'banked',
#  'The',
#  'Governor',
#  'hijackers',
#  'frock',
#  "tonight's",
#  'high-density',
#  'guiding',
#  'hour',
#  'pleaded',
#  'glanced',
#  'beat',
#  'volume',
#  'Revolutionary',
#  'extent',
#  'clinic',
#  'imports',
#  '186',
#  'Calvary',
#  'idealism',
#  'population',
#  'Baird',
#  'default',
#  'bombing',
#  'Felix',
#  'Av.',
#  'diversified',
#  '68',
#  'Another',
#  'strength',
#  'Dublin',
#  'Trouble-free',
#  '10%',
#  'controllers',
#  'aids',
#  'Salary',
#  'Gin',
#  'expire',
#  ',',
#  'Warren',
#  'studies',
#  'drifting',
#  'procedures',
#  'gambling',
#  'outlawed',
#  'Taking',
#  'house',
#  'Baldrige',
#  'twelfth',
#  'minorities',
#  '1914',
#  'grounds',
#  'Forest',
#  'subbing',
#  'analysis',
#  'such',
#  'movie',
#  'Naturally',
#  'window',
#  'two-season',
#  '3505o',
#  'charging',
#  'design-conscious',
#  'Aug.',
#  'spends',
#  'collecting',
#  'add',
#  'authorities',
#  'La.',
#  'Hood',
#  'measure',
#  'economist',
#  'Frederick',
#  'thwarted',
#  'prizes',
#  'Valedictorian',
#  'biz',
#  'ruled',
#  'loyalty',
#  'communism',
#  'Jay',
#  'Baringer',
#  'Beesemyers',
#  'customs',
#  'Ramsey',
#  'flowers',
#  'storm',
#  'Mays',
#  'Aiken',
#  'briskly',
#  'paces',
#  'Trail',
#  'corn',
#  'Guests',
#  'Sharon',
#  'apartments',
#  'wants',
#  'Guinea',
#  'Beneficiary',
#  'Sydney',
#  'gather',
#  'downstairs',
#  'named',
#  'bet',
#  'Charge',
#  'Sarmi',
#  'one-fourth',
#  'filly',
#  'overtake',
#  "nation's",
#  'achieved',
#  'theaters',
#  'shares',
#  'teach',
#  'Cotton',
#  'doubles',
#  'Hartselle',
#  'Generally',
#  'thriving',
#  'Dillon',
#  'wear',
#  '$278,877,000',
#  'Monroe',
#  'deeply',
#  'inhabitants',
#  'plenary',
#  'misses',
#  'three-way',
#  'Lowe',
#  'engines',
#  'breaching',
#  'conducts',
#  'turned',
#  'ambled',
#  'belongs',
#  'shoulder',
#  'caskets',
#  'roaring',
#  'Nieman',
#  'argued',
#  'Hengesbach',
#  'dichotomy',
#  'judging',
#  '25-footer',
#  'bum',
#  '361',
#  'walloped',
#  'Hack',
#  'Trooper',
#  'Dukes',
#  'bill',
#  'Lamar',
#  'chafing',
#  'Stepson',
#  'keyboarding',
#  'effected',
#  'enunciate',
#  'puts',
#  'Farrell',
#  '704',
#  'stomachs',
#  "Owl's",
#  'specializing',
#  'lay',
#  'Bears',
#  'rulers',
#  'honored',
#  'believing',
#  'documents',
#  '40%',
#  'also',
#  'dimension',
#  'Company',
#  'hours',
#  'become',
#  'continuous',
#  'player',
#  '$17',
#  'Frank',
#  'orders',
#  'chocolate',
#  'reprimanded',
#  '44-year-old',
#  'Caucusing',
#  'inviolate',
#  'Idea',
#  'Actor-Crooner',
#  'October',
#  'Romans',
#  'Lounge',
#  'motivated',
#  'administered',
#  '1913',
#  'toward',
#  "people's",
#  'entered',
#  'Quell',
#  '52-year',
#  'Caroline',
#  'Skylark',
#  'surrender',
#  'simultaneous',
#  'diminutive',
#  'alleged',
#  'dissent',
#  'airlines',
#  'June',
#  'Times-Picayune',
#  'laying',
#  'stew',
#  'Woodyard',
#  'Voters',
#  'Eugene',
#  'Dunbar',
#  'distance',
#  'tests',
#  'laborers',
#  '7034',
#  'foot',
#  'wonderful',
#  'go',
#  'carcass',
#  '3.98',
#  'Bales',
#  'major-league',
#  'lag',
#  'lettermen',
#  'persistent',
#  'Kenilworth',
#  'comprised',
#  'chests',
#  'statutory',
#  'Siciliana',
#  'Rhine-Westphalia',
#  'applying',
#  'national',
#  'included',
#  'clue',
#  'golfer',
#  'Athletics',
#  'applaud',
#  'Solicitor',
#  '169',
#  'bedtime',
#  "League's",
#  '205-pound',
#  'enacting',
#  'de',
#  'Pinar',
#  'Fazio',
#  'liberal-conservative',
#  'detonation',
#  'employed',
#  'cocktail',
#  '3:30',
#  'secure',
#  'headmaster',
#  'well-prepared',
#  'compensations',
#  'masterpiece',
#  'blunt',
#  'nominal',
#  'learned',
#  'grows',
#  'tin',
#  'Unit',
#  'span',
#  'occupants',
#  'pretext',
#  'logical',
#  'played',
#  'Me',
#  'Weeks',
#  'Jurisdiction',
#  'gas',
#  'pictured',
#  '50%',
#  '1917',
#  'Beauty',
#  'Carreon',
#  'attainment',
#  'guidance',
#  'edging',
#  'participation',
#  '1',
#  'interested',
#  'Ceil',
#  'valve',
#  'famed',
#  'fiercest',
#  'anymore',
#  'dessert',
#  'owners',
#  '6934',
#  'Neal',
#  'When',
#  'prod',
#  'Andrew',
#  'Sixty-seven',
#  'Guest',
#  'register',
#  'trusted',
#  'concerns',
#  'mined',
#  'ensconced',
#  'stuck',
#  'principal',
#  'extern',
#  'things',
#  '$22',
#  '$7,082',
#  'jury-tampering',
#  'Nancy',
#  'totaling',
#  'commuting',
#  'Williams',
#  'prosecute',
#  '$450',
#  'Neusteters',
#  'waiting',
#  'smuggling',
#  'unique',
#  'Highway',
#  'worse',
#  'formal',
#  'textile-importing',
#  'inadequate',
#  'workshop',
#  'capital',
#  'Leadership',
#  'chef',
#  'hasty',
#  'chrome',
#  'Elios',
#  'Rozelle',
#  'titian-haired',
#  'world-wide',
#  'road',
#  'holdings',
#  'status',
#  'heat',
#  'rival',
#  'collective-bargaining',
#  "Veeck's",
#  'nomination',
#  'fly',
#  'SW',
#  'widely',
#  'triumphs',
#  'hands',
#  'ties',
#  'stewardess',
#  'Ken',
#  'teeth',
#  'Galt',
#  '65',
#  '6-7',
#  'miss',
#  'Net',
#  'more-than-ordinary',
#  'Hose',
#  "members'",
#  'Command',
#  'Hoyt',
#  'again',
#  'flex',
#  'Gentile',
#  'issued',
#  'preferably',
#  'policemen',
#  'Jury',
#  'satisfaction',
#  'Christ',
#  'listen',
#  '14.2',
#  'waged',
#  'Central',
#  'twice-a-year',
#  'replace',
#  'Designs',
#  'Loeb',
#  'one-week-old',
#  'network',
#  'School',
#  'victims',
#  "Ginner's",
#  'swine',
#  'hearing',
#  'yards',
#  "else's",
#  'judged',
#  '38-7',
#  'Shop',
#  'breathes',
#  'steel',
#  'intern',
#  'stronger',
#  'feeds',
#  'select',
#  'worn',
#  'Marskmen',
#  'Big',
#  'bodily',
#  'Area',
#  'advance',
#  'Nehf',
#  'Newtown',
#  '25,000,000',
#  'question',
#  'Niven',
#  '260-member',
#  'officiated',
#  'assembly',
#  'monks',
#  'banquet',
#  'copper',
#  'mammoth',
#  'Outstanding',
#  'Ultimately',
#  'upshots',
#  'indorsed',
#  'contained',
#  'obligation',
#  'counting',
#  'motel-keepers',
#  'typical',
#  'lasted',
#  'whom',
#  'episodes',
#  'he',
#  'Tsitouris',
#  'taxes',
#  '$581,000',
#  '$28',
#  "Mantle's",
#  '$102,285,000',
#  'fast',
#  'clerical-lay',
#  'Western',
#  'Finance',
#  'lots',
#  'create',
#  'scholastically',
#  'Campagnoli',
#  'streetcar',
#  'yard',
#  'months',
#  'anti-Kennedy',
#  'Greene',
#  'bonding',
#  'five-cent',
#  'answered',
#  'acclimatized',
#  'dividend',
#  'Chapelles',
#  'Cash',
#  'whole',
#  'unearned',
#  'valued',
#  'Lorenz',
#  'Welborn',
#  'Danger',
#  'Gretchen',
#  'carries',
#  'Kiwanis',
#  'Charles',
#  "Party's",
#  'sponsors',
#  'Cudmore',
#  'Otis',
#  'though',
#  'reminiscence',
#  'precarious',
#  'stripped',
#  'Seven',
#  'State',
#  'plaintiffs',
#  'Seats',
#  'Cherry',
#  'Johnston',
#  'prior',
#  'ex-marine',
#  'on-the-scene',
#  'Using',
#  'drifts',
#  'reservoir',
#  'lose',
#  'provincial',
#  'Hargett',
#  'Sheraton-Biltmore',
#  '12th',
#  'Coconut',
#  'unspecified',
#  'obliged',
#  'informally',
#  'desperate',
#  'Person',
#  'hosts',
#  'existed',
#  'below',
#  'provisional',
#  'reservations',
#  'hammered',
#  'ayes',
#  'wedge',
#  '160',
#  'junior-senior',
#  'sporadic',
#  '2731',
#  'retarded',
#  'Golden',
#  'Vicky',
#  'means',
#  'Guam',
#  'outdoors',
#  'Aiding',
#  'peculiarities',
#  'executives',
#  'Circle',
#  '7-9',
#  'occupied',
#  '543',
#  '3,000',
#  '$46.7',
#  'specific',
#  'provoked',
#  "fund's",
#  'verdict',
#  'Ave.',
#  'walked',
#  'contingent',
#  'Second',
#  'Medical',
#  'scrutiny',
#  'adapting',
#  'manifestly',
#  'signals',
#  'Haddix',
#  'whiplash',
#  'Basel',
#  'marching',
#  'took',
#  'Leading',
#  'refuted',
#  'discrimination',
#  'repository',
#  'relinquish',
#  'Deane',
#  'Philadelphia',
#  'boundaries',
#  'lighters',
#  "Lanin's",
#  'corner',
#  'mad',
#  'competitor',
#  '$1.4',
#  'Boston',
#  'debuts',
#  'Hampton',
#  'issuance',
#  'Watson',
#  'Sheets',
#  'signing',
#  'rioting',
#  'burglarproof',
#  'privileges',
#  '1600',
#  'Brook',
#  'Kedzie',
#  'Horton',
#  'expended',
#  'tones',
#  'areas',
#  'chairs',
#  'prosecutors',
#  'unmistakably',
#  'franchise',
#  'ants',
#  'roommate',
#  'through',
#  'Tipoff',
#  'Navy',
#  'easy',
#  'Francis',
#  'infest',
#  "Beadles'",
#  'Zeising',
#  'Carlo',
#  'off-duty',
#  'silver',
#  'constituents',
#  'ends',
#  'false',
#  'batted',
#  'seat',
#  'Yogi',
#  'Opposition',
#  'Americans',
#  'owned',
#  'Stratton',
#  'skyjackers',
#  'Liberal',
#  'overlooked',
#  'churches',
#  'Sharkey',
#  'unofficial',
#  'dental',
#  'hand-crafted',
#  'monthly',
#  'bankers',
#  'Wilderness',
#  'contribution',
#  'doldrums',
#  'shaped',
#  'self-plagiarisms',
#  'Chancellor',
#  'imagine',
#  'negotiate',
#  'subtitled',
#  'skills',
#  'celebrates',
#  'Newcomers',
#  'preaching',
#  'mechanics',
#  'pursued',
#  'calendar',
#  'producer-hubby',
#  'one-over-par',
#  'JA',
#  'reached',
#  'amend',
#  'calls',
#  '32,589',
#  'dive',
#  'Richey',
#  'scenic',
#  'Shiflett',
#  'hijacked',
#  'century',
#  "Jenkins's",
#  'drums',
#  'grain',
#  "Simmons'",
#  'Drs.',
#  'gotten',
#  'benefits',
#  'Sunay',
#  'prospects',
#  'Nationalist',
#  'Sherwood',
#  'envision',
#  'cracked',
#  'Flushing',
#  'defray',
#  '46',
#  'meantime',
#  'mink',
#  'lend',
#  'Jefferson',
#  'improperly',
#  'blood',
#  'Grzesiak',
#  'merchandise',
#  'dread',
#  '$70',
#  'absorbed',
#  'Petitions',
#  'Burkes',
#  'royal',
#  'Foxx',
#  'Brandeis',
#  'Karns',
#  'labor',
#  'Cody',
#  'Nov.',
#  'Centredale',
#  'appraisal',
#  'delay',
#  'cross-examination',
#  'borrowing',
#  'figure',
#  'Pratt',
#  'statistical',
#  'oil',
#  'Angeles',
#  'Add',
#  'tiles',
#  'alarmingly',
#  'contributing',
#  'raises',
#  'Presently',
#  'enter',
#  'violation',
#  'recommendation',
#  'trying',
#  'Concern',
#  'Briar',
#  'get',
#  '$2,700',
#  '1500',
#  'Buddy',
#  'withdraw',
#  'exhibition',
#  'golden',
#  'in',
#  'honest',
#  'obligated',
#  'Universal-International',
#  'Motel',
#  'spices',
#  'manufacturer',
#  'previously',
#  'pre-set',
#  'unexpected',
#  'confrontations',
#  'sake',
#  'five-month',
#  'Westinghouse',
#  'Conflict',
#  'Division',
#  'fame',
#  'Joyce',
#  ...]

# %%
#numericalization
word2index = {w: i for i, w in enumerate(vocab)}
print(word2index)
# Out:
# {'chien': 0, "conference's": 1, 'Well-wishers': 2, 'While': 3, 'patrons': 4, 'Navigation': 5, 'motels': 6, 'testing': 7, 'petty': 8, '$90': 9, 'Given': 10, 'Sanger-Harris': 11, 'scoreless': 12, 'Outside': 13, 'Atty.': 14, 'spongy': 15, 'Are': 16, 'negotiations': 17, 'Hord': 18, 'washed-out': 19, 'courtroom': 20, 'contrasting': 21, 'Gotham': 22, 'Charitable': 23, 'Antone': 24, 'meter': 25, 'maker': 26, 'SMU': 27, 'book-selection': 28, 'instructed': 29, 'Seidel': 30, 'ball-hawking': 31, 'fearing': 32, '108': 33, 'picking': 34, 'U-2': 35, 'self-sacrifice': 36, "'52": 37, 'alternatives': 38, "isn't": 39, 'queen': 40, 'area': 41, 'Hall': 42, "he'll": 43, 'mall': 44, 'combination': 45, 'Red': 46, 'honeymoon': 47, 'masterful': 48, 'feted': 49, 'Librarians': 50, 'highway': 51, 'Frick': 52, 'clocking': 53, 'exploring': 54, 'Anaconda': 55, 'consequences': 56, 'hood': 57, 'valuation': 58, '375': 59, 'staggered': 60, 'Shelby': 61, 'Shipman': 62, 'Italy': 63, 'Vegas': 64, 'undergone': 65, 'enterprisingly': 66, 'closing': 67, 'colonies': 68, 'best': 69, 'streak': 70, 'terminated': 71, 'machine': 72, 'Players': 73, 'presiding': 74, 'walloping': 75, 'dwindled': 76, 'warless': 77, 'obtained': 78, 'missed': 79, "Tennessee's": 80, 'successes': 81, 'Annamorena': 82, 'reforms': 83, 'shrink': 84, 'junior': 85, 'breakups': 86, 'Beadles': 87, 'secretarial': 88, 'nor': 89, 'label': 90, 'vouchers': 91, 'Macon': 92, '255': 93, 'loaded': 94, 'Casey': 95, 'Mana': 96, 'invoked': 97, 'Fonta': 98, 'slums': 99, 'dynamic': 100, 'teen-age': 101, 'Laotian': 102, 'upturn': 103, 'Bundle': 104, 'Bimini': 105, 'scoop': 106, 'specialized': 107, 'Class': 108, 'Works': 109, 'champions': 110, 'improving': 111, 'Milties': 112, 'line': 113, "we've": 114, 'budgets': 115, 'Auditorium': 116, 'granted': 117, 'greeting': 118, 'react': 119, 'casuals': 120, '4,500': 121, 'Water': 122, 'toy': 123, 'sirens': 124, 'goal': 125, 'across': 126, "Mays'": 127, 'someone': 128, 'ballots': 129, 'firmer': 130, 'approximately': 131, 'paid-for': 132, 'strange': 133, '62-year-old': 134, 'Pinsk': 135, 'Darrow': 136, 'mobile': 137, 'filing': 138, 'two-family': 139, 'team': 140, 'orientation': 141, 'Lavaughn': 142, 'radioactive': 143, 'beardown': 144, '10-hour': 145, 'stewardesses': 146, 'learning': 147, 'book': 148, 'marriages': 149, 'discharging': 150, 'Iran': 151, 'Inaugural': 152, 'Rte.': 153, 'Smithfield': 154, 'maintaining': 155, 'of': 156, 'headboard': 157, 'contendere': 158, 'canvass': 159, 'pretenses': 160, 'captain': 161, 'prevailed': 162, 'potatoes': 163, 'among': 164, "Meyner's": 165, 'maintain': 166, 'seize': 167, 'Cardinals': 168, 'productive': 169, 'secrets': 170, 'bolted': 171, 'Felske': 172, 'cleared': 173, 'enthralling': 174, 'son': 175, 'despair': 176, 'mushrooms': 177, 'alive': 178, 'Hit': 179, 'exclusively': 180, 'Stickney': 181, 'secessionist': 182, 'Liberals': 183, '22111': 184, 'unhappy': 185, 'labeled': 186, "you're": 187, 'Windsor': 188, 'tape': 189, 'citation': 190, 'rather': 191, '116': 192, 'compared': 193, 'Wert': 194, 'agricultural': 195, 'fertilizer': 196, '675': 197, 'lieutenants': 198, 'enact': 199, 'Adjusted': 200, 'Insuring': 201, 'Fortin': 202, 'motion': 203, 'alike': 204, 'mine': 205, 'cloture': 206, 'certain': 207, 'Kader': 208, 'care': 209, 'collaborators': 210, 'Composite': 211, 'recently': 212, 'moment': 213, 'racial': 214, "farmers'": 215, 'policy': 216, 'baseballight': 217, 'SEATO': 218, 'great': 219, '300-450': 220, '100,000': 221, 'survival': 222, 'fighting': 223, 'Toronto': 224, 'blow': 225, 'called': 226, "Purdue's": 227, 're-arguing': 228, 'Publishing': 229, 'annual': 230, 'sort': 231, 'various': 232, '64': 233, 'tentative': 234, 'contaminating': 235, 'Long': 236, 'members': 237, 'propaganda': 238, 'Thus': 239, 'language': 240, 'split': 241, 'Vietnam': 242, 'high-ceilinged': 243, 'registration': 244, 'front': 245, 'Eastern': 246, 'emphasis': 247, 'varied': 248, 'segregationist': 249, 'model': 250, 'Winston': 251, 'Volume': 252, 'Curry': 253, "Denve ...

# %%
#vocab size
voc_size = len(vocab)
print(voc_size)
# Out:
# 14394

# %%
#append UNK
vocab.append('<UNK>')

# %%
vocab
# Out:
# ['chien',
#  "conference's",
#  'Well-wishers',
#  'While',
#  'patrons',
#  'Navigation',
#  'motels',
#  'testing',
#  'petty',
#  '$90',
#  'Given',
#  'Sanger-Harris',
#  'scoreless',
#  'Outside',
#  'Atty.',
#  'spongy',
#  'Are',
#  'negotiations',
#  'Hord',
#  'washed-out',
#  'courtroom',
#  'contrasting',
#  'Gotham',
#  'Charitable',
#  'Antone',
#  'meter',
#  'maker',
#  'SMU',
#  'book-selection',
#  'instructed',
#  'Seidel',
#  'ball-hawking',
#  'fearing',
#  '108',
#  'picking',
#  'U-2',
#  'self-sacrifice',
#  "'52",
#  'alternatives',
#  "isn't",
#  'queen',
#  'area',
#  'Hall',
#  "he'll",
#  'mall',
#  'combination',
#  'Red',
#  'honeymoon',
#  'masterful',
#  'feted',
#  'Librarians',
#  'highway',
#  'Frick',
#  'clocking',
#  'exploring',
#  'Anaconda',
#  'consequences',
#  'hood',
#  'valuation',
#  '375',
#  'staggered',
#  'Shelby',
#  'Shipman',
#  'Italy',
#  'Vegas',
#  'undergone',
#  'enterprisingly',
#  'closing',
#  'colonies',
#  'best',
#  'streak',
#  'terminated',
#  'machine',
#  'Players',
#  'presiding',
#  'walloping',
#  'dwindled',
#  'warless',
#  'obtained',
#  'missed',
#  "Tennessee's",
#  'successes',
#  'Annamorena',
#  'reforms',
#  'shrink',
#  'junior',
#  'breakups',
#  'Beadles',
#  'secretarial',
#  'nor',
#  'label',
#  'vouchers',
#  'Macon',
#  '255',
#  'loaded',
#  'Casey',
#  'Mana',
#  'invoked',
#  'Fonta',
#  'slums',
#  'dynamic',
#  'teen-age',
#  'Laotian',
#  'upturn',
#  'Bundle',
#  'Bimini',
#  'scoop',
#  'specialized',
#  'Class',
#  'Works',
#  'champions',
#  'improving',
#  'Milties',
#  'line',
#  "we've",
#  'budgets',
#  'Auditorium',
#  'granted',
#  'greeting',
#  'react',
#  'casuals',
#  '4,500',
#  'Water',
#  'toy',
#  'sirens',
#  'goal',
#  'across',
#  "Mays'",
#  'someone',
#  'ballots',
#  'firmer',
#  'approximately',
#  'paid-for',
#  'strange',
#  '62-year-old',
#  'Pinsk',
#  'Darrow',
#  'mobile',
#  'filing',
#  'two-family',
#  'team',
#  'orientation',
#  'Lavaughn',
#  'radioactive',
#  'beardown',
#  '10-hour',
#  'stewardesses',
#  'learning',
#  'book',
#  'marriages',
#  'discharging',
#  'Iran',
#  'Inaugural',
#  'Rte.',
#  'Smithfield',
#  'maintaining',
#  'of',
#  'headboard',
#  'contendere',
#  'canvass',
#  'pretenses',
#  'captain',
#  'prevailed',
#  'potatoes',
#  'among',
#  "Meyner's",
#  'maintain',
#  'seize',
#  'Cardinals',
#  'productive',
#  'secrets',
#  'bolted',
#  'Felske',
#  'cleared',
#  'enthralling',
#  'son',
#  'despair',
#  'mushrooms',
#  'alive',
#  'Hit',
#  'exclusively',
#  'Stickney',
#  'secessionist',
#  'Liberals',
#  '22111',
#  'unhappy',
#  'labeled',
#  "you're",
#  'Windsor',
#  'tape',
#  'citation',
#  'rather',
#  '116',
#  'compared',
#  'Wert',
#  'agricultural',
#  'fertilizer',
#  '675',
#  'lieutenants',
#  'enact',
#  'Adjusted',
#  'Insuring',
#  'Fortin',
#  'motion',
#  'alike',
#  'mine',
#  'cloture',
#  'certain',
#  'Kader',
#  'care',
#  'collaborators',
#  'Composite',
#  'recently',
#  'moment',
#  'racial',
#  "farmers'",
#  'policy',
#  'baseballight',
#  'SEATO',
#  'great',
#  '300-450',
#  '100,000',
#  'survival',
#  'fighting',
#  'Toronto',
#  'blow',
#  'called',
#  "Purdue's",
#  're-arguing',
#  'Publishing',
#  'annual',
#  'sort',
#  'various',
#  '64',
#  'tentative',
#  'contaminating',
#  'Long',
#  'members',
#  'propaganda',
#  'Thus',
#  'language',
#  'split',
#  'Vietnam',
#  'high-ceilinged',
#  'registration',
#  'front',
#  'Eastern',
#  'emphasis',
#  'varied',
#  'segregationist',
#  'model',
#  'Winston',
#  'Volume',
#  'Curry',
#  "Denver's",
#  "fall's",
#  'fell',
#  '$77,389,000',
#  'so-called',
#  'See-through',
#  'Joey',
#  'King',
#  'a',
#  'cool',
#  'eight-year',
#  '354',
#  'cellist',
#  'Spangled',
#  'singers',
#  'precisely',
#  'clears',
#  'Master',
#  'spun',
#  'Bake',
#  '1948',
#  'knees',
#  'wheat',
#  'Mayor',
#  'banked',
#  'The',
#  'Governor',
#  'hijackers',
#  'frock',
#  "tonight's",
#  'high-density',
#  'guiding',
#  'hour',
#  'pleaded',
#  'glanced',
#  'beat',
#  'volume',
#  'Revolutionary',
#  'extent',
#  'clinic',
#  'imports',
#  '186',
#  'Calvary',
#  'idealism',
#  'population',
#  'Baird',
#  'default',
#  'bombing',
#  'Felix',
#  'Av.',
#  'diversified',
#  '68',
#  'Another',
#  'strength',
#  'Dublin',
#  'Trouble-free',
#  '10%',
#  'controllers',
#  'aids',
#  'Salary',
#  'Gin',
#  'expire',
#  ',',
#  'Warren',
#  'studies',
#  'drifting',
#  'procedures',
#  'gambling',
#  'outlawed',
#  'Taking',
#  'house',
#  'Baldrige',
#  'twelfth',
#  'minorities',
#  '1914',
#  'grounds',
#  'Forest',
#  'subbing',
#  'analysis',
#  'such',
#  'movie',
#  'Naturally',
#  'window',
#  'two-season',
#  '3505o',
#  'charging',
#  'design-conscious',
#  'Aug.',
#  'spends',
#  'collecting',
#  'add',
#  'authorities',
#  'La.',
#  'Hood',
#  'measure',
#  'economist',
#  'Frederick',
#  'thwarted',
#  'prizes',
#  'Valedictorian',
#  'biz',
#  'ruled',
#  'loyalty',
#  'communism',
#  'Jay',
#  'Baringer',
#  'Beesemyers',
#  'customs',
#  'Ramsey',
#  'flowers',
#  'storm',
#  'Mays',
#  'Aiken',
#  'briskly',
#  'paces',
#  'Trail',
#  'corn',
#  'Guests',
#  'Sharon',
#  'apartments',
#  'wants',
#  'Guinea',
#  'Beneficiary',
#  'Sydney',
#  'gather',
#  'downstairs',
#  'named',
#  'bet',
#  'Charge',
#  'Sarmi',
#  'one-fourth',
#  'filly',
#  'overtake',
#  "nation's",
#  'achieved',
#  'theaters',
#  'shares',
#  'teach',
#  'Cotton',
#  'doubles',
#  'Hartselle',
#  'Generally',
#  'thriving',
#  'Dillon',
#  'wear',
#  '$278,877,000',
#  'Monroe',
#  'deeply',
#  'inhabitants',
#  'plenary',
#  'misses',
#  'three-way',
#  'Lowe',
#  'engines',
#  'breaching',
#  'conducts',
#  'turned',
#  'ambled',
#  'belongs',
#  'shoulder',
#  'caskets',
#  'roaring',
#  'Nieman',
#  'argued',
#  'Hengesbach',
#  'dichotomy',
#  'judging',
#  '25-footer',
#  'bum',
#  '361',
#  'walloped',
#  'Hack',
#  'Trooper',
#  'Dukes',
#  'bill',
#  'Lamar',
#  'chafing',
#  'Stepson',
#  'keyboarding',
#  'effected',
#  'enunciate',
#  'puts',
#  'Farrell',
#  '704',
#  'stomachs',
#  "Owl's",
#  'specializing',
#  'lay',
#  'Bears',
#  'rulers',
#  'honored',
#  'believing',
#  'documents',
#  '40%',
#  'also',
#  'dimension',
#  'Company',
#  'hours',
#  'become',
#  'continuous',
#  'player',
#  '$17',
#  'Frank',
#  'orders',
#  'chocolate',
#  'reprimanded',
#  '44-year-old',
#  'Caucusing',
#  'inviolate',
#  'Idea',
#  'Actor-Crooner',
#  'October',
#  'Romans',
#  'Lounge',
#  'motivated',
#  'administered',
#  '1913',
#  'toward',
#  "people's",
#  'entered',
#  'Quell',
#  '52-year',
#  'Caroline',
#  'Skylark',
#  'surrender',
#  'simultaneous',
#  'diminutive',
#  'alleged',
#  'dissent',
#  'airlines',
#  'June',
#  'Times-Picayune',
#  'laying',
#  'stew',
#  'Woodyard',
#  'Voters',
#  'Eugene',
#  'Dunbar',
#  'distance',
#  'tests',
#  'laborers',
#  '7034',
#  'foot',
#  'wonderful',
#  'go',
#  'carcass',
#  '3.98',
#  'Bales',
#  'major-league',
#  'lag',
#  'lettermen',
#  'persistent',
#  'Kenilworth',
#  'comprised',
#  'chests',
#  'statutory',
#  'Siciliana',
#  'Rhine-Westphalia',
#  'applying',
#  'national',
#  'included',
#  'clue',
#  'golfer',
#  'Athletics',
#  'applaud',
#  'Solicitor',
#  '169',
#  'bedtime',
#  "League's",
#  '205-pound',
#  'enacting',
#  'de',
#  'Pinar',
#  'Fazio',
#  'liberal-conservative',
#  'detonation',
#  'employed',
#  'cocktail',
#  '3:30',
#  'secure',
#  'headmaster',
#  'well-prepared',
#  'compensations',
#  'masterpiece',
#  'blunt',
#  'nominal',
#  'learned',
#  'grows',
#  'tin',
#  'Unit',
#  'span',
#  'occupants',
#  'pretext',
#  'logical',
#  'played',
#  'Me',
#  'Weeks',
#  'Jurisdiction',
#  'gas',
#  'pictured',
#  '50%',
#  '1917',
#  'Beauty',
#  'Carreon',
#  'attainment',
#  'guidance',
#  'edging',
#  'participation',
#  '1',
#  'interested',
#  'Ceil',
#  'valve',
#  'famed',
#  'fiercest',
#  'anymore',
#  'dessert',
#  'owners',
#  '6934',
#  'Neal',
#  'When',
#  'prod',
#  'Andrew',
#  'Sixty-seven',
#  'Guest',
#  'register',
#  'trusted',
#  'concerns',
#  'mined',
#  'ensconced',
#  'stuck',
#  'principal',
#  'extern',
#  'things',
#  '$22',
#  '$7,082',
#  'jury-tampering',
#  'Nancy',
#  'totaling',
#  'commuting',
#  'Williams',
#  'prosecute',
#  '$450',
#  'Neusteters',
#  'waiting',
#  'smuggling',
#  'unique',
#  'Highway',
#  'worse',
#  'formal',
#  'textile-importing',
#  'inadequate',
#  'workshop',
#  'capital',
#  'Leadership',
#  'chef',
#  'hasty',
#  'chrome',
#  'Elios',
#  'Rozelle',
#  'titian-haired',
#  'world-wide',
#  'road',
#  'holdings',
#  'status',
#  'heat',
#  'rival',
#  'collective-bargaining',
#  "Veeck's",
#  'nomination',
#  'fly',
#  'SW',
#  'widely',
#  'triumphs',
#  'hands',
#  'ties',
#  'stewardess',
#  'Ken',
#  'teeth',
#  'Galt',
#  '65',
#  '6-7',
#  'miss',
#  'Net',
#  'more-than-ordinary',
#  'Hose',
#  "members'",
#  'Command',
#  'Hoyt',
#  'again',
#  'flex',
#  'Gentile',
#  'issued',
#  'preferably',
#  'policemen',
#  'Jury',
#  'satisfaction',
#  'Christ',
#  'listen',
#  '14.2',
#  'waged',
#  'Central',
#  'twice-a-year',
#  'replace',
#  'Designs',
#  'Loeb',
#  'one-week-old',
#  'network',
#  'School',
#  'victims',
#  "Ginner's",
#  'swine',
#  'hearing',
#  'yards',
#  "else's",
#  'judged',
#  '38-7',
#  'Shop',
#  'breathes',
#  'steel',
#  'intern',
#  'stronger',
#  'feeds',
#  'select',
#  'worn',
#  'Marskmen',
#  'Big',
#  'bodily',
#  'Area',
#  'advance',
#  'Nehf',
#  'Newtown',
#  '25,000,000',
#  'question',
#  'Niven',
#  '260-member',
#  'officiated',
#  'assembly',
#  'monks',
#  'banquet',
#  'copper',
#  'mammoth',
#  'Outstanding',
#  'Ultimately',
#  'upshots',
#  'indorsed',
#  'contained',
#  'obligation',
#  'counting',
#  'motel-keepers',
#  'typical',
#  'lasted',
#  'whom',
#  'episodes',
#  'he',
#  'Tsitouris',
#  'taxes',
#  '$581,000',
#  '$28',
#  "Mantle's",
#  '$102,285,000',
#  'fast',
#  'clerical-lay',
#  'Western',
#  'Finance',
#  'lots',
#  'create',
#  'scholastically',
#  'Campagnoli',
#  'streetcar',
#  'yard',
#  'months',
#  'anti-Kennedy',
#  'Greene',
#  'bonding',
#  'five-cent',
#  'answered',
#  'acclimatized',
#  'dividend',
#  'Chapelles',
#  'Cash',
#  'whole',
#  'unearned',
#  'valued',
#  'Lorenz',
#  'Welborn',
#  'Danger',
#  'Gretchen',
#  'carries',
#  'Kiwanis',
#  'Charles',
#  "Party's",
#  'sponsors',
#  'Cudmore',
#  'Otis',
#  'though',
#  'reminiscence',
#  'precarious',
#  'stripped',
#  'Seven',
#  'State',
#  'plaintiffs',
#  'Seats',
#  'Cherry',
#  'Johnston',
#  'prior',
#  'ex-marine',
#  'on-the-scene',
#  'Using',
#  'drifts',
#  'reservoir',
#  'lose',
#  'provincial',
#  'Hargett',
#  'Sheraton-Biltmore',
#  '12th',
#  'Coconut',
#  'unspecified',
#  'obliged',
#  'informally',
#  'desperate',
#  'Person',
#  'hosts',
#  'existed',
#  'below',
#  'provisional',
#  'reservations',
#  'hammered',
#  'ayes',
#  'wedge',
#  '160',
#  'junior-senior',
#  'sporadic',
#  '2731',
#  'retarded',
#  'Golden',
#  'Vicky',
#  'means',
#  'Guam',
#  'outdoors',
#  'Aiding',
#  'peculiarities',
#  'executives',
#  'Circle',
#  '7-9',
#  'occupied',
#  '543',
#  '3,000',
#  '$46.7',
#  'specific',
#  'provoked',
#  "fund's",
#  'verdict',
#  'Ave.',
#  'walked',
#  'contingent',
#  'Second',
#  'Medical',
#  'scrutiny',
#  'adapting',
#  'manifestly',
#  'signals',
#  'Haddix',
#  'whiplash',
#  'Basel',
#  'marching',
#  'took',
#  'Leading',
#  'refuted',
#  'discrimination',
#  'repository',
#  'relinquish',
#  'Deane',
#  'Philadelphia',
#  'boundaries',
#  'lighters',
#  "Lanin's",
#  'corner',
#  'mad',
#  'competitor',
#  '$1.4',
#  'Boston',
#  'debuts',
#  'Hampton',
#  'issuance',
#  'Watson',
#  'Sheets',
#  'signing',
#  'rioting',
#  'burglarproof',
#  'privileges',
#  '1600',
#  'Brook',
#  'Kedzie',
#  'Horton',
#  'expended',
#  'tones',
#  'areas',
#  'chairs',
#  'prosecutors',
#  'unmistakably',
#  'franchise',
#  'ants',
#  'roommate',
#  'through',
#  'Tipoff',
#  'Navy',
#  'easy',
#  'Francis',
#  'infest',
#  "Beadles'",
#  'Zeising',
#  'Carlo',
#  'off-duty',
#  'silver',
#  'constituents',
#  'ends',
#  'false',
#  'batted',
#  'seat',
#  'Yogi',
#  'Opposition',
#  'Americans',
#  'owned',
#  'Stratton',
#  'skyjackers',
#  'Liberal',
#  'overlooked',
#  'churches',
#  'Sharkey',
#  'unofficial',
#  'dental',
#  'hand-crafted',
#  'monthly',
#  'bankers',
#  'Wilderness',
#  'contribution',
#  'doldrums',
#  'shaped',
#  'self-plagiarisms',
#  'Chancellor',
#  'imagine',
#  'negotiate',
#  'subtitled',
#  'skills',
#  'celebrates',
#  'Newcomers',
#  'preaching',
#  'mechanics',
#  'pursued',
#  'calendar',
#  'producer-hubby',
#  'one-over-par',
#  'JA',
#  'reached',
#  'amend',
#  'calls',
#  '32,589',
#  'dive',
#  'Richey',
#  'scenic',
#  'Shiflett',
#  'hijacked',
#  'century',
#  "Jenkins's",
#  'drums',
#  'grain',
#  "Simmons'",
#  'Drs.',
#  'gotten',
#  'benefits',
#  'Sunay',
#  'prospects',
#  'Nationalist',
#  'Sherwood',
#  'envision',
#  'cracked',
#  'Flushing',
#  'defray',
#  '46',
#  'meantime',
#  'mink',
#  'lend',
#  'Jefferson',
#  'improperly',
#  'blood',
#  'Grzesiak',
#  'merchandise',
#  'dread',
#  '$70',
#  'absorbed',
#  'Petitions',
#  'Burkes',
#  'royal',
#  'Foxx',
#  'Brandeis',
#  'Karns',
#  'labor',
#  'Cody',
#  'Nov.',
#  'Centredale',
#  'appraisal',
#  'delay',
#  'cross-examination',
#  'borrowing',
#  'figure',
#  'Pratt',
#  'statistical',
#  'oil',
#  'Angeles',
#  'Add',
#  'tiles',
#  'alarmingly',
#  'contributing',
#  'raises',
#  'Presently',
#  'enter',
#  'violation',
#  'recommendation',
#  'trying',
#  'Concern',
#  'Briar',
#  'get',
#  '$2,700',
#  '1500',
#  'Buddy',
#  'withdraw',
#  'exhibition',
#  'golden',
#  'in',
#  'honest',
#  'obligated',
#  'Universal-International',
#  'Motel',
#  'spices',
#  'manufacturer',
#  'previously',
#  'pre-set',
#  'unexpected',
#  'confrontations',
#  'sake',
#  'five-month',
#  'Westinghouse',
#  'Conflict',
#  'Division',
#  'fame',
#  'Joyce',
#  ...]

# %%
word2index['<UNK>'] = 0

# %%
#just in case we need to use
index2word = {v:k for k, v in word2index.items()}

# %% [markdown]
# ## 2. Build Co-occurence Matrix X

# %% [markdown]
# Here, we need to count the co-occurence of two words given some window size.  We gonna use window size of 1.

# %%
from collections import Counter

X_i = Counter(flatten(corpus))
X_i
# Out:
# Counter({'The': 806,
#          'Fulton': 14,
#          'County': 35,
#          'Grand': 6,
#          'Jury': 2,
#          'said': 402,
#          'Friday': 41,
#          'an': 300,
#          'investigation': 9,
#          'of': 2849,
#          "Atlanta's": 4,
#          'recent': 20,
#          'primary': 17,
#          'election': 38,
#          'produced': 6,
#          '``': 732,
#          'no': 109,
#          'evidence': 17,
#          "''": 702,
#          'that': 802,
#          'any': 90,
#          'irregularities': 3,
#          'took': 47,
#          'place': 25,
#          '.': 4030,
#          'jury': 44,
#          'further': 16,
#          'in': 1893,
#          'term-end': 1,
#          'presentments': 1,
#          'the': 5580,
#          'City': 44,
#          'Executive': 6,
#          'Committee': 37,
#          ',': 5188,
#          'which': 244,
#          'had': 279,
#          'over-all': 2,
#          'charge': 17,
#          'deserves': 3,
#          'praise': 2,
#          'and': 2146,
#          'thanks': 6,
#          'Atlanta': 14,
#          'for': 943,
#          'manner': 7,
#          'was': 717,
#          'conducted': 8,
#          'September-October': 1,
#          'term': 13,
#          'been': 212,
#          'charged': 12,
#          'by': 497,
#          'Superior': 5,
#          'Court': 26,
#          'Judge': 28,
#          'Durwood': 1,
#          'Pye': 1,
#          'to': 2116,
#          'investigate': 3,
#          'reports': 12,
#          'possible': 28,
#          'hard-fought': 1,
#          'won': 24,
#          'Mayor-nominate': 1,
#          'Ivan': 2,
#          'Allen': 7,
#          'Jr.': 46,
#          'Only': 8,
#          'a': 1993,
#          'relative': 3,
#          'handful': 1,
#          'such': 70,
#          'received': 33,
#          'considering': 2,
#          'widespread': 4,
#          'interest': 32,
#          'number': 32,
#          'voters': 12,
#          'size': 8,
#          'this': 250,
#          'city': 49,
#          'it': 363,
#          'did': 63,
#          'find': 16,
#          'many': 60,
#          "Georgia's": 7,
#          'registration': 2,
#          'laws': 30,
#          'are': 328,
#          'outmoded': 1,
#          'or': 173,
#          'inadequate': 4,
#          'often': 14,
#          'ambiguous': 1,
#          'It': 115,
#          'recommended': 9,
#          'legislators': 8,
#          'act': 20,
#          'have': 265,
#          'these': 59,
#          'studied': 7,
#          'revised': 2,
#          'end': 29,
#          'modernizing': 1,
#          'improving': 4,
#          'them': 96,
#          'grand': 13,
#          'commented': 7,
#          'on': 657,
#          'other': 149,
#          'topics': 2,
#          'among': 24,
#          'purchasing': 3,
#          'departments': 2,
#          'well': 43,
#          'operated': 4,
#          'follow': 12,
#          'generally': 14,
#          'accepted': 4,
#          'practices': 7,
#          'inure': 1,
#          'best': 29,
#          'both': 56,
#          'governments': 5,
#          'Merger': 1,
#          'proposed': 18,
#          'However': 12,
#          'believes': 8,
#          'two': 157,
#          'offices': 4,
#          'should': 59,
#          'be': 526,
#          'combined': 9,
#          'achieve': 6,
#          'greater': 10,
#          'efficiency': 2,
#          'reduce': 8,
#          'cost': 15,
#          'administration': 52,
#          'Purchasing': 1,
#          'Department': 20,
#          'is': 732,
#          'lacking': 3,
#          'experienced': 4,
#          'clerical': 4,
#          'personnel': 11,
#          'as': 481,
#          'result': 30,
#          'policies': 8,
#          'urged': 11,
#          'take': 48,
#          'steps': 8,
#          'remedy': 1,
#          'problem': 39,
#          'Implementation': 1,
#          'automobile': 4,
#          'title': 3,
#          'law': 38,
#          'also': 120,
#          'outgoing': 3,
#          'next': 40,
#          'Legislature': 19,
#          'provide': 24,
#          'enabling': 5,
#          'funds': 28,
#          're-set': 1,
#          'effective': 15,
#          'date': 16,
#          'so': 67,
#          'orderly': 3,
#          'implementation': 1,
#          'may': 66,
#          'effected': 1,
#          'swipe': 1,
#          'at': 598,
#          'State': 63,
#          'Welfare': 3,
#          "Department's": 2,
#          'handling': 3,
#          'federal': 35,
#          'granted': 5,
#          'child': 9,
#          'welfare': 13,
#          'services': 18,
#          'foster': 1,
#          'homes': 9,
#          'This': 70,
#          'one': 184,
#          'major': 28,
#          'items': 4,
#          'general': 29,
#          'assistance': 8,
#          'program': 66,
#          'but': 174,
#          'has': 300,
#          'seen': 7,
#          'fit': 3,
#          'distribute': 2,
#          'through': 54,
#          'all': 163,
#          'counties': 13,
#          'state': 90,
#          'with': 545,
#          'exception': 4,
#          'receives': 1,
#          'none': 7,
#          'money': 29,
#          'jurors': 4,
#          'they': 205,
#          'realize': 4,
#          'proportionate': 1,
#          'distribution': 7,
#          'might': 38,
#          'disable': 1,
#          'our': 55,
#          'less': 10,
#          'populous': 3,
#          'Nevertheless': 1,
#          'we': 77,
#          'feel': 19,
#          'future': 25,
#          'receive': 15,
#          'some': 95,
#          'portion': 2,
#          'available': 10,
#          'Failure': 2,
#          'do': 63,
#          'will': 389,
#          'continue': 11,
#          'disproportionate': 1,
#          'burden': 2,
#          'taxpayers': 5,
#          "ordinary's": 1,
#          'court': 29,
#          'under': 83,
#          'fire': 21,
#          'its': 174,
#          'appointment': 8,
#          'appraisers': 1,
#          'guardians': 2,
#          'administrators': 1,
#          'awarding': 1,
#          'fees': 13,
#          'compensation': 4,
#          'Wards': 1,
#          'protected': 1,
#          'found': 30,
#          'incorporated': 1,
#          'into': 114,
#          'operating': 4,
#          'procedures': 5,
#          'recommendations': 6,
#          'previous': 11,
#          'juries': 1,
#          'Bar': 2,
#          'Association': 18,
#          'interim': 2,
#          'citizens': 6,
#          'committee': 38,
#          'These': 11,
#          'actions': 6,
#          'serve': 7,
#          'protect': 2,
#          'fact': 25,
#          'effect': 17,
#          "court's": 1,
#          'wards': 1,
#          'from': 344,
#          'undue': 2,
#          'costs': 18,
#          'appointed': 6,
#          'elected': 11,
#          'servants': 5,
#          'unmeritorious': 1,
#          'criticisms': 2,
#          'Regarding': 1,
#          'new': 148,
#          'multi-million-dollar': 1,
#          'airport': 3,
#          'when': 128,
#          'management': 6,
#          'takes': 7,
#          'Jan.': 15,
#          '1': 47,
#          'eliminate': 5,
#          'political': 27,
#          'influences': 1,
#          'not': 254,
#          'elaborate': 3,
#          'added': 33,
#          'there': 131,
#          'periodic': 1,
#          'surveillance': 1,
#          'pricing': 3,
#          'concessionaires': 1,
#          'purpose': 9,
#          'keeping': 4,
#          'prices': 19,
#          'reasonable': 2,
#          'Ask': 1,
#          'jail': 6,
#          'deputies': 3,
#          'On': 34,
#          'matters': 3,
#          ':': 149,
#          '(': 168,
#          ')': 171,
#          'Four': 9,
#          'additional': 14,
#          'employed': 5,
#          'Jail': 2,
#          'doctor': 3,
#          'medical': 18,
#          'intern': 1,
#          'extern': 1,
#          'night': 64,
#          'weekend': 12,
#          'duty': 2,
#          '2': 33,
#          'work': 66,
#          'officials': 12,
#          'pass': 15,
#          'legislation': 14,
#          'permit': 6,
#          'establishment': 7,
#          'fair': 10,
#          'equitable': 1,
#          'pension': 5,
#          'plan': 45,
#          'employes': 9,
#          'praised': 3,
#          'operation': 15,
#          'Police': 9,
#          'Tax': 5,
#          "Commissioner's": 1,
#          'Office': 4,
#          'Bellwood': 1,
#          'Alpharetta': 1,
#          'prison': 7,
#          'farms': 3,
#          'Grady': 5,
#          'Hospital': 21,
#          'Health': 5,
#          'Mayor': 17,
#          'William': 36,
#          'B.': 31,
#          'Hartsfield': 5,
#          'filed': 7,
#          'suit': 6,
#          'divorce': 3,
#          'his': 399,
#          'wife': 35,
#          'Pearl': 1,
#          'Williams': 14,
#          'His': 29,
#          'petition': 6,
#          'mental': 1,
#          'cruelty': 1,
#          'couple': 13,
#          'married': 8,
#          'Aug.': 8,
#          '1913': 2,
#          'They': 62,
#          'son': 22,
#          'Berry': 5,
#          'daughter': 26,
#          'Mrs.': 253,
#          'J.': 42,
#          'M.': 22,
#          'Cheshire': 1,
#          'Griffin': 2,
#          'Attorneys': 2,
#          'mayor': 2,
#          'amicable': 1,
#          'property': 16,
#          'settlement': 3,
#          'agreed': 15,
#          'upon': 23,
#          'listed': 10,
#          "mayor's": 4,
#          'occupation': 4,
#          'attorney': 17,
#          'age': 11,
#          '71': 4,
#          "wife's": 1,
#          '74': 3,
#          'birth': 5,
#          'Opelika': 1,
#          'Ala.': 7,
#          'lived': 3,
#          'together': 27,
#          'man': 72,
#          'more': 171,
#          'than': 138,
#          'year': 138,
#          'home': 127,
#          '637': 1,
#          'E.': 34,
#          'Pelham': 5,
#          'Rd.': 3,
#          'Aj': 14,
#          'Henry': 18,
#          'L.': 25,
#          'Bowden': 2,
#          'brief': 2,
#          'interlude': 1,
#          'since': 61,
#          '1937': 2,
#          'career': 10,
#          'goes': 5,
#          'back': 69,
#          'council': 19,
#          '1923': 2,
#          'present': 30,
#          'office': 24,
#          'expires': 1,
#          'He': 191,
#          'succeeded': 3,
#          'who': 268,
#          'became': 20,
#          'candidate': 17,
#          'Sept.': 6,
#          '13': 16,
#          'after': 127,
#          'announced': 37,
#          'he': 451,
#          'would': 244,
#          'run': 35,
#          'reelection': 1,
#          'Georgia': 18,
#          'Republicans': 15,
#          'getting': 17,
#          'strong': 13,
#          'encouragement': 5,
#          'enter': 5,
#          '1962': 5,
#          "governor's": 4,
#          'race': 20,
#          'top': 34,
#          'official': 16,
#          'Wednesday': 22,
#          'Robert': 28,
#          'Snodgrass': 1,
#          'GOP': 5,
#          'chairman': 35,
#          'meeting': 62,
#          'held': 41,
#          'Tuesday': 43,
#          'Blue': 11,
#          'Ridge': 3,
#          'brought': 21,
#          'enthusiastic': 3,
#          'responses': 1,
#          'audience': 12,
#          'Party': 9,
#          'Chairman': 8,
#          'James': 37,
#          'W.': 38,
#          'Dorsey': 1,
#          'enthusiasm': 3,
#          'picking': 1,
#          'up': 168,
#          'rally': 3,
#          '8': 22,
#          'Savannah': 1,
#          'newly': 6,
#          'Texas': 48,
#          'Sen.': 18,
#          'John': 65,
#          'Tower': 1,
#          'featured': 3,
#          'speaker': 4,
#          'In': 127,
#          'warned': 2,
#          'entering': 5,
#          'governor': 13,
#          'force': 7,
#          'petitions': 6,
#          'out': 161,
#          'voting': 7,
#          'precincts': 4,
#          'obtain': 8,
#          'signatures': 5,
#          'registered': 2,
#          'Despite': 5,
#          'warning': 4,
#          'unanimous': 2,
#          'vote': 28,
#          'according': 23,
#          'attended': 10,
#          'When': 41,
#          'crowd': 8,
#          'asked': 34,
#          'whether': 18,
#          'wanted': 20,
#          'wait': 4,
#          'make': 43,
#          'voted': 9,
#          '--': 300,
#          'were': 252,
#          'dissents': 1,
#          'largest': 10,
#          'hurdle': 1,
#          'face': 19,
#          'says': 28,
#          'before': 86,
#          'making': 25,
#          'first': 143,
#          'alternative': 4,
#          'courses': 5,
#          'must': 50,
#          'taken': 30,
#          'Five': 4,
#          'per': 61,
#          'cent': 51,
#          'each': 61,
#          'county': 26,
#          'sign': 9,
#          'requesting': 1,
#          'allowed': 8,
#          'names': 6,
#          'candidates': 10,
#          'ballot': 8,
#          'hold': 10,
#          'unit': 10,
#          'system': 47,
#          'party': 34,
#          'opposes': 2,
#          'platform': 2,
#          'Sam': 13,
#          'Caldwell': 2,
#          'Highway': 6,
#          'public': 51,
#          'relations': 16,
#          'director': 30,
#          'resigned': 5,
#          'Lt.': 1,
#          'Gov.': 10,
#          'Garland': 3,
#          "Byrd's": 1,
#          'campaign': 17,
#          "Caldwell's": 1,
#          'resignation': 4,
#          'expected': 40,
#          'time': 97,
#          'Rob': 1,
#          'Ledford': 1,
#          'Gainesville': 1,
#          'assistant': 10,
#          'three': 97,
#          'years': 102,
#          'gubernatorial': 6,
#          'starts': 9,
#          'become': 23,
#          'coordinator': 5,
#          'Byrd': 1,
#          'wind': 4,
#          '1961': 42,
#          'session': 37,
#          'Monday': 54,
#          'head': 24,
#          'where': 58,
#          'highway': 7,
#          'bond': 11,
#          'approved': 8,
#          'shortly': 5,
#          'Before': 7,
#          'adjournment': 2,
#          'afternoon': 19,
#          'Senate': 32,
#          'approve': 2,
#          'study': 13,
#          'allotted': 2,
#          'rural': 9,
#          'urban': 4,
#          'areas': 12,
#          'determine': 3,
#          'what': 76,
#          'adjustments': 2,
#          'made': 107,
#          'Vandiver': 4,
#          'traditional': 8,
#          'visit': 6,
#          'chambers': 2,
#          'toward': 23,
#          'likely': 7,
#          'mention': 6,
#          '$100': 7,
#          'million': 45,
#          'issue': 30,
#          'earlier': 24,
#          'priority': 4,
#          'item': 1,
#          'Construction': 2,
#          'bonds': 29,
#          'Meanwhile': 4,
#          'learned': 7,
#          'very': 33,
#          'near': 16,
#          'being': 56,
#          'ready': 12,
#          '$30': 1,
#          'worth': 15,
#          'reconstruction': 1,
#          'go': 41,
#          'courts': 6,
#          'friendly': 3,
#          'test': 15,
#          'validity': 1,
#          'then': 56,
#          'sales': 51,
#          'begin': 10,
#          'contracts': 4,
#          'let': 10,
#          'repair': 2,
#          'most': 74,
#          'heavily': 5,
#          'traveled': 2,
#          'highways': 3,
#          'A': 137,
#          'source': 7,
#          '$3': 1,
#          '$4': 1,
#          'Rural': 2,
#          'Roads': 2,
#          'Authority': 4,
#          'road': 12,
#          'construction': 14,
#          'revolving': 3,
#          'fund': 12,
#          'department': 12,
#          'apparently': 12,
#          'intends': 1,
#          'issued': 8,
#          'every': 25,
#          'old': 23,
#          'ones': 8,
#          'paid': 25,
#          'off': 73,
#          'tax': 53,
#          'authorities': 7,
#          'opened': 9,
#          '1958': 19,
#          'battle': 15,
#          'against': 78,
#          'issuance': 2,
#          '$50': 2,
#          'roads': 10,
#          'Marvin': 2,
#          'told': 53,
#          'Constitution': 4,
#          'however': 37,
#          'consulted': 4,
#          'yet': 10,
#          'about': 136,
#          'plans': 22,
#          'Schley': 1,
#          'Rep.': 10,
#          'D.': 24,
#          'offer': 9,
#          'resolution': 21,
#          'House': 71,
#          'rescind': 2,
#          "body's": 1,
#          'action': 20,
#          'itself': 10,
#          '$10': 3,
#          'day': 61,
#          'increase': 24,
#          'expense': 7,
#          'allowances': 3,
#          'Sunday': 51,
#          'research': 15,
#          'done': 24,
#          'quickie': 1,
#          'can': 93,
#          'repealed': 1,
#          'outright': 3,
#          'notice': 5,
#          'given': 37,
#          'reconsideration': 2,
#          'sought': 6,
#          'While': 12,
#          'emphasizing': 1,
#          'technical': 7,
#          'details': 3,
#          'fully': 6,
#          'worked': 12,
#          'seek': 12,
#          'set': 51,
#          'aside': 5,
#          'privilege': 3,
#          '87-31': 1,
#          'similar': 17,
#          'passed': 18,
#          '29-5': 1,
#          'As': 36,
#          'word': 14,
#          'offered': 11,
#          'pointed': 9,
#          'last': 161,
#          'November': 10,
#          'rejected': 8,
#          'constitutional': 8,
#          'amendment': 5,
#          'allow': 5,
#          'pay': 33,
#          'raises': 3,
#          'sessions': 6,
#          'veteran': 11,
#          'Jackson': 5,
#          'legislator': 2,
#          'ask': 7,
#          'aid': 25,
#          'education': 31,
#          'something': 14,
#          'consistently': 1,
#          'opposed': 9,
#          'past': 35,
#          'Mac': 1,
#          'Barber': 5,
#          'Commerce': 7,
#          'asking': 5,
#          'endorse': 3,
#          'increased': 10,
#          'support': 24,
#          'provided': 8,
#          'expended': 1,
#          '13th': 5,
#          'members': 69,
#          'congressional': 6,
#          'delegation': 3,
#          'Washington': 48,
#          'like': 46,
#          'see': 38,
#          'But': 109,
#          'congressmen': 3,
#          'specifically': 1,
#          'him': 93,
#          'tossed': 1,
#          'hopper': 1,
#          'formally': 7,
#          'read': 13,
#          'event': 15,
#          'Congress': 21,
#          'does': 26,
#          'Board': 17,
#          'Education': 15,
#          'directed': 8,
#          'give': 32,
#          'teacher': 9,
#          'Colquitt': 2,
#          'After': 24,
#          'long': 39,
#          'hot': 9,
#          'controversy': 5,
#          'Miller': 3,
#          'school': 65,
#          'superintendent': 9,
#          'policeman': 2,
#          'put': 27,
#          'coolest': 2,
#          'I': 179,
#          'ever': 32,
#          'saw': 17,
#          'Harry': 10,
#          'Davis': 13,
#          'agriculture': 2,
#          'defeated': 5,
#          'Felix': 2,
#          'Bush': 3,
#          'principal': 9,
#          'Democratic': 37,
#          '1,119': 1,
#          'votes': 7,
#          "Saturday's": 2,
#          'got': 45,
#          '402': 1,
#          'Ordinary': 2,
#          'Carey': 5,
#          'armed': 7,
#          'pistol': 3,
#          'stood': 4,
#          'polls': 3,
#          'insure': 2,
#          'order': 19,
#          'calmest': 1,
#          'Policeman': 1,
#          'Tom': 6,
#          'Being': 1,
#          'just': 42,
#          'church': 16,
#          "didn't": 15,
#          'smell': 2,
#          'drop': 6,
#          'liquor': 4,
#          'bit': 7,
#          'trouble': 8,
#          'leading': 11,
#          'quiet': 5,
#          'marked': 4,
#          'anonymous': 4,
#          'midnight': 4,
#          'phone': 5,
#          'calls': 13,
#          'veiled': 3,
#          'threats': 1,
#          'violence': 3,
#          'former': 27,
#          'George': 23,
#          'P.': 18,
#          'Callan': 1,
#          'shot': 14,
#          'himself': 21,
#          'death': 10,
#          'March': 36,
#          '18': 20,
#          'four': 73,
#          'days': 38,
#          'post': 10,
#          'dispute': 2,
#          'board': 47,
#          'During': 5,
#          'reportedly': 4,
#          'telephone': 8,
#          'too': 37,
#          'subjected': 2,
#          'soon': 15,
#          'scheduled': 14,
#          'Many': 12,
#          'local': 39,
#          'feared': 1,
#          'carry': 11,
#          'gun': 2,
#          'promised': 4,
#          'Sheriff': 2,
#          'Tabb': 1,
#          'ordinary': 7,
#          'good': 50,
#          'promise': 3,
#          'Everything': 1,
#          'went': 37,
#          'real': 24,
#          'smooth': 1,
#          'sheriff': 3,
#          'There': 58,
#          "wasn't": 3,
#          'Austin': 15,
#          'approval': 8,
#          'Price': 3,
#          "Daniel's": 1,
#          'abandoned': 3,
#          'seemed': 12,
#          'certain': 18,
#          'Thursday': 20,
#          'despite': 11,
#          'adamant': 2,
#          'protests': 1,
#          'bankers': 8,
#          'Daniel': 5,
#          'personally': 3,
#          'led': 17,
#          'fight': 14,
#          'measure': 13,
#          'watered': 1,
#          'down': 50,
#          'considerably': 5,
#          'rejection': 3,
#          'Legislatures': 1,
#          'hearing': 14,
#          'Revenue': 5,
#          'Taxation': 1,
#          'Under': 8,
#          'rules': 11,
#          'automatically': 3,
#          'subcommittee': 1,
#          'week': 86,
#          'questions': 8,
#          'taunted': 1,
#          'appearing': 1,
#          'witnesses': 7,
#          'left': 39,
#          'little': 35,
#          'doubt': 6,
#          'recommend': 4,
#          'passage': 3,
#          'termed': 4,
#          'extremely': 2,
#          'conservative': 5,
#          'estimate': 3,
#          'produce': 7,
#          '17': 14,
#          'dollars': 15,
#          'help': 30,
#          'erase': 1,
#          'anticipated': 4,
#          'deficit': 1,
#          '63': 1,
#          'current': 13,
#          'fiscal': 5,
#          '31': 6,
#          'merely': 15,
#          'means': 18,
#          'enforcing': 1,
#          'escheat': 2,
#          'books': 12,
#          'republic': 1,
#          'permits': 4,
#          'over': 115,
#          'bank': 11,
#          'accounts': 2,
#          'stocks': 10,
#          'personal': 12,
#          'persons': 24,
#          'missing': 3,
#          'seven': 16,
#          'bill': 45,
#          'drafted': 1,
#          'banks': 4,
#          'insurance': 4,
#          'firms': 15,
#          'pipeline': 2,
#          'companies': 18,
#          'corporations': 2,
#          'report': 25,
#          'treasurer': 6,
#          'cannot': 15,
#          'enforced': 3,
#          'now': 76,
#          'because': 51,
#          'almost': 24,
#          'impossible': 4,
#          'locate': 1,
#          'declared': 15,
#          'Dewey': 1,
#          'Lawrence': 12,
#          'Tyler': 2,
#          'lawyer': 9,
#          'representing': 8,
#          'Bankers': 3,
#          'sounded': 1,
#          'opposition': 8,
#          'keynote': 3,
#          'violate': 2,
#          'their': 219,
#          'contractual': 1,
#          'obligations': 4,
#          'depositors': 1,
#          'undermine': 1,
#          'confidence': 6,
#          'customers': 7,
#          'If': 29,
#          'you': 55,
#          'destroy': 5,
#          'economy': 9,
#          'You': 11,
#          'circulation': 2,
#          'millions': 9,
#          'Charles': 22,
#          'Hughes': 22,
#          'Sherman': 9,
#          'sponsor': 4,
#          'failure': 5,
#          'enact': 1,
#          'amount': 18,
#          'gift': 5,
#          "taxpayers'": 2,
#          'pockets': 2,
#          'contention': 2,
#          'denied': 5,
#          'several': 34,
#          'including': 25,
#          'Scott': 3,
#          'Hudson': 2,
#          'Gaynor': 1,
#          'Jones': 22,
#          'Houston': 15,
#          'Brady': 1,
#          'Harlingen': 1,
#          'Howard': 13,
#          'Cox': 4,
#          'argued': 7,
#          'probably': 19,
#          'unconstitutional': 1,
#          'impair': 1,
#          'complained': 4,
#          'enough': 27,
#          'introduced': 10,
#          'only': 103,
#          'Senators': 4,
#          'unanimously': 2,
#          'Parkhouse': 5,
#          'Dallas': 49,
#          'authorizing': 2,
#          'schools': 37,
#          'deaf': 5,
#          'designed': 16,
#          'special': 41,
#          'schooling': 2,
#          ...})

# %%
window_size = 2

skip_grams = []

#loop each corpus
for doc in corpus:
    #look from the 2nd word until second last word
    for i in range(window_size, len(doc)-window_size):
        #center word
        center = doc[i]
        #outside words = 2 words

        outside = []
        for j in range(window_size):
            outside.append(doc[i+(j+1)])
            outside.append(doc[i-(j+1)])

        #for each of these two outside words, we gonna append to a list
        for each_out in outside:
            skip_grams.append((center, each_out))
            #center, outside1;   center, outside2

skip_grams
# Out:
# [('County', 'Grand'),
#  ('County', 'Fulton'),
#  ('County', 'Jury'),
#  ('County', 'The'),
#  ('Grand', 'Jury'),
#  ('Grand', 'County'),
#  ('Grand', 'said'),
#  ('Grand', 'Fulton'),
#  ('Jury', 'said'),
#  ('Jury', 'Grand'),
#  ('Jury', 'Friday'),
#  ('Jury', 'County'),
#  ('said', 'Friday'),
#  ('said', 'Jury'),
#  ('said', 'an'),
#  ('said', 'Grand'),
#  ('Friday', 'an'),
#  ('Friday', 'said'),
#  ('Friday', 'investigation'),
#  ('Friday', 'Jury'),
#  ('an', 'investigation'),
#  ('an', 'Friday'),
#  ('an', 'of'),
#  ('an', 'said'),
#  ('investigation', 'of'),
#  ('investigation', 'an'),
#  ('investigation', "Atlanta's"),
#  ('investigation', 'Friday'),
#  ('of', "Atlanta's"),
#  ('of', 'investigation'),
#  ('of', 'recent'),
#  ('of', 'an'),
#  ("Atlanta's", 'recent'),
#  ("Atlanta's", 'of'),
#  ("Atlanta's", 'primary'),
#  ("Atlanta's", 'investigation'),
#  ('recent', 'primary'),
#  ('recent', "Atlanta's"),
#  ('recent', 'election'),
#  ('recent', 'of'),
#  ('primary', 'election'),
#  ('primary', 'recent'),
#  ('primary', 'produced'),
#  ('primary', "Atlanta's"),
#  ('election', 'produced'),
#  ('election', 'primary'),
#  ('election', '``'),
#  ('election', 'recent'),
#  ('produced', '``'),
#  ('produced', 'election'),
#  ('produced', 'no'),
#  ('produced', 'primary'),
#  ('``', 'no'),
#  ('``', 'produced'),
#  ('``', 'evidence'),
#  ('``', 'election'),
#  ('no', 'evidence'),
#  ('no', '``'),
#  ('no', "''"),
#  ('no', 'produced'),
#  ('evidence', "''"),
#  ('evidence', 'no'),
#  ('evidence', 'that'),
#  ('evidence', '``'),
#  ("''", 'that'),
#  ("''", 'evidence'),
#  ("''", 'any'),
#  ("''", 'no'),
#  ('that', 'any'),
#  ('that', "''"),
#  ('that', 'irregularities'),
#  ('that', 'evidence'),
#  ('any', 'irregularities'),
#  ('any', 'that'),
#  ('any', 'took'),
#  ('any', "''"),
#  ('irregularities', 'took'),
#  ('irregularities', 'any'),
#  ('irregularities', 'place'),
#  ('irregularities', 'that'),
#  ('took', 'place'),
#  ('took', 'irregularities'),
#  ('took', '.'),
#  ('took', 'any'),
#  ('further', 'said'),
#  ('further', 'jury'),
#  ('further', 'in'),
#  ('further', 'The'),
#  ('said', 'in'),
#  ('said', 'further'),
#  ('said', 'term-end'),
#  ('said', 'jury'),
#  ('in', 'term-end'),
#  ('in', 'said'),
#  ('in', 'presentments'),
#  ('in', 'further'),
#  ('term-end', 'presentments'),
#  ('term-end', 'in'),
#  ('term-end', 'that'),
#  ('term-end', 'said'),
#  ('presentments', 'that'),
#  ('presentments', 'term-end'),
#  ('presentments', 'the'),
#  ('presentments', 'in'),
#  ('that', 'the'),
#  ('that', 'presentments'),
#  ('that', 'City'),
#  ('that', 'term-end'),
#  ('the', 'City'),
#  ('the', 'that'),
#  ('the', 'Executive'),
#  ('the', 'presentments'),
#  ('City', 'Executive'),
#  ('City', 'the'),
#  ('City', 'Committee'),
#  ('City', 'that'),
#  ('Executive', 'Committee'),
#  ('Executive', 'City'),
#  ('Executive', ','),
#  ('Executive', 'the'),
#  ('Committee', ','),
#  ('Committee', 'Executive'),
#  ('Committee', 'which'),
#  ('Committee', 'City'),
#  (',', 'which'),
#  (',', 'Committee'),
#  (',', 'had'),
#  (',', 'Executive'),
#  ('which', 'had'),
#  ('which', ','),
#  ('which', 'over-all'),
#  ('which', 'Committee'),
#  ('had', 'over-all'),
#  ('had', 'which'),
#  ('had', 'charge'),
#  ('had', ','),
#  ('over-all', 'charge'),
#  ('over-all', 'had'),
#  ('over-all', 'of'),
#  ('over-all', 'which'),
#  ('charge', 'of'),
#  ('charge', 'over-all'),
#  ('charge', 'the'),
#  ('charge', 'had'),
#  ('of', 'the'),
#  ('of', 'charge'),
#  ('of', 'election'),
#  ('of', 'over-all'),
#  ('the', 'election'),
#  ('the', 'of'),
#  ('the', ','),
#  ('the', 'charge'),
#  ('election', ','),
#  ('election', 'the'),
#  ('election', '``'),
#  ('election', 'of'),
#  (',', '``'),
#  (',', 'election'),
#  (',', 'deserves'),
#  (',', 'the'),
#  ('``', 'deserves'),
#  ('``', ','),
#  ('``', 'the'),
#  ('``', 'election'),
#  ('deserves', 'the'),
#  ('deserves', '``'),
#  ('deserves', 'praise'),
#  ('deserves', ','),
#  ('the', 'praise'),
#  ('the', 'deserves'),
#  ('the', 'and'),
#  ('the', '``'),
#  ('praise', 'and'),
#  ('praise', 'the'),
#  ('praise', 'thanks'),
#  ('praise', 'deserves'),
#  ('and', 'thanks'),
#  ('and', 'praise'),
#  ('and', 'of'),
#  ('and', 'the'),
#  ('thanks', 'of'),
#  ('thanks', 'and'),
#  ('thanks', 'the'),
#  ('thanks', 'praise'),
#  ('of', 'the'),
#  ('of', 'thanks'),
#  ('of', 'City'),
#  ('of', 'and'),
#  ('the', 'City'),
#  ('the', 'of'),
#  ('the', 'of'),
#  ('the', 'thanks'),
#  ('City', 'of'),
#  ('City', 'the'),
#  ('City', 'Atlanta'),
#  ('City', 'of'),
#  ('of', 'Atlanta'),
#  ('of', 'City'),
#  ('of', "''"),
#  ('of', 'the'),
#  ('Atlanta', "''"),
#  ('Atlanta', 'of'),
#  ('Atlanta', 'for'),
#  ('Atlanta', 'City'),
#  ("''", 'for'),
#  ("''", 'Atlanta'),
#  ("''", 'the'),
#  ("''", 'of'),
#  ('for', 'the'),
#  ('for', "''"),
#  ('for', 'manner'),
#  ('for', 'Atlanta'),
#  ('the', 'manner'),
#  ('the', 'for'),
#  ('the', 'in'),
#  ('the', "''"),
#  ('manner', 'in'),
#  ('manner', 'the'),
#  ('manner', 'which'),
#  ('manner', 'for'),
#  ('in', 'which'),
#  ('in', 'manner'),
#  ('in', 'the'),
#  ('in', 'the'),
#  ('which', 'the'),
#  ('which', 'in'),
#  ('which', 'election'),
#  ('which', 'manner'),
#  ('the', 'election'),
#  ('the', 'which'),
#  ('the', 'was'),
#  ('the', 'in'),
#  ('election', 'was'),
#  ('election', 'the'),
#  ('election', 'conducted'),
#  ('election', 'which'),
#  ('was', 'conducted'),
#  ('was', 'election'),
#  ('was', '.'),
#  ('was', 'the'),
#  ('term', 'jury'),
#  ('term', 'September-October'),
#  ('term', 'had'),
#  ('term', 'The'),
#  ('jury', 'had'),
#  ('jury', 'term'),
#  ('jury', 'been'),
#  ('jury', 'September-October'),
#  ('had', 'been'),
#  ('had', 'jury'),
#  ('had', 'charged'),
#  ('had', 'term'),
#  ('been', 'charged'),
#  ('been', 'had'),
#  ('been', 'by'),
#  ('been', 'jury'),
#  ('charged', 'by'),
#  ('charged', 'been'),
#  ('charged', 'Fulton'),
#  ('charged', 'had'),
#  ('by', 'Fulton'),
#  ('by', 'charged'),
#  ('by', 'Superior'),
#  ('by', 'been'),
#  ('Fulton', 'Superior'),
#  ('Fulton', 'by'),
#  ('Fulton', 'Court'),
#  ('Fulton', 'charged'),
#  ('Superior', 'Court'),
#  ('Superior', 'Fulton'),
#  ('Superior', 'Judge'),
#  ('Superior', 'by'),
#  ('Court', 'Judge'),
#  ('Court', 'Superior'),
#  ('Court', 'Durwood'),
#  ('Court', 'Fulton'),
#  ('Judge', 'Durwood'),
#  ('Judge', 'Court'),
#  ('Judge', 'Pye'),
#  ('Judge', 'Superior'),
#  ('Durwood', 'Pye'),
#  ('Durwood', 'Judge'),
#  ('Durwood', 'to'),
#  ('Durwood', 'Court'),
#  ('Pye', 'to'),
#  ('Pye', 'Durwood'),
#  ('Pye', 'investigate'),
#  ('Pye', 'Judge'),
#  ('to', 'investigate'),
#  ('to', 'Pye'),
#  ('to', 'reports'),
#  ('to', 'Durwood'),
#  ('investigate', 'reports'),
#  ('investigate', 'to'),
#  ('investigate', 'of'),
#  ('investigate', 'Pye'),
#  ('reports', 'of'),
#  ('reports', 'investigate'),
#  ('reports', 'possible'),
#  ('reports', 'to'),
#  ('of', 'possible'),
#  ('of', 'reports'),
#  ('of', '``'),
#  ('of', 'investigate'),
#  ('possible', '``'),
#  ('possible', 'of'),
#  ('possible', 'irregularities'),
#  ('possible', 'reports'),
#  ('``', 'irregularities'),
#  ('``', 'possible'),
#  ('``', "''"),
#  ('``', 'of'),
#  ('irregularities', "''"),
#  ('irregularities', '``'),
#  ('irregularities', 'in'),
#  ('irregularities', 'possible'),
#  ("''", 'in'),
#  ("''", 'irregularities'),
#  ("''", 'the'),
#  ("''", '``'),
#  ('in', 'the'),
#  ('in', "''"),
#  ('in', 'hard-fought'),
#  ('in', 'irregularities'),
#  ('the', 'hard-fought'),
#  ('the', 'in'),
#  ('the', 'primary'),
#  ('the', "''"),
#  ('hard-fought', 'primary'),
#  ('hard-fought', 'the'),
#  ('hard-fought', 'which'),
#  ('hard-fought', 'in'),
#  ('primary', 'which'),
#  ('primary', 'hard-fought'),
#  ('primary', 'was'),
#  ('primary', 'the'),
#  ('which', 'was'),
#  ('which', 'primary'),
#  ('which', 'won'),
#  ('which', 'hard-fought'),
#  ('was', 'won'),
#  ('was', 'which'),
#  ('was', 'by'),
#  ('was', 'primary'),
#  ('won', 'by'),
#  ('won', 'was'),
#  ('won', 'Mayor-nominate'),
#  ('won', 'which'),
#  ('by', 'Mayor-nominate'),
#  ('by', 'won'),
#  ('by', 'Ivan'),
#  ('by', 'was'),
#  ('Mayor-nominate', 'Ivan'),
#  ('Mayor-nominate', 'by'),
#  ('Mayor-nominate', 'Allen'),
#  ('Mayor-nominate', 'won'),
#  ('Ivan', 'Allen'),
#  ('Ivan', 'Mayor-nominate'),
#  ('Ivan', 'Jr.'),
#  ('Ivan', 'by'),
#  ('Allen', 'Jr.'),
#  ('Allen', 'Ivan'),
#  ('Allen', '.'),
#  ('Allen', 'Mayor-nominate'),
#  ('a', 'relative'),
#  ('a', 'Only'),
#  ('a', 'handful'),
#  ('a', '``'),
#  ('relative', 'handful'),
#  ('relative', 'a'),
#  ('relative', 'of'),
#  ('relative', 'Only'),
#  ('handful', 'of'),
#  ('handful', 'relative'),
#  ('handful', 'such'),
#  ('handful', 'a'),
#  ('of', 'such'),
#  ('of', 'handful'),
#  ('of', 'reports'),
#  ('of', 'relative'),
#  ('such', 'reports'),
#  ('such', 'of'),
#  ('such', 'was'),
#  ('such', 'handful'),
#  ('reports', 'was'),
#  ('reports', 'such'),
#  ('reports', 'received'),
#  ('reports', 'of'),
#  ('was', 'received'),
#  ('was', 'reports'),
#  ('was', "''"),
#  ('was', 'such'),
#  ('received', "''"),
#  ('received', 'was'),
#  ('received', ','),
#  ('received', 'reports'),
#  ("''", ','),
#  ("''", 'received'),
#  ("''", 'the'),
#  ("''", 'was'),
#  (',', 'the'),
#  (',', "''"),
#  (',', 'jury'),
#  (',', 'received'),
#  ('the', 'jury'),
#  ('the', ','),
#  ('the', 'said'),
#  ('the', "''"),
#  ('jury', 'said'),
#  ('jury', 'the'),
#  ('jury', ','),
#  ('jury', ','),
#  ('said', ','),
#  ('said', 'jury'),
#  ('said', '``'),
#  ('said', 'the'),
#  (',', '``'),
#  (',', 'said'),
#  (',', 'considering'),
#  (',', 'jury'),
#  ('``', 'considering'),
#  ('``', ','),
#  ('``', 'the'),
#  ('``', 'said'),
#  ('considering', 'the'),
#  ('considering', '``'),
#  ('considering', 'widespread'),
#  ('considering', ','),
#  ('the', 'widespread'),
#  ('the', 'considering'),
#  ('the', 'interest'),
#  ('the', '``'),
#  ('widespread', 'interest'),
#  ('widespread', 'the'),
#  ('widespread', 'in'),
#  ('widespread', 'considering'),
#  ('interest', 'in'),
#  ('interest', 'widespread'),
#  ('interest', 'the'),
#  ('interest', 'the'),
#  ('in', 'the'),
#  ('in', 'interest'),
#  ('in', 'election'),
#  ('in', 'widespread'),
#  ('the', 'election'),
#  ('the', 'in'),
#  ('the', ','),
#  ('the', 'interest'),
#  ('election', ','),
#  ('election', 'the'),
#  ('election', 'the'),
#  ('election', 'in'),
#  (',', 'the'),
#  (',', 'election'),
#  (',', 'number'),
#  (',', 'the'),
#  ('the', 'number'),
#  ('the', ','),
#  ('the', 'of'),
#  ('the', 'election'),
#  ('number', 'of'),
#  ('number', 'the'),
#  ('number', 'voters'),
#  ('number', ','),
#  ('of', 'voters'),
#  ('of', 'number'),
#  ('of', 'and'),
#  ('of', 'the'),
#  ('voters', 'and'),
#  ('voters', 'of'),
#  ('voters', 'the'),
#  ('voters', 'number'),
#  ('and', 'the'),
#  ('and', 'voters'),
#  ('and', 'size'),
#  ('and', 'of'),
#  ('the', 'size'),
#  ('the', 'and'),
#  ('the', 'of'),
#  ('the', 'voters'),
#  ('size', 'of'),
#  ('size', 'the'),
#  ('size', 'this'),
#  ('size', 'and'),
#  ('of', 'this'),
#  ('of', 'size'),
#  ('of', 'city'),
#  ('of', 'the'),
#  ('this', 'city'),
#  ('this', 'of'),
#  ('this', "''"),
#  ('this', 'size'),
#  ('city', "''"),
#  ('city', 'this'),
#  ('city', '.'),
#  ('city', 'of'),
#  ('said', 'it'),
#  ('said', 'jury'),
#  ('said', 'did'),
#  ('said', 'The'),
#  ('it', 'did'),
#  ('it', 'said'),
#  ('it', 'find'),
#  ('it', 'jury'),
#  ('did', 'find'),
#  ('did', 'it'),
#  ('did', 'that'),
#  ('did', 'said'),
#  ('find', 'that'),
#  ('find', 'did'),
#  ('find', 'many'),
#  ('find', 'it'),
#  ('that', 'many'),
#  ('that', 'find'),
#  ('that', 'of'),
#  ('that', 'did'),
#  ('many', 'of'),
#  ('many', 'that'),
#  ('many', "Georgia's"),
#  ('many', 'find'),
#  ('of', "Georgia's"),
#  ('of', 'many'),
#  ('of', 'registration'),
#  ('of', 'that'),
#  ("Georgia's", 'registration'),
#  ("Georgia's", 'of'),
#  ("Georgia's", 'and'),
#  ("Georgia's", 'many'),
#  ('registration', 'and'),
#  ('registration', "Georgia's"),
#  ('registration', 'election'),
#  ('registration', 'of'),
#  ('and', 'election'),
#  ('and', 'registration'),
#  ('and', 'laws'),
#  ('and', "Georgia's"),
#  ('election', 'laws'),
#  ('election', 'and'),
#  ('election', '``'),
#  ('election', 'registration'),
#  ('laws', '``'),
#  ('laws', 'election'),
#  ('laws', 'are'),
#  ('laws', 'and'),
#  ('``', 'are'),
#  ('``', 'laws'),
#  ('``', 'outmoded'),
#  ('``', 'election'),
#  ('are', 'outmoded'),
#  ('are', '``'),
#  ('are', 'or'),
#  ('are', 'laws'),
#  ('outmoded', 'or'),
#  ('outmoded', 'are'),
#  ('outmoded', 'inadequate'),
#  ('outmoded', '``'),
#  ('or', 'inadequate'),
#  ('or', 'outmoded'),
#  ('or', 'and'),
#  ('or', 'are'),
#  ('inadequate', 'and'),
#  ('inadequate', 'or'),
#  ('inadequate', 'often'),
#  ('inadequate', 'outmoded'),
#  ('and', 'often'),
#  ('and', 'inadequate'),
#  ('and', 'ambiguous'),
#  ('and', 'or'),
#  ('often', 'ambiguous'),
#  ('often', 'and'),
#  ('often', "''"),
#  ('often', 'inadequate'),
#  ('ambiguous', "''"),
#  ('ambiguous', 'often'),
#  ('ambiguous', '.'),
#  ('ambiguous', 'and'),
#  ('that', 'Fulton'),
#  ('that', 'recommended'),
#  ('that', 'legislators'),
#  ('that', 'It'),
#  ('Fulton', 'legislators'),
#  ('Fulton', 'that'),
#  ('Fulton', 'act'),
#  ('Fulton', 'recommended'),
#  ('legislators', 'act'),
#  ('legislators', 'Fulton'),
#  ('legislators', '``'),
#  ('legislators', 'that'),
#  ('act', '``'),
#  ('act', 'legislators'),
#  ('act', 'to'),
#  ('act', 'Fulton'),
#  ('``', 'to'),
#  ('``', 'act'),
#  ('``', 'have'),
#  ('``', 'legislators'),
#  ('to', 'have'),
#  ('to', '``'),
#  ('to', 'these'),
#  ('to', 'act'),
#  ('have', 'these'),
#  ('have', 'to'),
#  ('have', 'laws'),
#  ('have', '``'),
#  ('these', 'laws'),
#  ('these', 'have'),
#  ('these', 'studied'),
#  ('these', 'to'),
#  ('laws', 'studied'),
#  ('laws', 'these'),
#  ('laws', 'and'),
#  ('laws', 'have'),
#  ('studied', 'and'),
#  ('studied', 'laws'),
#  ('studied', 'revised'),
#  ('studied', 'these'),
#  ('and', 'revised'),
#  ('and', 'studied'),
#  ('and', 'to'),
#  ('and', 'laws'),
#  ('revised', 'to'),
#  ('revised', 'and'),
#  ('revised', 'the'),
#  ('revised', 'studied'),
#  ('to', 'the'),
#  ('to', 'revised'),
#  ('to', 'end'),
#  ('to', 'and'),
#  ('the', 'end'),
#  ('the', 'to'),
#  ('the', 'of'),
#  ('the', 'revised'),
#  ('end', 'of'),
#  ('end', 'the'),
#  ('end', 'modernizing'),
#  ('end', 'to'),
#  ('of', 'modernizing'),
#  ('of', 'end'),
#  ('of', 'and'),
#  ('of', 'the'),
#  ('modernizing', 'and'),
#  ('modernizing', 'of'),
#  ('modernizing', 'improving'),
#  ('modernizing', 'end'),
#  ('and', 'improving'),
#  ('and', 'modernizing'),
#  ('and', 'them'),
#  ('and', 'of'),
#  ('improving', 'them'),
#  ('improving', 'and'),
#  ('improving', "''"),
#  ('improving', 'modernizing'),
#  ('them', "''"),
#  ('them', 'improving'),
#  ('them', '.'),
#  ('them', 'and'),
#  ('jury', 'commented'),
#  ('jury', 'grand'),
#  ('jury', 'on'),
#  ('jury', 'The'),
#  ('commented', 'on'),
#  ('commented', 'jury'),
#  ('commented', 'a'),
#  ('commented', 'grand'),
#  ('on', 'a'),
#  ('on', 'commented'),
#  ('on', 'number'),
#  ('on', 'jury'),
#  ('a', 'number'),
#  ('a', 'on'),
#  ('a', 'of'),
#  ('a', 'commented'),
#  ('number', 'of'),
#  ('number', 'a'),
#  ('number', 'other'),
#  ('number', 'on'),
#  ('of', 'other'),
#  ('of', 'number'),
#  ('of', 'topics'),
#  ('of', 'a'),
#  ('other', 'topics'),
#  ('other', 'of'),
#  ('other', ','),
#  ('other', 'number'),
#  ('topics', ','),
#  ('topics', 'other'),
#  ('topics', 'among'),
#  ('topics', 'of'),
#  (',', 'among'),
#  (',', 'topics'),
#  (',', 'them'),
#  (',', 'other'),
#  ('among', 'them'),
#  ('among', ','),
#  ('among', 'the'),
#  ('among', 'topics'),
#  ('them', 'the'),
#  ('them', 'among'),
#  ('them', 'Atlanta'),
#  ('them', ','),
#  ('the', 'Atlanta'),
#  ('the', 'them'),
#  ('the', 'and'),
#  ('the', 'among'),
#  ('Atlanta', 'and'),
#  ('Atlanta', 'the'),
#  ('Atlanta', 'Fulton'),
#  ('Atlanta', 'them'),
#  ('and', 'Fulton'),
#  ('and', 'Atlanta'),
#  ('and', 'County'),
#  ('and', 'the'),
#  ('Fulton', 'County'),
#  ('Fulton', 'and'),
#  ('Fulton', 'purchasing'),
#  ('Fulton', 'Atlanta'),
#  ('County', 'purchasing'),
#  ('County', 'Fulton'),
#  ('County', 'departments'),
#  ('County', 'and'),
#  ('purchasing', 'departments'),
#  ('purchasing', 'County'),
#  ('purchasing', 'which'),
#  ('purchasing', 'Fulton'),
#  ('departments', 'which'),
#  ('departments', 'purchasing'),
#  ('departments', 'it'),
#  ('departments', 'County'),
#  ('which', 'it'),
#  ('which', 'departments'),
#  ('which', 'said'),
#  ('which', 'purchasing'),
#  ('it', 'said'),
#  ('it', 'which'),
#  ('it', '``'),
#  ('it', 'departments'),
#  ('said', '``'),
#  ('said', 'it'),
#  ('said', 'are'),
#  ('said', 'which'),
#  ('``', 'are'),
#  ('``', 'said'),
#  ('``', 'well'),
#  ('``', 'it'),
#  ('are', 'well'),
#  ('are', '``'),
#  ('are', 'operated'),
#  ('are', 'said'),
#  ('well', 'operated'),
#  ('well', 'are'),
#  ('well', 'and'),
#  ('well', '``'),
#  ('operated', 'and'),
#  ('operated', 'well'),
#  ('operated', 'follow'),
#  ('operated', 'are'),
#  ('and', 'follow'),
#  ('and', 'operated'),
#  ('and', 'generally'),
#  ('and', 'well'),
#  ('follow', 'generally'),
#  ('follow', 'and'),
#  ('follow', 'accepted'),
#  ('follow', 'operated'),
#  ('generally', 'accepted'),
#  ('generally', 'follow'),
#  ('generally', 'practices'),
#  ('generally', 'and'),
#  ('accepted', 'practices'),
#  ('accepted', 'generally'),
#  ('accepted', 'which'),
#  ('accepted', 'follow'),
#  ('practices', 'which'),
#  ('practices', 'accepted'),
#  ('practices', 'inure'),
#  ('practices', 'generally'),
#  ('which', 'inure'),
#  ('which', 'practices'),
#  ('which', 'to'),
#  ('which', 'accepted'),
#  ('inure', 'to'),
#  ('inure', 'which'),
#  ('inure', 'the'),
#  ('inure', 'practices'),
#  ('to', 'the'),
#  ('to', 'inure'),
#  ('to', 'best'),
#  ('to', 'which'),
#  ('the', 'best'),
#  ('the', 'to'),
#  ('the', 'interest'),
#  ('the', 'inure'),
#  ('best', 'interest'),
#  ('best', 'the'),
#  ('best', 'of'),
#  ('best', 'to'),
#  ('interest', 'of'),
#  ('interest', 'best'),
#  ('interest', 'both'),
#  ('interest', 'the'),
#  ('of', 'both'),
#  ('of', 'interest'),
#  ('of', 'governments'),
#  ('of', 'best'),
#  ('both', 'governments'),
#  ('both', 'of'),
#  ('both', "''"),
#  ('both', 'interest'),
#  ('governments', "''"),
#  ('governments', 'both'),
#  ('governments', '.'),
#  ('governments', 'of'),
#  ('the', 'jury'),
#  ('the', ','),
#  ('the', 'said'),
#  ('the', 'However'),
#  ('jury', 'said'),
#  ('jury', 'the'),
#  ('jury', 'it'),
#  ('jury', ','),
#  ('said', 'it'),
#  ('said', 'jury'),
#  ('said', 'believes'),
#  ('said', 'the'),
#  ('it', 'believes'),
#  ('it', 'said'),
#  ('it', '``'),
#  ('it', 'jury'),
#  ('believes', '``'),
#  ('believes', 'it'),
#  ('believes', 'these'),
#  ('believes', 'said'),
#  ('``', 'these'),
#  ('``', 'believes'),
#  ('``', 'two'),
#  ('``', 'it'),
#  ('these', 'two'),
#  ('these', '``'),
#  ('these', 'offices'),
#  ('these', 'believes'),
#  ('two', 'offices'),
#  ('two', 'these'),
#  ('two', 'should'),
#  ('two', '``'),
#  ('offices', 'should'),
#  ('offices', 'two'),
#  ('offices', 'be'),
#  ('offices', 'these'),
#  ('should', 'be'),
#  ('should', 'offices'),
#  ('should', 'combined'),
#  ('should', 'two'),
#  ('be', 'combined'),
#  ('be', 'should'),
#  ('be', 'to'),
#  ('be', 'offices'),
#  ('combined', 'to'),
#  ('combined', 'be'),
#  ('combined', 'achieve'),
#  ('combined', 'should'),
#  ('to', 'achieve'),
#  ('to', 'combined'),
#  ('to', 'greater'),
#  ('to', 'be'),
#  ('achieve', 'greater'),
#  ('achieve', 'to'),
#  ('achieve', 'efficiency'),
#  ('achieve', 'combined'),
#  ('greater', 'efficiency'),
#  ('greater', 'achieve'),
#  ('greater', 'and'),
#  ('greater', 'to'),
#  ('efficiency', 'and'),
#  ('efficiency', 'greater'),
#  ('efficiency', 'reduce'),
#  ('efficiency', 'achieve'),
#  ('and', 'reduce'),
#  ('and', 'efficiency'),
#  ('and', 'the'),
#  ('and', 'greater'),
#  ('reduce', 'the'),
#  ('reduce', 'and'),
#  ('reduce', 'cost'),
#  ('reduce', 'efficiency'),
#  ('the', 'cost'),
#  ('the', 'reduce'),
#  ('the', 'of'),
#  ('the', 'and'),
#  ('cost', 'of'),
#  ('cost', 'the'),
#  ('cost', 'administration'),
#  ('cost', 'reduce'),
#  ('of', 'administration'),
#  ('of', 'cost'),
#  ('of', "''"),
#  ('of', 'the'),
#  ('administration', "''"),
#  ('administration', 'of'),
#  ('administration', '.'),
#  ('administration', 'cost'),
#  ('Purchasing', 'Department'),
#  ('Purchasing', 'City'),
#  ('Purchasing', ','),
#  ('Purchasing', 'The'),
#  ('Department', ','),
#  ('Department', 'Purchasing'),
#  ('Department', 'the'),
#  ('Department', 'City'),
#  (',', 'the'),
#  (',', 'Department'),
#  (',', 'jury'),
#  (',', 'Purchasing'),
#  ('the', 'jury'),
#  ('the', ','),
#  ('the', 'said'),
#  ('the', 'Department'),
#  ('jury', 'said'),
#  ('jury', 'the'),
#  ('jury', ','),
#  ('jury', ','),
#  ('said', ','),
#  ('said', 'jury'),
#  ('said', '``'),
#  ('said', 'the'),
#  (',', '``'),
#  (',', 'said'),
#  (',', 'is'),
#  (',', 'jury'),
#  ('``', 'is'),
#  ('``', ','),
#  ('``', 'lacking'),
#  ('``', 'said'),
#  ('is', 'lacking'),
#  ('is', '``'),
#  ('is', 'in'),
#  ('is', ','),
#  ('lacking', 'in'),
#  ('lacking', 'is'),
#  ('lacking', 'experienced'),
#  ('lacking', '``'),
#  ('in', 'experienced'),
#  ('in', 'lacking'),
#  ('in', 'clerical'),
#  ('in', 'is'),
#  ('experienced', 'clerical'),
#  ('experienced', 'in'),
#  ('experienced', 'personnel'),
#  ('experienced', 'lacking'),
#  ('clerical', 'personnel'),
#  ('clerical', 'experienced'),
#  ('clerical', 'as'),
#  ('clerical', 'in'),
#  ('personnel', 'as'),
#  ('personnel', 'clerical'),
#  ('personnel', 'a'),
#  ('personnel', 'experienced'),
#  ('as', 'a'),
#  ('as', 'personnel'),
#  ('as', 'result'),
#  ('as', 'clerical'),
#  ('a', 'result'),
#  ('a', 'as'),
#  ('a', 'of'),
#  ('a', 'personnel'),
#  ('result', 'of'),
#  ('result', 'a'),
#  ('result', 'city'),
#  ('result', 'as'),
#  ('of', 'city'),
#  ('of', 'result'),
#  ('of', 'personnel'),
#  ('of', 'a'),
#  ('city', 'personnel'),
#  ('city', 'of'),
#  ('city', 'policies'),
#  ('city', 'result'),
#  ('personnel', 'policies'),
#  ('personnel', 'city'),
#  ('personnel', "''"),
#  ('personnel', 'of'),
#  ('policies', "''"),
#  ('policies', 'personnel'),
#  ('policies', '.'),
#  ('policies', 'city'),
#  ('that', 'the'),
#  ('that', 'urged'),
#  ('that', 'city'),
#  ('that', 'It'),
#  ('the', 'city'),
#  ('the', 'that'),
#  ('the', '``'),
#  ('the', 'urged'),
#  ('city', '``'),
#  ('city', 'the'),
#  ('city', 'take'),
#  ('city', 'that'),
#  ('``', 'take'),
#  ('``', 'city'),
#  ('``', 'steps'),
#  ('``', 'the'),
#  ...]

# %%
X_ik_skipgrams = Counter(skip_grams)
X_ik_skipgrams
# Out:
# Counter({('County', 'Grand'): 1,
#          ('County', 'Fulton'): 6,
#          ('County', 'Jury'): 1,
#          ('County', 'The'): 1,
#          ('Grand', 'Jury'): 1,
#          ('Grand', 'County'): 1,
#          ('Grand', 'said'): 1,
#          ('Grand', 'Fulton'): 1,
#          ('Jury', 'said'): 1,
#          ('Jury', 'Grand'): 2,
#          ('Jury', 'Friday'): 1,
#          ('Jury', 'County'): 1,
#          ('said', 'Friday'): 5,
#          ('said', 'Jury'): 1,
#          ('said', 'an'): 2,
#          ('said', 'Grand'): 1,
#          ('Friday', 'an'): 1,
#          ('Friday', 'said'): 3,
#          ('Friday', 'investigation'): 1,
#          ('Friday', 'Jury'): 1,
#          ('an', 'investigation'): 3,
#          ('an', 'Friday'): 1,
#          ('an', 'of'): 43,
#          ('an', 'said'): 2,
#          ('investigation', 'of'): 4,
#          ('investigation', 'an'): 4,
#          ('investigation', "Atlanta's"): 1,
#          ('investigation', 'Friday'): 1,
#          ('of', "Atlanta's"): 1,
#          ('of', 'investigation'): 5,
#          ('of', 'recent'): 2,
#          ('of', 'an'): 44,
#          ("Atlanta's", 'recent'): 1,
#          ("Atlanta's", 'of'): 1,
#          ("Atlanta's", 'primary'): 1,
#          ("Atlanta's", 'investigation'): 1,
#          ('recent', 'primary'): 1,
#          ('recent', "Atlanta's"): 1,
#          ('recent', 'election'): 2,
#          ('recent', 'of'): 3,
#          ('primary', 'election'): 2,
#          ('primary', 'recent'): 1,
#          ('primary', 'produced'): 1,
#          ('primary', "Atlanta's"): 1,
#          ('election', 'produced'): 1,
#          ('election', 'primary'): 2,
#          ('election', '``'): 4,
#          ('election', 'recent'): 2,
#          ('produced', '``'): 3,
#          ('produced', 'election'): 1,
#          ('produced', 'no'): 1,
#          ('produced', 'primary'): 1,
#          ('``', 'no'): 2,
#          ('``', 'produced'): 3,
#          ('``', 'evidence'): 2,
#          ('``', 'election'): 4,
#          ('no', 'evidence'): 2,
#          ('no', '``'): 2,
#          ('no', "''"): 1,
#          ('no', 'produced'): 1,
#          ('evidence', "''"): 2,
#          ('evidence', 'no'): 2,
#          ('evidence', 'that'): 6,
#          ('evidence', '``'): 2,
#          ("''", 'that'): 7,
#          ("''", 'evidence'): 1,
#          ("''", 'any'): 1,
#          ("''", 'no'): 1,
#          ('that', 'any'): 8,
#          ('that', "''"): 12,
#          ('that', 'irregularities'): 1,
#          ('that', 'evidence'): 6,
#          ('any', 'irregularities'): 1,
#          ('any', 'that'): 8,
#          ('any', 'took'): 1,
#          ('any', "''"): 3,
#          ('irregularities', 'took'): 1,
#          ('irregularities', 'any'): 1,
#          ('irregularities', 'place'): 1,
#          ('irregularities', 'that'): 1,
#          ('took', 'place'): 4,
#          ('took', 'irregularities'): 1,
#          ('took', '.'): 4,
#          ('took', 'any'): 1,
#          ('further', 'said'): 3,
#          ('further', 'jury'): 1,
#          ('further', 'in'): 3,
#          ('further', 'The'): 1,
#          ('said', 'in'): 8,
#          ('said', 'further'): 3,
#          ('said', 'term-end'): 1,
#          ('said', 'jury'): 7,
#          ('in', 'term-end'): 1,
#          ('in', 'said'): 8,
#          ('in', 'presentments'): 1,
#          ('in', 'further'): 3,
#          ('term-end', 'presentments'): 1,
#          ('term-end', 'in'): 1,
#          ('term-end', 'that'): 1,
#          ('term-end', 'said'): 1,
#          ('presentments', 'that'): 1,
#          ('presentments', 'term-end'): 1,
#          ('presentments', 'the'): 1,
#          ('presentments', 'in'): 1,
#          ('that', 'the'): 222,
#          ('that', 'presentments'): 1,
#          ('that', 'City'): 1,
#          ('that', 'term-end'): 1,
#          ('the', 'City'): 10,
#          ('the', 'that'): 224,
#          ('the', 'Executive'): 4,
#          ('the', 'presentments'): 1,
#          ('City', 'Executive'): 1,
#          ('City', 'the'): 10,
#          ('City', 'Committee'): 1,
#          ('City', 'that'): 1,
#          ('Executive', 'Committee'): 2,
#          ('Executive', 'City'): 1,
#          ('Executive', ','): 2,
#          ('Executive', 'the'): 4,
#          ('Committee', ','): 7,
#          ('Committee', 'Executive'): 1,
#          ('Committee', 'which'): 1,
#          ('Committee', 'City'): 1,
#          (',', 'which'): 86,
#          (',', 'Committee'): 7,
#          (',', 'had'): 39,
#          (',', 'Executive'): 2,
#          ('which', 'had'): 11,
#          ('which', ','): 88,
#          ('which', 'over-all'): 1,
#          ('which', 'Committee'): 1,
#          ('had', 'over-all'): 1,
#          ('had', 'which'): 11,
#          ('had', 'charge'): 1,
#          ('had', ','): 40,
#          ('over-all', 'charge'): 1,
#          ('over-all', 'had'): 1,
#          ('over-all', 'of'): 2,
#          ('over-all', 'which'): 1,
#          ('charge', 'of'): 10,
#          ('charge', 'over-all'): 1,
#          ('charge', 'the'): 6,
#          ('charge', 'had'): 1,
#          ('of', 'the'): 1443,
#          ('of', 'charge'): 10,
#          ('of', 'election'): 6,
#          ('of', 'over-all'): 2,
#          ('the', 'election'): 15,
#          ('the', 'of'): 1460,
#          ('the', ','): 870,
#          ('the', 'charge'): 7,
#          ('election', ','): 8,
#          ('election', 'the'): 15,
#          ('election', 'of'): 6,
#          (',', '``'): 126,
#          (',', 'election'): 8,
#          (',', 'deserves'): 1,
#          (',', 'the'): 855,
#          ('``', 'deserves'): 1,
#          ('``', ','): 121,
#          ('``', 'the'): 78,
#          ('deserves', 'the'): 1,
#          ('deserves', '``'): 1,
#          ('deserves', 'praise'): 1,
#          ('deserves', ','): 1,
#          ('the', 'praise'): 1,
#          ('the', 'deserves'): 1,
#          ('the', 'and'): 353,
#          ('the', '``'): 82,
#          ('praise', 'and'): 1,
#          ('praise', 'the'): 1,
#          ('praise', 'thanks'): 1,
#          ('praise', 'deserves'): 1,
#          ('and', 'thanks'): 1,
#          ('and', 'praise'): 1,
#          ('and', 'of'): 163,
#          ('and', 'the'): 357,
#          ('thanks', 'of'): 1,
#          ('thanks', 'and'): 1,
#          ('thanks', 'the'): 1,
#          ('thanks', 'praise'): 1,
#          ('of', 'thanks'): 1,
#          ('of', 'City'): 8,
#          ('of', 'and'): 162,
#          ('the', 'thanks'): 1,
#          ('City', 'of'): 8,
#          ('City', 'Atlanta'): 1,
#          ('of', 'Atlanta'): 8,
#          ('of', "''"): 38,
#          ('Atlanta', "''"): 1,
#          ('Atlanta', 'of'): 6,
#          ('Atlanta', 'for'): 1,
#          ('Atlanta', 'City'): 1,
#          ("''", 'for'): 12,
#          ("''", 'Atlanta'): 1,
#          ("''", 'the'): 81,
#          ("''", 'of'): 26,
#          ('for', 'the'): 279,
#          ('for', "''"): 17,
#          ('for', 'manner'): 1,
#          ('for', 'Atlanta'): 1,
#          ('the', 'manner'): 3,
#          ('the', 'for'): 280,
#          ('the', 'in'): 663,
#          ('the', "''"): 107,
#          ('manner', 'in'): 4,
#          ('manner', 'the'): 3,
#          ('manner', 'which'): 2,
#          ('manner', 'for'): 1,
#          ('in', 'which'): 25,
#          ('in', 'manner'): 4,
#          ('in', 'the'): 659,
#          ('which', 'the'): 51,
#          ('which', 'in'): 25,
#          ('which', 'election'): 2,
#          ('which', 'manner'): 2,
#          ('the', 'which'): 51,
#          ('the', 'was'): 126,
#          ('election', 'was'): 2,
#          ('election', 'conducted'): 1,
#          ('election', 'which'): 2,
#          ('was', 'conducted'): 1,
#          ('was', 'election'): 2,
#          ('was', '.'): 27,
#          ('was', 'the'): 116,
#          ('term', 'jury'): 1,
#          ('term', 'September-October'): 1,
#          ('term', 'had'): 1,
#          ('term', 'The'): 1,
#          ('jury', 'had'): 1,
#          ('jury', 'term'): 1,
#          ('jury', 'been'): 1,
#          ('jury', 'September-October'): 1,
#          ('had', 'been'): 47,
#          ('had', 'jury'): 1,
#          ('had', 'charged'): 1,
#          ('had', 'term'): 1,
#          ('been', 'charged'): 1,
#          ('been', 'had'): 52,
#          ('been', 'by'): 13,
#          ('been', 'jury'): 1,
#          ('charged', 'by'): 1,
#          ('charged', 'been'): 1,
#          ('charged', 'Fulton'): 1,
#          ('charged', 'had'): 2,
#          ('by', 'Fulton'): 1,
#          ('by', 'charged'): 1,
#          ('by', 'Superior'): 1,
#          ('by', 'been'): 13,
#          ('Fulton', 'Superior'): 2,
#          ('Fulton', 'by'): 1,
#          ('Fulton', 'Court'): 2,
#          ('Fulton', 'charged'): 1,
#          ('Superior', 'Court'): 5,
#          ('Superior', 'Fulton'): 2,
#          ('Superior', 'Judge'): 1,
#          ('Superior', 'by'): 1,
#          ('Court', 'Judge'): 1,
#          ('Court', 'Superior'): 5,
#          ('Court', 'Durwood'): 1,
#          ('Court', 'Fulton'): 2,
#          ('Judge', 'Durwood'): 1,
#          ('Judge', 'Court'): 1,
#          ('Judge', 'Pye'): 1,
#          ('Judge', 'Superior'): 1,
#          ('Durwood', 'Pye'): 1,
#          ('Durwood', 'Judge'): 1,
#          ('Durwood', 'to'): 1,
#          ('Durwood', 'Court'): 1,
#          ('Pye', 'to'): 1,
#          ('Pye', 'Durwood'): 1,
#          ('Pye', 'investigate'): 1,
#          ('Pye', 'Judge'): 1,
#          ('to', 'investigate'): 3,
#          ('to', 'Pye'): 1,
#          ('to', 'reports'): 1,
#          ('to', 'Durwood'): 1,
#          ('investigate', 'reports'): 1,
#          ('investigate', 'to'): 2,
#          ('investigate', 'of'): 1,
#          ('investigate', 'Pye'): 1,
#          ('reports', 'of'): 5,
#          ('reports', 'investigate'): 1,
#          ('reports', 'possible'): 1,
#          ('reports', 'to'): 1,
#          ('of', 'possible'): 4,
#          ('of', 'reports'): 5,
#          ('of', '``'): 45,
#          ('of', 'investigate'): 1,
#          ('possible', '``'): 1,
#          ('possible', 'of'): 4,
#          ('possible', 'irregularities'): 1,
#          ('possible', 'reports'): 1,
#          ('``', 'irregularities'): 1,
#          ('``', 'possible'): 1,
#          ('``', "''"): 100,
#          ('``', 'of'): 42,
#          ('irregularities', "''"): 1,
#          ('irregularities', '``'): 1,
#          ('irregularities', 'in'): 1,
#          ('irregularities', 'possible'): 1,
#          ("''", 'in'): 15,
#          ("''", 'irregularities'): 1,
#          ("''", '``'): 100,
#          ('in', "''"): 24,
#          ('in', 'hard-fought'): 1,
#          ('in', 'irregularities'): 1,
#          ('the', 'hard-fought'): 1,
#          ('the', 'primary'): 8,
#          ('hard-fought', 'primary'): 1,
#          ('hard-fought', 'the'): 1,
#          ('hard-fought', 'which'): 1,
#          ('hard-fought', 'in'): 1,
#          ('primary', 'which'): 2,
#          ('primary', 'hard-fought'): 1,
#          ('primary', 'was'): 1,
#          ('primary', 'the'): 7,
#          ('which', 'was'): 9,
#          ('which', 'primary'): 2,
#          ('which', 'won'): 2,
#          ('which', 'hard-fought'): 1,
#          ('was', 'won'): 2,
#          ('was', 'which'): 9,
#          ('was', 'by'): 33,
#          ('was', 'primary'): 1,
#          ('won', 'by'): 3,
#          ('won', 'was'): 2,
#          ('won', 'Mayor-nominate'): 1,
#          ('won', 'which'): 2,
#          ('by', 'Mayor-nominate'): 1,
#          ('by', 'won'): 3,
#          ('by', 'Ivan'): 2,
#          ('by', 'was'): 36,
#          ('Mayor-nominate', 'Ivan'): 1,
#          ('Mayor-nominate', 'by'): 1,
#          ('Mayor-nominate', 'Allen'): 1,
#          ('Mayor-nominate', 'won'): 1,
#          ('Ivan', 'Allen'): 2,
#          ('Ivan', 'Mayor-nominate'): 1,
#          ('Ivan', 'Jr.'): 2,
#          ('Ivan', 'by'): 2,
#          ('Allen', 'Jr.'): 2,
#          ('Allen', 'Ivan'): 2,
#          ('Allen', '.'): 1,
#          ('Allen', 'Mayor-nominate'): 1,
#          ('a', 'relative'): 1,
#          ('a', 'Only'): 1,
#          ('a', 'handful'): 1,
#          ('a', '``'): 47,
#          ('relative', 'handful'): 1,
#          ('relative', 'a'): 1,
#          ('relative', 'of'): 3,
#          ('relative', 'Only'): 1,
#          ('handful', 'of'): 1,
#          ('handful', 'relative'): 1,
#          ('handful', 'such'): 1,
#          ('handful', 'a'): 1,
#          ('of', 'such'): 8,
#          ('of', 'handful'): 1,
#          ('of', 'relative'): 3,
#          ('such', 'reports'): 1,
#          ('such', 'of'): 8,
#          ('such', 'was'): 2,
#          ('such', 'handful'): 1,
#          ('reports', 'was'): 1,
#          ('reports', 'such'): 1,
#          ('reports', 'received'): 1,
#          ('was', 'received'): 1,
#          ('was', 'reports'): 1,
#          ('was', "''"): 6,
#          ('was', 'such'): 2,
#          ('received', "''"): 1,
#          ('received', 'was'): 1,
#          ('received', ','): 6,
#          ('received', 'reports'): 1,
#          ("''", ','): 207,
#          ("''", 'received'): 1,
#          ("''", 'was'): 5,
#          (',', "''"): 209,
#          (',', 'jury'): 16,
#          (',', 'received'): 5,
#          ('the', 'jury'): 27,
#          ('the', 'said'): 80,
#          ('jury', 'said'): 5,
#          ('jury', 'the'): 22,
#          ('jury', ','): 15,
#          ('said', ','): 193,
#          ('said', '``'): 37,
#          ('said', 'the'): 52,
#          (',', 'said'): 250,
#          (',', 'considering'): 1,
#          ('``', 'considering'): 1,
#          ('``', 'said'): 44,
#          ('considering', 'the'): 1,
#          ('considering', '``'): 1,
#          ('considering', 'widespread'): 1,
#          ('considering', ','): 1,
#          ('the', 'widespread'): 1,
#          ('the', 'considering'): 1,
#          ('the', 'interest'): 12,
#          ('widespread', 'interest'): 1,
#          ('widespread', 'the'): 1,
#          ('widespread', 'in'): 2,
#          ('widespread', 'considering'): 1,
#          ('interest', 'in'): 11,
#          ('interest', 'widespread'): 1,
#          ('interest', 'the'): 11,
#          ('in', 'interest'): 11,
#          ('in', 'election'): 6,
#          ('in', 'widespread'): 2,
#          ('election', 'in'): 6,
#          (',', 'number'): 1,
#          ('the', 'number'): 9,
#          ('number', 'of'): 28,
#          ('number', 'the'): 8,
#          ('number', 'voters'): 1,
#          ('number', ','): 1,
#          ('of', 'voters'): 3,
#          ('of', 'number'): 29,
#          ('voters', 'and'): 1,
#          ('voters', 'of'): 2,
#          ('voters', 'the'): 4,
#          ('voters', 'number'): 1,
#          ('and', 'voters'): 1,
#          ('and', 'size'): 5,
#          ('the', 'size'): 5,
#          ('the', 'voters'): 6,
#          ('size', 'of'): 5,
#          ('size', 'the'): 5,
#          ('size', 'this'): 1,
#          ('size', 'and'): 5,
#          ('of', 'this'): 33,
#          ('of', 'size'): 5,
#          ('of', 'city'): 10,
#          ('this', 'city'): 3,
#          ('this', 'of'): 33,
#          ('this', "''"): 20,
#          ('this', 'size'): 1,
#          ('city', "''"): 1,
#          ('city', 'this'): 1,
#          ('city', '.'): 3,
#          ('city', 'of'): 9,
#          ('said', 'it'): 15,
#          ('said', 'did'): 3,
#          ('said', 'The'): 17,
#          ('it', 'did'): 3,
#          ('it', 'said'): 16,
#          ('it', 'find'): 5,
#          ('it', 'jury'): 3,
#          ('did', 'find'): 1,
#          ('did', 'it'): 3,
#          ('did', 'that'): 3,
#          ('did', 'said'): 3,
#          ('find', 'that'): 3,
#          ('find', 'did'): 1,
#          ('find', 'many'): 1,
#          ('find', 'it'): 5,
#          ('that', 'many'): 7,
#          ('that', 'find'): 3,
#          ('that', 'of'): 45,
#          ('that', 'did'): 3,
#          ('many', 'of'): 18,
#          ('many', 'that'): 6,
#          ('many', "Georgia's"): 1,
#          ('many', 'find'): 1,
#          ('of', "Georgia's"): 4,
#          ('of', 'many'): 18,
#          ('of', 'registration'): 1,
#          ('of', 'that'): 45,
#          ("Georgia's", 'registration'): 1,
#          ("Georgia's", 'of'): 4,
#          ("Georgia's", 'and'): 1,
#          ("Georgia's", 'many'): 1,
#          ('registration', 'and'): 1,
#          ('registration', "Georgia's"): 1,
#          ('registration', 'election'): 1,
#          ('registration', 'of'): 1,
#          ('and', 'election'): 3,
#          ('and', 'registration'): 1,
#          ('and', 'laws'): 2,
#          ('and', "Georgia's"): 1,
#          ('election', 'laws'): 1,
#          ('election', 'and'): 3,
#          ('election', 'registration'): 1,
#          ('laws', '``'): 1,
#          ('laws', 'election'): 1,
#          ('laws', 'are'): 3,
#          ('laws', 'and'): 2,
#          ('``', 'are'): 12,
#          ('``', 'laws'): 1,
#          ('``', 'outmoded'): 1,
#          ('are', 'outmoded'): 1,
#          ('are', '``'): 16,
#          ('are', 'or'): 2,
#          ('are', 'laws'): 3,
#          ('outmoded', 'or'): 1,
#          ('outmoded', 'are'): 1,
#          ('outmoded', 'inadequate'): 1,
#          ('outmoded', '``'): 1,
#          ('or', 'inadequate'): 1,
#          ('or', 'outmoded'): 1,
#          ('or', 'and'): 3,
#          ('or', 'are'): 2,
#          ('inadequate', 'and'): 1,
#          ('inadequate', 'or'): 1,
#          ('inadequate', 'often'): 1,
#          ('inadequate', 'outmoded'): 1,
#          ('and', 'often'): 3,
#          ('and', 'inadequate'): 1,
#          ('and', 'ambiguous'): 1,
#          ('and', 'or'): 3,
#          ('often', 'ambiguous'): 1,
#          ('often', 'and'): 3,
#          ('often', "''"): 1,
#          ('often', 'inadequate'): 1,
#          ('ambiguous', "''"): 1,
#          ('ambiguous', 'often'): 1,
#          ('ambiguous', '.'): 1,
#          ('ambiguous', 'and'): 1,
#          ('that', 'Fulton'): 1,
#          ('that', 'recommended'): 5,
#          ('that', 'legislators'): 2,
#          ('that', 'It'): 8,
#          ('Fulton', 'legislators'): 1,
#          ('Fulton', 'that'): 1,
#          ('Fulton', 'act'): 1,
#          ('Fulton', 'recommended'): 1,
#          ('legislators', 'act'): 1,
#          ('legislators', 'Fulton'): 1,
#          ('legislators', '``'): 1,
#          ('legislators', 'that'): 2,
#          ('act', '``'): 2,
#          ('act', 'legislators'): 1,
#          ('act', 'to'): 7,
#          ('act', 'Fulton'): 1,
#          ('``', 'to'): 29,
#          ('``', 'act'): 2,
#          ('``', 'have'): 6,
#          ('``', 'legislators'): 2,
#          ('to', 'have'): 54,
#          ('to', '``'): 30,
#          ('to', 'these'): 7,
#          ('to', 'act'): 7,
#          ('have', 'these'): 4,
#          ('have', 'to'): 54,
#          ('have', 'laws'): 1,
#          ('have', '``'): 11,
#          ('these', 'laws'): 2,
#          ('these', 'have'): 4,
#          ('these', 'studied'): 1,
#          ('these', 'to'): 7,
#          ('laws', 'studied'): 1,
#          ('laws', 'these'): 2,
#          ('laws', 'have'): 1,
#          ('studied', 'and'): 1,
#          ('studied', 'laws'): 1,
#          ('studied', 'revised'): 1,
#          ('studied', 'these'): 1,
#          ('and', 'revised'): 1,
#          ('and', 'studied'): 1,
#          ('and', 'to'): 90,
#          ('revised', 'to'): 1,
#          ('revised', 'and'): 1,
#          ('revised', 'the'): 1,
#          ('revised', 'studied'): 1,
#          ('to', 'the'): 590,
#          ('to', 'revised'): 1,
#          ('to', 'end'): 11,
#          ('to', 'and'): 89,
#          ('the', 'end'): 22,
#          ('the', 'to'): 594,
#          ('the', 'revised'): 1,
#          ('end', 'of'): 10,
#          ('end', 'the'): 22,
#          ('end', 'modernizing'): 1,
#          ('end', 'to'): 11,
#          ('of', 'modernizing'): 1,
#          ('of', 'end'): 10,
#          ('modernizing', 'and'): 1,
#          ('modernizing', 'of'): 1,
#          ('modernizing', 'improving'): 1,
#          ('modernizing', 'end'): 1,
#          ('and', 'improving'): 1,
#          ('and', 'modernizing'): 1,
#          ('and', 'them'): 8,
#          ('improving', 'them'): 1,
#          ('improving', 'and'): 1,
#          ('improving', "''"): 1,
#          ('improving', 'modernizing'): 1,
#          ('them', "''"): 7,
#          ('them', 'improving'): 1,
#          ('them', '.'): 8,
#          ('them', 'and'): 8,
#          ('jury', 'commented'): 1,
#          ('jury', 'grand'): 5,
#          ('jury', 'on'): 1,
#          ('jury', 'The'): 2,
#          ('commented', 'on'): 2,
#          ('commented', 'jury'): 2,
#          ('commented', 'a'): 1,
#          ('commented', 'grand'): 1,
#          ('on', 'a'): 71,
#          ('on', 'commented'): 2,
#          ('on', 'number'): 1,
#          ('on', 'jury'): 3,
#          ('a', 'number'): 19,
#          ('a', 'on'): 73,
#          ('a', 'of'): 346,
#          ('a', 'commented'): 1,
#          ('number', 'a'): 20,
#          ('number', 'other'): 4,
#          ('number', 'on'): 1,
#          ('of', 'other'): 24,
#          ('of', 'topics'): 1,
#          ('of', 'a'): 351,
#          ('other', 'topics'): 1,
#          ('other', 'of'): 24,
#          ('other', ','): 21,
#          ('other', 'number'): 4,
#          ('topics', ','): 1,
#          ('topics', 'other'): 1,
#          ('topics', 'among'): 1,
#          ('topics', 'of'): 1,
#          (',', 'among'): 7,
#          (',', 'topics'): 1,
#          (',', 'them'): 12,
#          (',', 'other'): 28,
#          ('among', 'them'): 2,
#          ('among', ','): 7,
#          ('among', 'the'): 12,
#          ('among', 'topics'): 1,
#          ('them', 'the'): 10,
#          ('them', 'among'): 2,
#          ('them', 'Atlanta'): 1,
#          ('them', ','): 12,
#          ('the', 'Atlanta'): 5,
#          ('the', 'them'): 11,
#          ('the', 'among'): 12,
#          ('Atlanta', 'and'): 3,
#          ('Atlanta', 'the'): 5,
#          ('Atlanta', 'Fulton'): 1,
#          ('Atlanta', 'them'): 1,
#          ('and', 'Fulton'): 2,
#          ('and', 'Atlanta'): 3,
#          ('and', 'County'): 4,
#          ('Fulton', 'County'): 5,
#          ('Fulton', 'and'): 2,
#          ('Fulton', 'purchasing'): 1,
#          ('Fulton', 'Atlanta'): 1,
#          ('County', 'purchasing'): 1,
#          ('County', 'departments'): 1,
#          ('County', 'and'): 4,
#          ('purchasing', 'departments'): 1,
#          ('purchasing', 'County'): 1,
#          ('purchasing', 'which'): 1,
#          ('purchasing', 'Fulton'): 1,
#          ('departments', 'which'): 1,
#          ('departments', 'purchasing'): 1,
#          ('departments', 'it'): 1,
#          ('departments', 'County'): 1,
#          ('which', 'it'): 6,
#          ('which', 'departments'): 1,
#          ('which', 'said'): 5,
#          ('which', 'purchasing'): 1,
#          ('it', 'which'): 5,
#          ('it', '``'): 11,
#          ('it', 'departments'): 1,
#          ('said', 'are'): 3,
#          ('said', 'which'): 5,
#          ('``', 'well'): 1,
#          ('``', 'it'): 10,
#          ('are', 'well'): 2,
#          ('are', 'operated'): 1,
#          ('are', 'said'): 3,
#          ('well', 'operated'): 1,
#          ('well', 'are'): 2,
#          ('well', 'and'): 2,
#          ('well', '``'): 1,
#          ('operated', 'and'): 2,
#          ('operated', 'well'): 1,
#          ('operated', 'follow'): 1,
#          ('operated', 'are'): 1,
#          ('and', 'follow'): 1,
#          ('and', 'operated'): 2,
#          ('and', 'generally'): 2,
#          ('and', 'well'): 2,
#          ('follow', 'generally'): 1,
#          ('follow', 'and'): 1,
#          ('follow', 'accepted'): 1,
#          ('follow', 'operated'): 1,
#          ('generally', 'accepted'): 1,
#          ('generally', 'follow'): 1,
#          ('generally', 'practices'): 1,
#          ('generally', 'and'): 2,
#          ('accepted', 'practices'): 1,
#          ('accepted', 'generally'): 1,
#          ('accepted', 'which'): 1,
#          ('accepted', 'follow'): 1,
#          ('practices', 'which'): 1,
#          ('practices', 'accepted'): 1,
#          ('practices', 'inure'): 1,
#          ('practices', 'generally'): 1,
#          ('which', 'inure'): 1,
#          ('which', 'practices'): 1,
#          ('which', 'to'): 13,
#          ('which', 'accepted'): 1,
#          ('inure', 'to'): 1,
#          ('inure', 'which'): 1,
#          ('inure', 'the'): 1,
#          ('inure', 'practices'): 1,
#          ('to', 'inure'): 1,
#          ('to', 'best'): 1,
#          ('to', 'which'): 13,
#          ('the', 'best'): 18,
#          ('the', 'inure'): 1,
#          ('best', 'interest'): 1,
#          ('best', 'the'): 16,
#          ('best', 'of'): 4,
#          ('best', 'to'): 1,
#          ('interest', 'of'): 8,
#          ('interest', 'best'): 1,
#          ('interest', 'both'): 1,
#          ('of', 'both'): 13,
#          ('of', 'interest'): 9,
#          ('of', 'governments'): 2,
#          ('of', 'best'): 4,
#          ('both', 'governments'): 1,
#          ('both', 'of'): 13,
#          ('both', "''"): 2,
#          ('both', 'interest'): 1,
#          ('governments', "''"): 1,
#          ('governments', 'both'): 1,
#          ('governments', '.'): 1,
#          ('governments', 'of'): 2,
#          ('the', 'However'): 3,
#          ('jury', 'it'): 1,
#          ('said', 'believes'): 1,
#          ('it', 'believes'): 2,
#          ('believes', '``'): 2,
#          ('believes', 'it'): 2,
#          ('believes', 'these'): 1,
#          ('believes', 'said'): 1,
#          ('``', 'these'): 3,
#          ('``', 'believes'): 2,
#          ('``', 'two'): 4,
#          ('these', 'two'): 3,
#          ('these', '``'): 4,
#          ('these', 'offices'): 1,
#          ('these', 'believes'): 1,
#          ('two', 'offices'): 1,
#          ('two', 'these'): 3,
#          ('two', 'should'): 1,
#          ('two', '``'): 4,
#          ('offices', 'should'): 1,
#          ('offices', 'two'): 1,
#          ('offices', 'be'): 1,
#          ('offices', 'these'): 1,
#          ('should', 'be'): 30,
#          ('should', 'offices'): 1,
#          ('should', 'combined'): 1,
#          ('should', 'two'): 1,
#          ('be', 'combined'): 1,
#          ('be', 'should'): 32,
#          ('be', 'to'): 167,
#          ('be', 'offices'): 1,
#          ('combined', 'to'): 3,
#          ('combined', 'be'): 1,
#          ('combined', 'achieve'): 1,
#          ('combined', 'should'): 1,
#          ('to', 'achieve'): 6,
#          ('to', 'combined'): 3,
#          ('to', 'greater'): 4,
#          ('to', 'be'): 167,
#          ('achieve', 'greater'): 1,
#          ('achieve', 'to'): 6,
#          ('achieve', 'efficiency'): 1,
#          ('achieve', 'combined'): 1,
#          ('greater', 'efficiency'): 1,
#          ('greater', 'achieve'): 1,
#          ('greater', 'and'): 2,
#          ('greater', 'to'): 4,
#          ('efficiency', 'and'): 1,
#          ('efficiency', 'greater'): 1,
#          ('efficiency', 'reduce'): 1,
#          ('efficiency', 'achieve'): 1,
#          ('and', 'reduce'): 1,
#          ('and', 'efficiency'): 1,
#          ('and', 'greater'): 2,
#          ('reduce', 'the'): 4,
#          ('reduce', 'and'): 1,
#          ('reduce', 'cost'): 1,
#          ('reduce', 'efficiency'): 1,
#          ('the', 'cost'): 5,
#          ('the', 'reduce'): 4,
#          ('cost', 'of'): 7,
#          ('cost', 'the'): 5,
#          ('cost', 'administration'): 1,
#          ('cost', 'reduce'): 1,
#          ('of', 'administration'): 6,
#          ('of', 'cost'): 8,
#          ('administration', "''"): 1,
#          ('administration', 'of'): 5,
#          ('administration', '.'): 2,
#          ('administration', 'cost'): 1,
#          ('Purchasing', 'Department'): 1,
#          ('Purchasing', 'City'): 1,
#          ('Purchasing', ','): 1,
#          ('Purchasing', 'The'): 1,
#          ('Department', ','): 3,
#          ('Department', 'Purchasing'): 1,
#          ('Department', 'the'): 8,
#          ('Department', 'City'): 1,
#          (',', 'Department'): 3,
#          (',', 'Purchasing'): 1,
#          ('the', 'Department'): 8,
#          (',', 'is'): 116,
#          ('``', 'is'): 22,
#          ('``', 'lacking'): 1,
#          ('is', 'lacking'): 1,
#          ('is', '``'): 40,
#          ('is', 'in'): 34,
#          ('is', ','): 118,
#          ('lacking', 'in'): 2,
#          ('lacking', 'is'): 1,
#          ('lacking', 'experienced'): 1,
#          ('lacking', '``'): 1,
#          ('in', 'experienced'): 1,
#          ('in', 'lacking'): 2,
#          ('in', 'clerical'): 1,
#          ('in', 'is'): 37,
#          ('experienced', 'clerical'): 1,
#          ('experienced', 'in'): 1,
#          ('experienced', 'personnel'): 1,
#          ('experienced', 'lacking'): 1,
#          ('clerical', 'personnel'): 1,
#          ('clerical', 'experienced'): 1,
#          ('clerical', 'as'): 2,
#          ('clerical', 'in'): 1,
#          ('personnel', 'as'): 1,
#          ('personnel', 'clerical'): 1,
#          ('personnel', 'a'): 1,
#          ('personnel', 'experienced'): 1,
#          ('as', 'a'): 89,
#          ('as', 'personnel'): 1,
#          ('as', 'result'): 14,
#          ('as', 'clerical'): 2,
#          ('a', 'result'): 16,
#          ('a', 'as'): 89,
#          ('a', 'personnel'): 1,
#          ('result', 'of'): 17,
#          ('result', 'a'): 21,
#          ('result', 'city'): 1,
#          ('result', 'as'): 14,
#          ('of', 'result'): 17,
#          ('of', 'personnel'): 2,
#          ('city', 'personnel'): 1,
#          ('city', 'policies'): 1,
#          ('city', 'result'): 1,
#          ('personnel', 'policies'): 2,
#          ('personnel', 'city'): 1,
#          ('personnel', "''"): 1,
#          ('personnel', 'of'): 2,
#          ('policies', "''"): 1,
#          ('policies', 'personnel'): 2,
#          ('policies', '.'): 2,
#          ('policies', 'city'): 1,
#          ('that', 'urged'): 4,
#          ('that', 'city'): 3,
#          ('the', 'city'): 29,
#          ('the', 'urged'): 5,
#          ('city', '``'): 2,
#          ('city', 'the'): 26,
#          ('city', 'take'): 1,
#          ('city', 'that'): 3,
#          ('``', 'take'): 5,
#          ('``', 'city'): 2,
#          ('``', 'steps'): 1,
#          ('take', 'steps'): 2,
#          ('take', '``'): 7,
#          ('take', 'to'): 24,
#          ('take', 'city'): 1,
#          ('steps', 'to'): 4,
#          ('steps', 'take'): 2,
#          ('steps', 'remedy'): 1,
#          ('steps', '``'): 1,
#          ('to', 'remedy'): 1,
#          ('to', 'steps'): 4,
#          ('to', "''"): 34,
#          ('to', 'take'): 24,
#          ('remedy', "''"): 1,
#          ('remedy', 'to'): 1,
#          ('remedy', 'this'): 1,
#          ('remedy', 'steps'): 1,
#          ("''", 'this'): 13,
#          ("''", 'remedy'): 1,
#          ("''", 'problem'): 1,
#          ("''", 'to'): 22,
#          ('this', 'problem'): 3,
#          ('this', '.'): 38,
#          ('this', 'remedy'): 1,
#          ("Georgia's", 'automobile'): 1,
#          ("Georgia's", 'title'): 1,
#          ("Georgia's", 'Implementation'): 1,
#          ('automobile', 'title'): 1,
#          ('automobile', "Georgia's"): 1,
#          ('automobile', 'law'): 1,
#          ('automobile', 'of'): 1,
#          ('title', 'law'): 1,
#          ('title', 'automobile'): 1,
#          ('title', 'was'): 2,
#          ('title', "Georgia's"): 1,
#          ('law', 'was'): 2,
#          ('law', 'title'): 1,
#          ('law', 'also'): 1,
#          ('law', 'automobile'): 1,
#          ('was', 'also'): 11,
#          ('was', 'law'): 2,
#          ('was', 'recommended'): 1,
#          ('was', 'title'): 2,
#          ('also', 'recommended'): 2,
#          ('also', 'was'): 12,
#          ('also', 'by'): 1,
#          ('also', 'law'): 1,
#          ('recommended', 'by'): 1,
#          ('recommended', 'also'): 2,
#          ('recommended', 'the'): 4,
#          ('recommended', 'was'): 1,
#          ('by', 'the'): 137,
#          ('by', 'recommended'): 1,
#          ('by', 'outgoing'): 1,
#          ('by', 'also'): 1,
#          ('the', 'outgoing'): 2,
#          ('the', 'by'): 139,
#          ('the', 'recommended'): 4,
#          ('outgoing', 'jury'): 1,
#          ('outgoing', 'the'): 2,
#          ('outgoing', '.'): 1,
#          ('outgoing', 'by'): 1,
#          ('that', 'next'): 2,
#          ('the', 'next'): 17,
#          ('the', 'Legislature'): 19,
#          ('next', 'Legislature'): 1,
#          ('next', 'the'): 17,
#          ('next', '``'): 1,
#          ('next', 'that'): 2,
#          ('Legislature', '``'): 1,
#          ('Legislature', 'next'): 1,
#          ('Legislature', 'provide'): 1,
#          ('Legislature', 'the'): 16,
#          ('``', 'provide'): 2,
#          ('``', 'Legislature'): 1,
#          ('``', 'enabling'): 1,
#          ('``', 'next'): 1,
#          ('provide', 'enabling'): 1,
#          ('provide', '``'): 2,
#          ('provide', 'funds'): 1,
#          ('provide', 'Legislature'): 1,
#          ('enabling', 'funds'): 1,
#          ('enabling', 'provide'): 1,
#          ('enabling', 'and'): 1,
#          ('enabling', '``'): 1,
#          ('funds', 'and'): 3,
#          ('funds', 'enabling'): 1,
#          ('funds', 're-set'): 1,
#          ('funds', 'provide'): 1,
#          ('and', 're-set'): 1,
#          ('and', 'funds'): 4,
#          ('and', 'enabling'): 1,
#          ('re-set', 'the'): 1,
#          ('re-set', 'and'): 1,
#          ('re-set', 'effective'): 1,
#          ('re-set', 'funds'): 1,
#          ('the', 'effective'): 2,
#          ('the', 're-set'): 1,
#          ('the', 'date'): 5,
#          ('effective', 'date'): 1,
#          ('effective', 'the'): 2,
#          ('effective', 'so'): 1,
#          ('effective', 're-set'): 1,
#          ('date', 'so'): 1,
#          ('date', 'effective'): 1,
#          ('date', 'that'): 4,
#          ('date', 'the'): 5,
#          ('so', 'that'): 13,
#          ('so', 'date'): 1,
#          ('so', 'an'): 1,
#          ('so', 'effective'): 1,
#          ('that', 'an'): 9,
#          ('that', 'so'): 13,
#          ('that', 'orderly'): 1,
#          ('that', 'date'): 3,
#          ('an', 'orderly'): 2,
#          ('an', 'that'): 9,
#          ('an', 'implementation'): 1,
#          ('an', 'so'): 1,
#          ('orderly', 'implementation'): 1,
#          ('orderly', 'an'): 2,
#          ('orderly', 'of'): 1,
#          ('orderly', 'that'): 1,
#          ...})

# %% [markdown]
# ### Weighting function
#
# GloVe includes a weighting function to scale down too frequent words.
#
# <img src = "../figures/glove_weighting_func.png" width=400>

# %%
def weighting(w_i, w_j, X_ik):
    
    #check whether the co-occurences between w_i and w_j is available
    try:
        x_ij = X_ik[(w_i, w_j)]
        #if not exist, then set to 1 "laplace smoothing"
    except:
        x_ij = 1
        
    #set xmax
    x_max = 100
    #set alpha
    alpha = 0.75
    
    #if co-ocurrence does not exceeed xmax, then just multiply with some alpha
    if x_ij < x_max:
        result = (x_ij / x_max)**alpha
    #otherwise, set to 1
    else:
        result = 1
    
    return result

# %%
from itertools import combinations_with_replacement

X_ik = {} #keeping the co-occurences
weighting_dic = {} #already scale the co-occurences using the weighting function

for bigram in combinations_with_replacement(vocab, 2):
    if X_ik_skipgrams.get(bigram):  #if the pair exists in our corpus
        co = X_ik_skipgrams[bigram]
        X_ik[bigram] = co + 1 #for stability
        X_ik[(bigram[1], bigram[0])] = co + 1 #basically apple, banana = banana, apple
    else:
        pass
    
    weighting_dic[bigram] = weighting(bigram[0], bigram[1], X_ik)
    weighting_dic[(bigram[1], bigram[0])] = weighting(bigram[1], bigram[0], X_ik)

# %% [markdown]
# ## 3. Prepare train data

# %%
import math

def random_batch(batch_size, word_sequence, skip_grams_id, X_ik, weighting_dic):
    
    random_inputs, random_labels, random_coocs, random_weightings = [], [], [], []
    
    #randomly choose indexes based on batch size
    random_index = np.random.choice(range(len(skip_grams_id)), batch_size, replace=False)
    
    #get the random input and labels
    for index in random_index:
        random_inputs.append([skip_grams_id[index][0]])
        random_labels.append([skip_grams_id[index][1]])
        #coocs
        pair = skip_grams[index] #e.g., ('banana', 'fruit')
        try:
            cooc = X_ik[pair]
        except:
            cooc = 1
        random_coocs.append([math.log(cooc)])
    
        #weightings
        weighting = weighting_dic[pair]
        random_weightings.append([weighting])
        
    return np.array(random_inputs), np.array(random_labels), np.array(random_coocs), np.array(random_weightings)

# %% [markdown]
# ### Testing the method

# %%
weighting_dic
# Out:
# {('chien', 'chien'): 0.03162277660168379,
#  ('chien', "conference's"): 0.03162277660168379,
#  ("conference's", 'chien'): 0.03162277660168379,
#  ('chien', 'Well-wishers'): 0.03162277660168379,
#  ('Well-wishers', 'chien'): 0.03162277660168379,
#  ('chien', 'While'): 0.03162277660168379,
#  ('While', 'chien'): 0.03162277660168379,
#  ('chien', 'patrons'): 0.03162277660168379,
#  ('patrons', 'chien'): 0.03162277660168379,
#  ('chien', 'Navigation'): 0.03162277660168379,
#  ('Navigation', 'chien'): 0.03162277660168379,
#  ('chien', 'motels'): 0.03162277660168379,
#  ('motels', 'chien'): 0.03162277660168379,
#  ('chien', 'testing'): 0.03162277660168379,
#  ('testing', 'chien'): 0.03162277660168379,
#  ('chien', 'petty'): 0.03162277660168379,
#  ('petty', 'chien'): 0.03162277660168379,
#  ('chien', '$90'): 0.03162277660168379,
#  ('$90', 'chien'): 0.03162277660168379,
#  ('chien', 'Given'): 0.03162277660168379,
#  ('Given', 'chien'): 0.03162277660168379,
#  ('chien', 'Sanger-Harris'): 0.03162277660168379,
#  ('Sanger-Harris', 'chien'): 0.03162277660168379,
#  ('chien', 'scoreless'): 0.03162277660168379,
#  ('scoreless', 'chien'): 0.03162277660168379,
#  ('chien', 'Outside'): 0.03162277660168379,
#  ('Outside', 'chien'): 0.03162277660168379,
#  ('chien', 'Atty.'): 0.03162277660168379,
#  ('Atty.', 'chien'): 0.03162277660168379,
#  ('chien', 'spongy'): 0.03162277660168379,
#  ('spongy', 'chien'): 0.03162277660168379,
#  ('chien', 'Are'): 0.03162277660168379,
#  ('Are', 'chien'): 0.03162277660168379,
#  ('chien', 'negotiations'): 0.03162277660168379,
#  ('negotiations', 'chien'): 0.03162277660168379,
#  ('chien', 'Hord'): 0.03162277660168379,
#  ('Hord', 'chien'): 0.03162277660168379,
#  ('chien', 'washed-out'): 0.03162277660168379,
#  ('washed-out', 'chien'): 0.03162277660168379,
#  ('chien', 'courtroom'): 0.03162277660168379,
#  ('courtroom', 'chien'): 0.03162277660168379,
#  ('chien', 'contrasting'): 0.03162277660168379,
#  ('contrasting', 'chien'): 0.03162277660168379,
#  ('chien', 'Gotham'): 0.03162277660168379,
#  ('Gotham', 'chien'): 0.03162277660168379,
#  ('chien', 'Charitable'): 0.03162277660168379,
#  ('Charitable', 'chien'): 0.03162277660168379,
#  ('chien', 'Antone'): 0.03162277660168379,
#  ('Antone', 'chien'): 0.03162277660168379,
#  ('chien', 'meter'): 0.03162277660168379,
#  ('meter', 'chien'): 0.03162277660168379,
#  ('chien', 'maker'): 0.03162277660168379,
#  ('maker', 'chien'): 0.03162277660168379,
#  ('chien', 'SMU'): 0.03162277660168379,
#  ('SMU', 'chien'): 0.03162277660168379,
#  ('chien', 'book-selection'): 0.03162277660168379,
#  ('book-selection', 'chien'): 0.03162277660168379,
#  ('chien', 'instructed'): 0.03162277660168379,
#  ('instructed', 'chien'): 0.03162277660168379,
#  ('chien', 'Seidel'): 0.03162277660168379,
#  ('Seidel', 'chien'): 0.03162277660168379,
#  ('chien', 'ball-hawking'): 0.03162277660168379,
#  ('ball-hawking', 'chien'): 0.03162277660168379,
#  ('chien', 'fearing'): 0.03162277660168379,
#  ('fearing', 'chien'): 0.03162277660168379,
#  ('chien', '108'): 0.03162277660168379,
#  ('108', 'chien'): 0.03162277660168379,
#  ('chien', 'picking'): 0.03162277660168379,
#  ('picking', 'chien'): 0.03162277660168379,
#  ('chien', 'U-2'): 0.03162277660168379,
#  ('U-2', 'chien'): 0.03162277660168379,
#  ('chien', 'self-sacrifice'): 0.03162277660168379,
#  ('self-sacrifice', 'chien'): 0.03162277660168379,
#  ('chien', "'52"): 0.03162277660168379,
#  ("'52", 'chien'): 0.03162277660168379,
#  ('chien', 'alternatives'): 0.03162277660168379,
#  ('alternatives', 'chien'): 0.03162277660168379,
#  ('chien', "isn't"): 0.03162277660168379,
#  ("isn't", 'chien'): 0.03162277660168379,
#  ('chien', 'queen'): 0.03162277660168379,
#  ('queen', 'chien'): 0.03162277660168379,
#  ('chien', 'area'): 0.03162277660168379,
#  ('area', 'chien'): 0.03162277660168379,
#  ('chien', 'Hall'): 0.03162277660168379,
#  ('Hall', 'chien'): 0.03162277660168379,
#  ('chien', "he'll"): 0.03162277660168379,
#  ("he'll", 'chien'): 0.03162277660168379,
#  ('chien', 'mall'): 0.03162277660168379,
#  ('mall', 'chien'): 0.03162277660168379,
#  ('chien', 'combination'): 0.03162277660168379,
#  ('combination', 'chien'): 0.03162277660168379,
#  ('chien', 'Red'): 0.03162277660168379,
#  ('Red', 'chien'): 0.03162277660168379,
#  ('chien', 'honeymoon'): 0.03162277660168379,
#  ('honeymoon', 'chien'): 0.03162277660168379,
#  ('chien', 'masterful'): 0.03162277660168379,
#  ('masterful', 'chien'): 0.03162277660168379,
#  ('chien', 'feted'): 0.03162277660168379,
#  ('feted', 'chien'): 0.03162277660168379,
#  ('chien', 'Librarians'): 0.03162277660168379,
#  ('Librarians', 'chien'): 0.03162277660168379,
#  ('chien', 'highway'): 0.03162277660168379,
#  ('highway', 'chien'): 0.03162277660168379,
#  ('chien', 'Frick'): 0.03162277660168379,
#  ('Frick', 'chien'): 0.03162277660168379,
#  ('chien', 'clocking'): 0.03162277660168379,
#  ('clocking', 'chien'): 0.03162277660168379,
#  ('chien', 'exploring'): 0.03162277660168379,
#  ('exploring', 'chien'): 0.03162277660168379,
#  ('chien', 'Anaconda'): 0.03162277660168379,
#  ('Anaconda', 'chien'): 0.03162277660168379,
#  ('chien', 'consequences'): 0.03162277660168379,
#  ('consequences', 'chien'): 0.03162277660168379,
#  ('chien', 'hood'): 0.03162277660168379,
#  ('hood', 'chien'): 0.03162277660168379,
#  ('chien', 'valuation'): 0.03162277660168379,
#  ('valuation', 'chien'): 0.03162277660168379,
#  ('chien', '375'): 0.03162277660168379,
#  ('375', 'chien'): 0.03162277660168379,
#  ('chien', 'staggered'): 0.03162277660168379,
#  ('staggered', 'chien'): 0.03162277660168379,
#  ('chien', 'Shelby'): 0.03162277660168379,
#  ('Shelby', 'chien'): 0.03162277660168379,
#  ('chien', 'Shipman'): 0.03162277660168379,
#  ('Shipman', 'chien'): 0.03162277660168379,
#  ('chien', 'Italy'): 0.03162277660168379,
#  ('Italy', 'chien'): 0.03162277660168379,
#  ('chien', 'Vegas'): 0.03162277660168379,
#  ('Vegas', 'chien'): 0.03162277660168379,
#  ('chien', 'undergone'): 0.03162277660168379,
#  ('undergone', 'chien'): 0.03162277660168379,
#  ('chien', 'enterprisingly'): 0.03162277660168379,
#  ('enterprisingly', 'chien'): 0.03162277660168379,
#  ('chien', 'closing'): 0.03162277660168379,
#  ('closing', 'chien'): 0.03162277660168379,
#  ('chien', 'colonies'): 0.03162277660168379,
#  ('colonies', 'chien'): 0.03162277660168379,
#  ('chien', 'best'): 0.03162277660168379,
#  ('best', 'chien'): 0.03162277660168379,
#  ('chien', 'streak'): 0.03162277660168379,
#  ('streak', 'chien'): 0.03162277660168379,
#  ('chien', 'terminated'): 0.03162277660168379,
#  ('terminated', 'chien'): 0.03162277660168379,
#  ('chien', 'machine'): 0.03162277660168379,
#  ('machine', 'chien'): 0.03162277660168379,
#  ('chien', 'Players'): 0.03162277660168379,
#  ('Players', 'chien'): 0.03162277660168379,
#  ('chien', 'presiding'): 0.03162277660168379,
#  ('presiding', 'chien'): 0.03162277660168379,
#  ('chien', 'walloping'): 0.03162277660168379,
#  ('walloping', 'chien'): 0.03162277660168379,
#  ('chien', 'dwindled'): 0.03162277660168379,
#  ('dwindled', 'chien'): 0.03162277660168379,
#  ('chien', 'warless'): 0.03162277660168379,
#  ('warless', 'chien'): 0.03162277660168379,
#  ('chien', 'obtained'): 0.03162277660168379,
#  ('obtained', 'chien'): 0.03162277660168379,
#  ('chien', 'missed'): 0.03162277660168379,
#  ('missed', 'chien'): 0.03162277660168379,
#  ('chien', "Tennessee's"): 0.03162277660168379,
#  ("Tennessee's", 'chien'): 0.03162277660168379,
#  ('chien', 'successes'): 0.03162277660168379,
#  ('successes', 'chien'): 0.03162277660168379,
#  ('chien', 'Annamorena'): 0.03162277660168379,
#  ('Annamorena', 'chien'): 0.03162277660168379,
#  ('chien', 'reforms'): 0.03162277660168379,
#  ('reforms', 'chien'): 0.03162277660168379,
#  ('chien', 'shrink'): 0.03162277660168379,
#  ('shrink', 'chien'): 0.03162277660168379,
#  ('chien', 'junior'): 0.03162277660168379,
#  ('junior', 'chien'): 0.03162277660168379,
#  ('chien', 'breakups'): 0.03162277660168379,
#  ('breakups', 'chien'): 0.03162277660168379,
#  ('chien', 'Beadles'): 0.03162277660168379,
#  ('Beadles', 'chien'): 0.03162277660168379,
#  ('chien', 'secretarial'): 0.03162277660168379,
#  ('secretarial', 'chien'): 0.03162277660168379,
#  ('chien', 'nor'): 0.03162277660168379,
#  ('nor', 'chien'): 0.03162277660168379,
#  ('chien', 'label'): 0.03162277660168379,
#  ('label', 'chien'): 0.03162277660168379,
#  ('chien', 'vouchers'): 0.03162277660168379,
#  ('vouchers', 'chien'): 0.03162277660168379,
#  ('chien', 'Macon'): 0.03162277660168379,
#  ('Macon', 'chien'): 0.03162277660168379,
#  ('chien', '255'): 0.03162277660168379,
#  ('255', 'chien'): 0.03162277660168379,
#  ('chien', 'loaded'): 0.03162277660168379,
#  ('loaded', 'chien'): 0.03162277660168379,
#  ('chien', 'Casey'): 0.03162277660168379,
#  ('Casey', 'chien'): 0.03162277660168379,
#  ('chien', 'Mana'): 0.03162277660168379,
#  ('Mana', 'chien'): 0.03162277660168379,
#  ('chien', 'invoked'): 0.03162277660168379,
#  ('invoked', 'chien'): 0.03162277660168379,
#  ('chien', 'Fonta'): 0.03162277660168379,
#  ('Fonta', 'chien'): 0.03162277660168379,
#  ('chien', 'slums'): 0.03162277660168379,
#  ('slums', 'chien'): 0.03162277660168379,
#  ('chien', 'dynamic'): 0.03162277660168379,
#  ('dynamic', 'chien'): 0.03162277660168379,
#  ('chien', 'teen-age'): 0.03162277660168379,
#  ('teen-age', 'chien'): 0.03162277660168379,
#  ('chien', 'Laotian'): 0.03162277660168379,
#  ('Laotian', 'chien'): 0.03162277660168379,
#  ('chien', 'upturn'): 0.03162277660168379,
#  ('upturn', 'chien'): 0.03162277660168379,
#  ('chien', 'Bundle'): 0.03162277660168379,
#  ('Bundle', 'chien'): 0.03162277660168379,
#  ('chien', 'Bimini'): 0.03162277660168379,
#  ('Bimini', 'chien'): 0.03162277660168379,
#  ('chien', 'scoop'): 0.03162277660168379,
#  ('scoop', 'chien'): 0.03162277660168379,
#  ('chien', 'specialized'): 0.03162277660168379,
#  ('specialized', 'chien'): 0.03162277660168379,
#  ('chien', 'Class'): 0.03162277660168379,
#  ('Class', 'chien'): 0.03162277660168379,
#  ('chien', 'Works'): 0.03162277660168379,
#  ('Works', 'chien'): 0.03162277660168379,
#  ('chien', 'champions'): 0.03162277660168379,
#  ('champions', 'chien'): 0.03162277660168379,
#  ('chien', 'improving'): 0.03162277660168379,
#  ('improving', 'chien'): 0.03162277660168379,
#  ('chien', 'Milties'): 0.03162277660168379,
#  ('Milties', 'chien'): 0.03162277660168379,
#  ('chien', 'line'): 0.03162277660168379,
#  ('line', 'chien'): 0.03162277660168379,
#  ('chien', "we've"): 0.03162277660168379,
#  ("we've", 'chien'): 0.03162277660168379,
#  ('chien', 'budgets'): 0.03162277660168379,
#  ('budgets', 'chien'): 0.03162277660168379,
#  ('chien', 'Auditorium'): 0.03162277660168379,
#  ('Auditorium', 'chien'): 0.03162277660168379,
#  ('chien', 'granted'): 0.03162277660168379,
#  ('granted', 'chien'): 0.03162277660168379,
#  ('chien', 'greeting'): 0.03162277660168379,
#  ('greeting', 'chien'): 0.03162277660168379,
#  ('chien', 'react'): 0.03162277660168379,
#  ('react', 'chien'): 0.03162277660168379,
#  ('chien', 'casuals'): 0.03162277660168379,
#  ('casuals', 'chien'): 0.03162277660168379,
#  ('chien', '4,500'): 0.03162277660168379,
#  ('4,500', 'chien'): 0.03162277660168379,
#  ('chien', 'Water'): 0.03162277660168379,
#  ('Water', 'chien'): 0.03162277660168379,
#  ('chien', 'toy'): 0.03162277660168379,
#  ('toy', 'chien'): 0.03162277660168379,
#  ('chien', 'sirens'): 0.03162277660168379,
#  ('sirens', 'chien'): 0.03162277660168379,
#  ('chien', 'goal'): 0.03162277660168379,
#  ('goal', 'chien'): 0.03162277660168379,
#  ('chien', 'across'): 0.03162277660168379,
#  ('across', 'chien'): 0.03162277660168379,
#  ('chien', "Mays'"): 0.03162277660168379,
#  ("Mays'", 'chien'): 0.03162277660168379,
#  ('chien', 'someone'): 0.03162277660168379,
#  ('someone', 'chien'): 0.03162277660168379,
#  ('chien', 'ballots'): 0.03162277660168379,
#  ('ballots', 'chien'): 0.03162277660168379,
#  ('chien', 'firmer'): 0.03162277660168379,
#  ('firmer', 'chien'): 0.03162277660168379,
#  ('chien', 'approximately'): 0.03162277660168379,
#  ('approximately', 'chien'): 0.03162277660168379,
#  ('chien', 'paid-for'): 0.03162277660168379,
#  ('paid-for', 'chien'): 0.03162277660168379,
#  ('chien', 'strange'): 0.03162277660168379,
#  ('strange', 'chien'): 0.03162277660168379,
#  ('chien', '62-year-old'): 0.03162277660168379,
#  ('62-year-old', 'chien'): 0.03162277660168379,
#  ('chien', 'Pinsk'): 0.03162277660168379,
#  ('Pinsk', 'chien'): 0.03162277660168379,
#  ('chien', 'Darrow'): 0.03162277660168379,
#  ('Darrow', 'chien'): 0.03162277660168379,
#  ('chien', 'mobile'): 0.03162277660168379,
#  ('mobile', 'chien'): 0.03162277660168379,
#  ('chien', 'filing'): 0.03162277660168379,
#  ('filing', 'chien'): 0.03162277660168379,
#  ('chien', 'two-family'): 0.03162277660168379,
#  ('two-family', 'chien'): 0.03162277660168379,
#  ('chien', 'team'): 0.03162277660168379,
#  ('team', 'chien'): 0.03162277660168379,
#  ('chien', 'orientation'): 0.03162277660168379,
#  ('orientation', 'chien'): 0.03162277660168379,
#  ('chien', 'Lavaughn'): 0.03162277660168379,
#  ('Lavaughn', 'chien'): 0.03162277660168379,
#  ('chien', 'radioactive'): 0.03162277660168379,
#  ('radioactive', 'chien'): 0.03162277660168379,
#  ('chien', 'beardown'): 0.03162277660168379,
#  ('beardown', 'chien'): 0.03162277660168379,
#  ('chien', '10-hour'): 0.03162277660168379,
#  ('10-hour', 'chien'): 0.03162277660168379,
#  ('chien', 'stewardesses'): 0.03162277660168379,
#  ('stewardesses', 'chien'): 0.03162277660168379,
#  ('chien', 'learning'): 0.03162277660168379,
#  ('learning', 'chien'): 0.03162277660168379,
#  ('chien', 'book'): 0.03162277660168379,
#  ('book', 'chien'): 0.03162277660168379,
#  ('chien', 'marriages'): 0.03162277660168379,
#  ('marriages', 'chien'): 0.03162277660168379,
#  ('chien', 'discharging'): 0.03162277660168379,
#  ('discharging', 'chien'): 0.03162277660168379,
#  ('chien', 'Iran'): 0.03162277660168379,
#  ('Iran', 'chien'): 0.03162277660168379,
#  ('chien', 'Inaugural'): 0.03162277660168379,
#  ('Inaugural', 'chien'): 0.03162277660168379,
#  ('chien', 'Rte.'): 0.03162277660168379,
#  ('Rte.', 'chien'): 0.03162277660168379,
#  ('chien', 'Smithfield'): 0.03162277660168379,
#  ('Smithfield', 'chien'): 0.03162277660168379,
#  ('chien', 'maintaining'): 0.03162277660168379,
#  ('maintaining', 'chien'): 0.03162277660168379,
#  ('chien', 'of'): 0.03162277660168379,
#  ('of', 'chien'): 0.03162277660168379,
#  ('chien', 'headboard'): 0.03162277660168379,
#  ('headboard', 'chien'): 0.03162277660168379,
#  ('chien', 'contendere'): 0.03162277660168379,
#  ('contendere', 'chien'): 0.03162277660168379,
#  ('chien', 'canvass'): 0.03162277660168379,
#  ('canvass', 'chien'): 0.03162277660168379,
#  ('chien', 'pretenses'): 0.03162277660168379,
#  ('pretenses', 'chien'): 0.03162277660168379,
#  ('chien', 'captain'): 0.03162277660168379,
#  ('captain', 'chien'): 0.03162277660168379,
#  ('chien', 'prevailed'): 0.03162277660168379,
#  ('prevailed', 'chien'): 0.03162277660168379,
#  ('chien', 'potatoes'): 0.03162277660168379,
#  ('potatoes', 'chien'): 0.03162277660168379,
#  ('chien', 'among'): 0.03162277660168379,
#  ('among', 'chien'): 0.03162277660168379,
#  ('chien', "Meyner's"): 0.03162277660168379,
#  ("Meyner's", 'chien'): 0.03162277660168379,
#  ('chien', 'maintain'): 0.03162277660168379,
#  ('maintain', 'chien'): 0.03162277660168379,
#  ('chien', 'seize'): 0.03162277660168379,
#  ('seize', 'chien'): 0.03162277660168379,
#  ('chien', 'Cardinals'): 0.03162277660168379,
#  ('Cardinals', 'chien'): 0.03162277660168379,
#  ('chien', 'productive'): 0.03162277660168379,
#  ('productive', 'chien'): 0.03162277660168379,
#  ('chien', 'secrets'): 0.03162277660168379,
#  ('secrets', 'chien'): 0.03162277660168379,
#  ('chien', 'bolted'): 0.03162277660168379,
#  ('bolted', 'chien'): 0.03162277660168379,
#  ('chien', 'Felske'): 0.03162277660168379,
#  ('Felske', 'chien'): 0.03162277660168379,
#  ('chien', 'cleared'): 0.03162277660168379,
#  ('cleared', 'chien'): 0.03162277660168379,
#  ('chien', 'enthralling'): 0.03162277660168379,
#  ('enthralling', 'chien'): 0.03162277660168379,
#  ('chien', 'son'): 0.03162277660168379,
#  ('son', 'chien'): 0.03162277660168379,
#  ('chien', 'despair'): 0.03162277660168379,
#  ('despair', 'chien'): 0.03162277660168379,
#  ('chien', 'mushrooms'): 0.03162277660168379,
#  ('mushrooms', 'chien'): 0.03162277660168379,
#  ('chien', 'alive'): 0.03162277660168379,
#  ('alive', 'chien'): 0.03162277660168379,
#  ('chien', 'Hit'): 0.03162277660168379,
#  ('Hit', 'chien'): 0.03162277660168379,
#  ('chien', 'exclusively'): 0.03162277660168379,
#  ('exclusively', 'chien'): 0.03162277660168379,
#  ('chien', 'Stickney'): 0.03162277660168379,
#  ('Stickney', 'chien'): 0.03162277660168379,
#  ('chien', 'secessionist'): 0.03162277660168379,
#  ('secessionist', 'chien'): 0.03162277660168379,
#  ('chien', 'Liberals'): 0.03162277660168379,
#  ('Liberals', 'chien'): 0.03162277660168379,
#  ('chien', '22111'): 0.03162277660168379,
#  ('22111', 'chien'): 0.03162277660168379,
#  ('chien', 'unhappy'): 0.03162277660168379,
#  ('unhappy', 'chien'): 0.03162277660168379,
#  ('chien', 'labeled'): 0.03162277660168379,
#  ('labeled', 'chien'): 0.03162277660168379,
#  ('chien', "you're"): 0.03162277660168379,
#  ("you're", 'chien'): 0.03162277660168379,
#  ('chien', 'Windsor'): 0.03162277660168379,
#  ('Windsor', 'chien'): 0.03162277660168379,
#  ('chien', 'tape'): 0.03162277660168379,
#  ('tape', 'chien'): 0.03162277660168379,
#  ('chien', 'citation'): 0.03162277660168379,
#  ('citation', 'chien'): 0.03162277660168379,
#  ('chien', 'rather'): 0.03162277660168379,
#  ('rather', 'chien'): 0.03162277660168379,
#  ('chien', '116'): 0.03162277660168379,
#  ('116', 'chien'): 0.03162277660168379,
#  ('chien', 'compared'): 0.03162277660168379,
#  ('compared', 'chien'): 0.03162277660168379,
#  ('chien', 'Wert'): 0.03162277660168379,
#  ('Wert', 'chien'): 0.03162277660168379,
#  ('chien', 'agricultural'): 0.03162277660168379,
#  ('agricultural', 'chien'): 0.03162277660168379,
#  ('chien', 'fertilizer'): 0.03162277660168379,
#  ('fertilizer', 'chien'): 0.03162277660168379,
#  ('chien', '675'): 0.03162277660168379,
#  ('675', 'chien'): 0.03162277660168379,
#  ('chien', 'lieutenants'): 0.03162277660168379,
#  ('lieutenants', 'chien'): 0.03162277660168379,
#  ('chien', 'enact'): 0.03162277660168379,
#  ('enact', 'chien'): 0.03162277660168379,
#  ('chien', 'Adjusted'): 0.03162277660168379,
#  ('Adjusted', 'chien'): 0.03162277660168379,
#  ('chien', 'Insuring'): 0.03162277660168379,
#  ('Insuring', 'chien'): 0.03162277660168379,
#  ('chien', 'Fortin'): 0.03162277660168379,
#  ('Fortin', 'chien'): 0.03162277660168379,
#  ('chien', 'motion'): 0.03162277660168379,
#  ('motion', 'chien'): 0.03162277660168379,
#  ('chien', 'alike'): 0.03162277660168379,
#  ('alike', 'chien'): 0.03162277660168379,
#  ('chien', 'mine'): 0.03162277660168379,
#  ('mine', 'chien'): 0.03162277660168379,
#  ('chien', 'cloture'): 0.03162277660168379,
#  ('cloture', 'chien'): 0.03162277660168379,
#  ('chien', 'certain'): 0.03162277660168379,
#  ('certain', 'chien'): 0.03162277660168379,
#  ('chien', 'Kader'): 0.03162277660168379,
#  ('Kader', 'chien'): 0.03162277660168379,
#  ('chien', 'care'): 0.03162277660168379,
#  ('care', 'chien'): 0.03162277660168379,
#  ('chien', 'collaborators'): 0.03162277660168379,
#  ('collaborators', 'chien'): 0.03162277660168379,
#  ('chien', 'Composite'): 0.03162277660168379,
#  ('Composite', 'chien'): 0.03162277660168379,
#  ('chien', 'recently'): 0.03162277660168379,
#  ('recently', 'chien'): 0.03162277660168379,
#  ('chien', 'moment'): 0.03162277660168379,
#  ('moment', 'chien'): 0.03162277660168379,
#  ('chien', 'racial'): 0.03162277660168379,
#  ('racial', 'chien'): 0.03162277660168379,
#  ('chien', "farmers'"): 0.03162277660168379,
#  ("farmers'", 'chien'): 0.03162277660168379,
#  ('chien', 'policy'): 0.03162277660168379,
#  ('policy', 'chien'): 0.03162277660168379,
#  ('chien', 'baseballight'): 0.03162277660168379,
#  ('baseballight', 'chien'): 0.03162277660168379,
#  ('chien', 'SEATO'): 0.03162277660168379,
#  ('SEATO', 'chien'): 0.03162277660168379,
#  ('chien', 'great'): 0.03162277660168379,
#  ('great', 'chien'): 0.03162277660168379,
#  ('chien', '300-450'): 0.03162277660168379,
#  ('300-450', 'chien'): 0.03162277660168379,
#  ('chien', '100,000'): 0.03162277660168379,
#  ('100,000', 'chien'): 0.03162277660168379,
#  ('chien', 'survival'): 0.03162277660168379,
#  ('survival', 'chien'): 0.03162277660168379,
#  ('chien', 'fighting'): 0.03162277660168379,
#  ('fighting', 'chien'): 0.03162277660168379,
#  ('chien', 'Toronto'): 0.03162277660168379,
#  ('Toronto', 'chien'): 0.03162277660168379,
#  ('chien', 'blow'): 0.03162277660168379,
#  ('blow', 'chien'): 0.03162277660168379,
#  ('chien', 'called'): 0.03162277660168379,
#  ('called', 'chien'): 0.03162277660168379,
#  ('chien', "Purdue's"): 0.03162277660168379,
#  ("Purdue's", 'chien'): 0.03162277660168379,
#  ('chien', 're-arguing'): 0.03162277660168379,
#  ('re-arguing', 'chien'): 0.03162277660168379,
#  ('chien', 'Publishing'): 0.03162277660168379,
#  ('Publishing', 'chien'): 0.03162277660168379,
#  ('chien', 'annual'): 0.03162277660168379,
#  ('annual', 'chien'): 0.03162277660168379,
#  ('chien', 'sort'): 0.03162277660168379,
#  ('sort', 'chien'): 0.03162277660168379,
#  ('chien', 'various'): 0.03162277660168379,
#  ('various', 'chien'): 0.03162277660168379,
#  ('chien', '64'): 0.03162277660168379,
#  ('64', 'chien'): 0.03162277660168379,
#  ('chien', 'tentative'): 0.03162277660168379,
#  ('tentative', 'chien'): 0.03162277660168379,
#  ('chien', 'contaminating'): 0.03162277660168379,
#  ('contaminating', 'chien'): 0.03162277660168379,
#  ('chien', 'Long'): 0.03162277660168379,
#  ('Long', 'chien'): 0.03162277660168379,
#  ('chien', 'members'): 0.03162277660168379,
#  ('members', 'chien'): 0.03162277660168379,
#  ('chien', 'propaganda'): 0.03162277660168379,
#  ('propaganda', 'chien'): 0.03162277660168379,
#  ('chien', 'Thus'): 0.03162277660168379,
#  ('Thus', 'chien'): 0.03162277660168379,
#  ('chien', 'language'): 0.03162277660168379,
#  ('language', 'chien'): 0.03162277660168379,
#  ('chien', 'split'): 0.03162277660168379,
#  ('split', 'chien'): 0.03162277660168379,
#  ('chien', 'Vietnam'): 0.03162277660168379,
#  ('Vietnam', 'chien'): 0.03162277660168379,
#  ('chien', 'high-ceilinged'): 0.03162277660168379,
#  ('high-ceilinged', 'chien'): 0.03162277660168379,
#  ('chien', 'registration'): 0.03162277660168379,
#  ('registration', 'chien'): 0.03162277660168379,
#  ('chien', 'front'): 0.03162277660168379,
#  ('front', 'chien'): 0.03162277660168379,
#  ('chien', 'Eastern'): 0.03162277660168379,
#  ('Eastern', 'chien'): 0.03162277660168379,
#  ('chien', 'emphasis'): 0.03162277660168379,
#  ('emphasis', 'chien'): 0.03162277660168379,
#  ('chien', 'varied'): 0.03162277660168379,
#  ('varied', 'chien'): 0.03162277660168379,
#  ('chien', 'segregationist'): 0.03162277660168379,
#  ('segregationist', 'chien'): 0.03162277660168379,
#  ('chien', 'model'): 0.03162277660168379,
#  ('model', 'chien'): 0.03162277660168379,
#  ('chien', 'Winston'): 0.03162277660168379,
#  ('Winston', 'chien'): 0.03162277660168379,
#  ('chien', 'Volume'): 0.03162277660168379,
#  ('Volume', 'chien'): 0.03162277660168379,
#  ('chien', 'Curry'): 0.03162277660168379,
#  ('Curry', 'chien'): 0.03162277660168379,
#  ('chien', "Denver's"): 0.03162277660168379,
#  ("Denver's", 'chien'): 0.03162277660168379,
#  ('chien', "fall's"): 0.03162277660168379,
#  ("fall's", 'chien'): 0.03162277660168379,
#  ('chien', 'fell'): 0.03162277660168379,
#  ('fell', 'chien'): 0.03162277660168379,
#  ('chien', '$77,389,000'): 0.03162277660168379,
#  ('$77,389,000', 'chien'): 0.03162277660168379,
#  ('chien', 'so-called'): 0.03162277660168379,
#  ('so-called', 'chien'): 0.03162277660168379,
#  ('chien', 'See-through'): 0.03162277660168379,
#  ('See-through', 'chien'): 0.03162277660168379,
#  ('chien', 'Joey'): 0.03162277660168379,
#  ('Joey', 'chien'): 0.03162277660168379,
#  ('chien', 'King'): 0.03162277660168379,
#  ('King', 'chien'): 0.03162277660168379,
#  ('chien', 'a'): 0.03162277660168379,
#  ('a', 'chien'): 0.03162277660168379,
#  ('chien', 'cool'): 0.03162277660168379,
#  ('cool', 'chien'): 0.03162277660168379,
#  ('chien', 'eight-year'): 0.03162277660168379,
#  ('eight-year', 'chien'): 0.03162277660168379,
#  ('chien', '354'): 0.03162277660168379,
#  ('354', 'chien'): 0.03162277660168379,
#  ('chien', 'cellist'): 0.03162277660168379,
#  ('cellist', 'chien'): 0.03162277660168379,
#  ('chien', 'Spangled'): 0.03162277660168379,
#  ('Spangled', 'chien'): 0.03162277660168379,
#  ('chien', 'singers'): 0.03162277660168379,
#  ('singers', 'chien'): 0.03162277660168379,
#  ('chien', 'precisely'): 0.03162277660168379,
#  ('precisely', 'chien'): 0.03162277660168379,
#  ('chien', 'clears'): 0.03162277660168379,
#  ('clears', 'chien'): 0.03162277660168379,
#  ('chien', 'Master'): 0.03162277660168379,
#  ('Master', 'chien'): 0.03162277660168379,
#  ('chien', 'spun'): 0.03162277660168379,
#  ('spun', 'chien'): 0.03162277660168379,
#  ('chien', 'Bake'): 0.03162277660168379,
#  ('Bake', 'chien'): 0.03162277660168379,
#  ('chien', '1948'): 0.03162277660168379,
#  ('1948', 'chien'): 0.03162277660168379,
#  ('chien', 'knees'): 0.03162277660168379,
#  ('knees', 'chien'): 0.03162277660168379,
#  ('chien', 'wheat'): 0.03162277660168379,
#  ('wheat', 'chien'): 0.03162277660168379,
#  ('chien', 'Mayor'): 0.03162277660168379,
#  ('Mayor', 'chien'): 0.03162277660168379,
#  ('chien', 'banked'): 0.03162277660168379,
#  ('banked', 'chien'): 0.03162277660168379,
#  ('chien', 'The'): 0.03162277660168379,
#  ('The', 'chien'): 0.03162277660168379,
#  ('chien', 'Governor'): 0.03162277660168379,
#  ('Governor', 'chien'): 0.03162277660168379,
#  ('chien', 'hijackers'): 0.03162277660168379,
#  ('hijackers', 'chien'): 0.03162277660168379,
#  ('chien', 'frock'): 0.03162277660168379,
#  ('frock', 'chien'): 0.03162277660168379,
#  ('chien', "tonight's"): 0.03162277660168379,
#  ("tonight's", 'chien'): 0.03162277660168379,
#  ('chien', 'high-density'): 0.03162277660168379,
#  ('high-density', 'chien'): 0.03162277660168379,
#  ('chien', 'guiding'): 0.03162277660168379,
#  ('guiding', 'chien'): 0.03162277660168379,
#  ('chien', 'hour'): 0.03162277660168379,
#  ('hour', 'chien'): 0.03162277660168379,
#  ('chien', 'pleaded'): 0.03162277660168379,
#  ('pleaded', 'chien'): 0.03162277660168379,
#  ('chien', 'glanced'): 0.03162277660168379,
#  ('glanced', 'chien'): 0.03162277660168379,
#  ('chien', 'beat'): 0.03162277660168379,
#  ('beat', 'chien'): 0.03162277660168379,
#  ('chien', 'volume'): 0.03162277660168379,
#  ('volume', 'chien'): 0.03162277660168379,
#  ('chien', 'Revolutionary'): 0.03162277660168379,
#  ('Revolutionary', 'chien'): 0.03162277660168379,
#  ('chien', 'extent'): 0.03162277660168379,
#  ('extent', 'chien'): 0.03162277660168379,
#  ('chien', 'clinic'): 0.03162277660168379,
#  ('clinic', 'chien'): 0.03162277660168379,
#  ('chien', 'imports'): 0.03162277660168379,
#  ('imports', 'chien'): 0.03162277660168379,
#  ('chien', '186'): 0.03162277660168379,
#  ('186', 'chien'): 0.03162277660168379,
#  ('chien', 'Calvary'): 0.03162277660168379,
#  ('Calvary', 'chien'): 0.03162277660168379,
#  ('chien', 'idealism'): 0.03162277660168379,
#  ('idealism', 'chien'): 0.03162277660168379,
#  ('chien', 'population'): 0.03162277660168379,
#  ('population', 'chien'): 0.03162277660168379,
#  ('chien', 'Baird'): 0.03162277660168379,
#  ('Baird', 'chien'): 0.03162277660168379,
#  ('chien', 'default'): 0.03162277660168379,
#  ('default', 'chien'): 0.03162277660168379,
#  ('chien', 'bombing'): 0.03162277660168379,
#  ('bombing', 'chien'): 0.03162277660168379,
#  ('chien', 'Felix'): 0.03162277660168379,
#  ('Felix', 'chien'): 0.03162277660168379,
#  ('chien', 'Av.'): 0.03162277660168379,
#  ('Av.', 'chien'): 0.03162277660168379,
#  ('chien', 'diversified'): 0.03162277660168379,
#  ('diversified', 'chien'): 0.03162277660168379,
#  ('chien', '68'): 0.03162277660168379,
#  ('68', 'chien'): 0.03162277660168379,
#  ('chien', 'Another'): 0.03162277660168379,
#  ('Another', 'chien'): 0.03162277660168379,
#  ('chien', 'strength'): 0.03162277660168379,
#  ('strength', 'chien'): 0.03162277660168379,
#  ('chien', 'Dublin'): 0.03162277660168379,
#  ('Dublin', 'chien'): 0.03162277660168379,
#  ('chien', 'Trouble-free'): 0.03162277660168379,
#  ('Trouble-free', 'chien'): 0.03162277660168379,
#  ('chien', '10%'): 0.03162277660168379,
#  ('10%', 'chien'): 0.03162277660168379,
#  ('chien', 'controllers'): 0.03162277660168379,
#  ('controllers', 'chien'): 0.03162277660168379,
#  ('chien', 'aids'): 0.03162277660168379,
#  ('aids', 'chien'): 0.03162277660168379,
#  ('chien', 'Salary'): 0.03162277660168379,
#  ('Salary', 'chien'): 0.03162277660168379,
#  ('chien', 'Gin'): 0.03162277660168379,
#  ('Gin', 'chien'): 0.03162277660168379,
#  ('chien', 'expire'): 0.03162277660168379,
#  ('expire', 'chien'): 0.03162277660168379,
#  ('chien', ','): 0.03162277660168379,
#  (',', 'chien'): 0.03162277660168379,
#  ('chien', 'Warren'): 0.03162277660168379,
#  ('Warren', 'chien'): 0.03162277660168379,
#  ('chien', 'studies'): 0.03162277660168379,
#  ('studies', 'chien'): 0.03162277660168379,
#  ('chien', 'drifting'): 0.03162277660168379,
#  ('drifting', 'chien'): 0.03162277660168379,
#  ('chien', 'procedures'): 0.03162277660168379,
#  ('procedures', 'chien'): 0.03162277660168379,
#  ('chien', 'gambling'): 0.03162277660168379,
#  ('gambling', 'chien'): 0.03162277660168379,
#  ('chien', 'outlawed'): 0.03162277660168379,
#  ('outlawed', 'chien'): 0.03162277660168379,
#  ('chien', 'Taking'): 0.03162277660168379,
#  ('Taking', 'chien'): 0.03162277660168379,
#  ('chien', 'house'): 0.03162277660168379,
#  ('house', 'chien'): 0.03162277660168379,
#  ('chien', 'Baldrige'): 0.03162277660168379,
#  ('Baldrige', 'chien'): 0.03162277660168379,
#  ('chien', 'twelfth'): 0.03162277660168379,
#  ('twelfth', 'chien'): 0.03162277660168379,
#  ('chien', 'minorities'): 0.03162277660168379,
#  ('minorities', 'chien'): 0.03162277660168379,
#  ('chien', '1914'): 0.03162277660168379,
#  ('1914', 'chien'): 0.03162277660168379,
#  ('chien', 'grounds'): 0.03162277660168379,
#  ('grounds', 'chien'): 0.03162277660168379,
#  ('chien', 'Forest'): 0.03162277660168379,
#  ('Forest', 'chien'): 0.03162277660168379,
#  ('chien', 'subbing'): 0.03162277660168379,
#  ('subbing', 'chien'): 0.03162277660168379,
#  ('chien', 'analysis'): 0.03162277660168379,
#  ('analysis', 'chien'): 0.03162277660168379,
#  ('chien', 'such'): 0.03162277660168379,
#  ('such', 'chien'): 0.03162277660168379,
#  ('chien', 'movie'): 0.03162277660168379,
#  ('movie', 'chien'): 0.03162277660168379,
#  ('chien', 'Naturally'): 0.03162277660168379,
#  ('Naturally', 'chien'): 0.03162277660168379,
#  ('chien', 'window'): 0.03162277660168379,
#  ('window', 'chien'): 0.03162277660168379,
#  ('chien', 'two-season'): 0.03162277660168379,
#  ('two-season', 'chien'): 0.03162277660168379,
#  ('chien', '3505o'): 0.03162277660168379,
#  ('3505o', 'chien'): 0.03162277660168379,
#  ('chien', 'charging'): 0.03162277660168379,
#  ('charging', 'chien'): 0.03162277660168379,
#  ('chien', 'design-conscious'): 0.03162277660168379,
#  ('design-conscious', 'chien'): 0.03162277660168379,
#  ('chien', 'Aug.'): 0.03162277660168379,
#  ('Aug.', 'chien'): 0.03162277660168379,
#  ('chien', 'spends'): 0.03162277660168379,
#  ('spends', 'chien'): 0.03162277660168379,
#  ('chien', 'collecting'): 0.03162277660168379,
#  ('collecting', 'chien'): 0.03162277660168379,
#  ('chien', 'add'): 0.03162277660168379,
#  ('add', 'chien'): 0.03162277660168379,
#  ('chien', 'authorities'): 0.03162277660168379,
#  ('authorities', 'chien'): 0.03162277660168379,
#  ('chien', 'La.'): 0.03162277660168379,
#  ('La.', 'chien'): 0.03162277660168379,
#  ('chien', 'Hood'): 0.03162277660168379,
#  ('Hood', 'chien'): 0.03162277660168379,
#  ('chien', 'measure'): 0.03162277660168379,
#  ('measure', 'chien'): 0.03162277660168379,
#  ('chien', 'economist'): 0.03162277660168379,
#  ('economist', 'chien'): 0.03162277660168379,
#  ('chien', 'Frederick'): 0.03162277660168379,
#  ('Frederick', 'chien'): 0.03162277660168379,
#  ('chien', 'thwarted'): 0.03162277660168379,
#  ('thwarted', 'chien'): 0.03162277660168379,
#  ('chien', 'prizes'): 0.03162277660168379,
#  ('prizes', 'chien'): 0.03162277660168379,
#  ('chien', 'Valedictorian'): 0.03162277660168379,
#  ('Valedictorian', 'chien'): 0.03162277660168379,
#  ('chien', 'biz'): 0.03162277660168379,
#  ('biz', 'chien'): 0.03162277660168379,
#  ('chien', 'ruled'): 0.03162277660168379,
#  ('ruled', 'chien'): 0.03162277660168379,
#  ('chien', 'loyalty'): 0.03162277660168379,
#  ('loyalty', 'chien'): 0.03162277660168379,
#  ('chien', 'communism'): 0.03162277660168379,
#  ('communism', 'chien'): 0.03162277660168379,
#  ('chien', 'Jay'): 0.03162277660168379,
#  ('Jay', 'chien'): 0.03162277660168379,
#  ('chien', 'Baringer'): 0.03162277660168379,
#  ('Baringer', 'chien'): 0.03162277660168379,
#  ('chien', 'Beesemyers'): 0.03162277660168379,
#  ('Beesemyers', 'chien'): 0.03162277660168379,
#  ('chien', 'customs'): 0.03162277660168379,
#  ('customs', 'chien'): 0.03162277660168379,
#  ('chien', 'Ramsey'): 0.03162277660168379,
#  ('Ramsey', 'chien'): 0.03162277660168379,
#  ('chien', 'flowers'): 0.03162277660168379,
#  ('flowers', 'chien'): 0.03162277660168379,
#  ('chien', 'storm'): 0.03162277660168379,
#  ('storm', 'chien'): 0.03162277660168379,
#  ('chien', 'Mays'): 0.03162277660168379,
#  ('Mays', 'chien'): 0.03162277660168379,
#  ('chien', 'Aiken'): 0.03162277660168379,
#  ('Aiken', 'chien'): 0.03162277660168379,
#  ('chien', 'briskly'): 0.03162277660168379,
#  ('briskly', 'chien'): 0.03162277660168379,
#  ('chien', 'paces'): 0.03162277660168379,
#  ('paces', 'chien'): 0.03162277660168379,
#  ('chien', 'Trail'): 0.03162277660168379,
#  ('Trail', 'chien'): 0.03162277660168379,
#  ('chien', 'corn'): 0.03162277660168379,
#  ('corn', 'chien'): 0.03162277660168379,
#  ('chien', 'Guests'): 0.03162277660168379,
#  ('Guests', 'chien'): 0.03162277660168379,
#  ('chien', 'Sharon'): 0.03162277660168379,
#  ('Sharon', 'chien'): 0.03162277660168379,
#  ('chien', 'apartments'): 0.03162277660168379,
#  ('apartments', 'chien'): 0.03162277660168379,
#  ('chien', 'wants'): 0.03162277660168379,
#  ('wants', 'chien'): 0.03162277660168379,
#  ('chien', 'Guinea'): 0.03162277660168379,
#  ('Guinea', 'chien'): 0.03162277660168379,
#  ('chien', 'Beneficiary'): 0.03162277660168379,
#  ('Beneficiary', 'chien'): 0.03162277660168379,
#  ('chien', 'Sydney'): 0.03162277660168379,
#  ('Sydney', 'chien'): 0.03162277660168379,
#  ('chien', 'gather'): 0.03162277660168379,
#  ('gather', 'chien'): 0.03162277660168379,
#  ('chien', 'downstairs'): 0.03162277660168379,
#  ('downstairs', 'chien'): 0.03162277660168379,
#  ('chien', 'named'): 0.03162277660168379,
#  ('named', 'chien'): 0.03162277660168379,
#  ('chien', 'bet'): 0.03162277660168379,
#  ('bet', 'chien'): 0.03162277660168379,
#  ('chien', 'Charge'): 0.03162277660168379,
#  ('Charge', 'chien'): 0.03162277660168379,
#  ('chien', 'Sarmi'): 0.03162277660168379,
#  ('Sarmi', 'chien'): 0.03162277660168379,
#  ('chien', 'one-fourth'): 0.03162277660168379,
#  ('one-fourth', 'chien'): 0.03162277660168379,
#  ('chien', 'filly'): 0.03162277660168379,
#  ('filly', 'chien'): 0.03162277660168379,
#  ('chien', 'overtake'): 0.03162277660168379,
#  ('overtake', 'chien'): 0.03162277660168379,
#  ('chien', "nation's"): 0.03162277660168379,
#  ("nation's", 'chien'): 0.03162277660168379,
#  ('chien', 'achieved'): 0.03162277660168379,
#  ('achieved', 'chien'): 0.03162277660168379,
#  ('chien', 'theaters'): 0.03162277660168379,
#  ('theaters', 'chien'): 0.03162277660168379,
#  ('chien', 'shares'): 0.03162277660168379,
#  ('shares', 'chien'): 0.03162277660168379,
#  ('chien', 'teach'): 0.03162277660168379,
#  ('teach', 'chien'): 0.03162277660168379,
#  ('chien', 'Cotton'): 0.03162277660168379,
#  ('Cotton', 'chien'): 0.03162277660168379,
#  ('chien', 'doubles'): 0.03162277660168379,
#  ('doubles', 'chien'): 0.03162277660168379,
#  ('chien', 'Hartselle'): 0.03162277660168379,
#  ('Hartselle', 'chien'): 0.03162277660168379,
#  ('chien', 'Generally'): 0.03162277660168379,
#  ('Generally', 'chien'): 0.03162277660168379,
#  ('chien', 'thriving'): 0.03162277660168379,
#  ('thriving', 'chien'): 0.03162277660168379,
#  ('chien', 'Dillon'): 0.03162277660168379,
#  ('Dillon', 'chien'): 0.03162277660168379,
#  ('chien', 'wear'): 0.03162277660168379,
#  ('wear', 'chien'): 0.03162277660168379,
#  ('chien', '$278,877,000'): 0.03162277660168379,
#  ('$278,877,000', 'chien'): 0.03162277660168379,
#  ('chien', 'Monroe'): 0.03162277660168379,
#  ('Monroe', 'chien'): 0.03162277660168379,
#  ('chien', 'deeply'): 0.03162277660168379,
#  ('deeply', 'chien'): 0.03162277660168379,
#  ('chien', 'inhabitants'): 0.03162277660168379,
#  ('inhabitants', 'chien'): 0.03162277660168379,
#  ('chien', 'plenary'): 0.03162277660168379,
#  ('plenary', 'chien'): 0.03162277660168379,
#  ('chien', 'misses'): 0.03162277660168379,
#  ('misses', 'chien'): 0.03162277660168379,
#  ('chien', 'three-way'): 0.03162277660168379,
#  ('three-way', 'chien'): 0.03162277660168379,
#  ('chien', 'Lowe'): 0.03162277660168379,
#  ('Lowe', 'chien'): 0.03162277660168379,
#  ('chien', 'engines'): 0.03162277660168379,
#  ('engines', 'chien'): 0.03162277660168379,
#  ('chien', 'breaching'): 0.03162277660168379,
#  ('breaching', 'chien'): 0.03162277660168379,
#  ('chien', 'conducts'): 0.03162277660168379,
#  ('conducts', 'chien'): 0.03162277660168379,
#  ('chien', 'turned'): 0.03162277660168379,
#  ('turned', 'chien'): 0.03162277660168379,
#  ('chien', 'ambled'): 0.03162277660168379,
#  ('ambled', 'chien'): 0.03162277660168379,
#  ('chien', 'belongs'): 0.03162277660168379,
#  ('belongs', 'chien'): 0.03162277660168379,
#  ('chien', 'shoulder'): 0.03162277660168379,
#  ('shoulder', 'chien'): 0.03162277660168379,
#  ('chien', 'caskets'): 0.03162277660168379,
#  ('caskets', 'chien'): 0.03162277660168379,
#  ('chien', 'roaring'): 0.03162277660168379,
#  ('roaring', 'chien'): 0.03162277660168379,
#  ('chien', 'Nieman'): 0.03162277660168379,
#  ('Nieman', 'chien'): 0.03162277660168379,
#  ('chien', 'argued'): 0.03162277660168379,
#  ('argued', 'chien'): 0.03162277660168379,
#  ('chien', 'Hengesbach'): 0.03162277660168379,
#  ('Hengesbach', 'chien'): 0.03162277660168379,
#  ('chien', 'dichotomy'): 0.03162277660168379,
#  ('dichotomy', 'chien'): 0.03162277660168379,
#  ('chien', 'judging'): 0.03162277660168379,
#  ('judging', 'chien'): 0.03162277660168379,
#  ('chien', '25-footer'): 0.03162277660168379,
#  ('25-footer', 'chien'): 0.03162277660168379,
#  ('chien', 'bum'): 0.03162277660168379,
#  ('bum', 'chien'): 0.03162277660168379,
#  ('chien', '361'): 0.03162277660168379,
#  ('361', 'chien'): 0.03162277660168379,
#  ('chien', 'walloped'): 0.03162277660168379,
#  ('walloped', 'chien'): 0.03162277660168379,
#  ('chien', 'Hack'): 0.03162277660168379,
#  ('Hack', 'chien'): 0.03162277660168379,
#  ('chien', 'Trooper'): 0.03162277660168379,
#  ('Trooper', 'chien'): 0.03162277660168379,
#  ('chien', 'Dukes'): 0.03162277660168379,
#  ('Dukes', 'chien'): 0.03162277660168379,
#  ('chien', 'bill'): 0.03162277660168379,
#  ('bill', 'chien'): 0.03162277660168379,
#  ('chien', 'Lamar'): 0.03162277660168379,
#  ('Lamar', 'chien'): 0.03162277660168379,
#  ('chien', 'chafing'): 0.03162277660168379,
#  ('chafing', 'chien'): 0.03162277660168379,
#  ('chien', 'Stepson'): 0.03162277660168379,
#  ('Stepson', 'chien'): 0.03162277660168379,
#  ('chien', 'keyboarding'): 0.03162277660168379,
#  ('keyboarding', 'chien'): 0.03162277660168379,
#  ('chien', 'effected'): 0.03162277660168379,
#  ('effected', 'chien'): 0.03162277660168379,
#  ('chien', 'enunciate'): 0.03162277660168379,
#  ('enunciate', 'chien'): 0.03162277660168379,
#  ('chien', 'puts'): 0.03162277660168379,
#  ('puts', 'chien'): 0.03162277660168379,
#  ('chien', 'Farrell'): 0.03162277660168379,
#  ('Farrell', 'chien'): 0.03162277660168379,
#  ('chien', '704'): 0.03162277660168379,
#  ('704', 'chien'): 0.03162277660168379,
#  ('chien', 'stomachs'): 0.03162277660168379,
#  ('stomachs', 'chien'): 0.03162277660168379,
#  ('chien', "Owl's"): 0.03162277660168379,
#  ("Owl's", 'chien'): 0.03162277660168379,
#  ('chien', 'specializing'): 0.03162277660168379,
#  ('specializing', 'chien'): 0.03162277660168379,
#  ('chien', 'lay'): 0.03162277660168379,
#  ('lay', 'chien'): 0.03162277660168379,
#  ('chien', 'Bears'): 0.03162277660168379,
#  ('Bears', 'chien'): 0.03162277660168379,
#  ('chien', 'rulers'): 0.03162277660168379,
#  ('rulers', 'chien'): 0.03162277660168379,
#  ('chien', 'honored'): 0.03162277660168379,
#  ('honored', 'chien'): 0.03162277660168379,
#  ('chien', 'believing'): 0.03162277660168379,
#  ('believing', 'chien'): 0.03162277660168379,
#  ('chien', 'documents'): 0.03162277660168379,
#  ('documents', 'chien'): 0.03162277660168379,
#  ('chien', '40%'): 0.03162277660168379,
#  ('40%', 'chien'): 0.03162277660168379,
#  ('chien', 'also'): 0.03162277660168379,
#  ('also', 'chien'): 0.03162277660168379,
#  ('chien', 'dimension'): 0.03162277660168379,
#  ('dimension', 'chien'): 0.03162277660168379,
#  ('chien', 'Company'): 0.03162277660168379,
#  ('Company', 'chien'): 0.03162277660168379,
#  ('chien', 'hours'): 0.03162277660168379,
#  ('hours', 'chien'): 0.03162277660168379,
#  ('chien', 'become'): 0.03162277660168379,
#  ('become', 'chien'): 0.03162277660168379,
#  ('chien', 'continuous'): 0.03162277660168379,
#  ('continuous', 'chien'): 0.03162277660168379,
#  ('chien', 'player'): 0.03162277660168379,
#  ('player', 'chien'): 0.03162277660168379,
#  ('chien', '$17'): 0.03162277660168379,
#  ('$17', 'chien'): 0.03162277660168379,
#  ('chien', 'Frank'): 0.03162277660168379,
#  ('Frank', 'chien'): 0.03162277660168379,
#  ('chien', 'orders'): 0.03162277660168379,
#  ('orders', 'chien'): 0.03162277660168379,
#  ('chien', 'chocolate'): 0.03162277660168379,
#  ('chocolate', 'chien'): 0.03162277660168379,
#  ('chien', 'reprimanded'): 0.03162277660168379,
#  ('reprimanded', 'chien'): 0.03162277660168379,
#  ('chien', '44-year-old'): 0.03162277660168379,
#  ('44-year-old', 'chien'): 0.03162277660168379,
#  ('chien', 'Caucusing'): 0.03162277660168379,
#  ('Caucusing', 'chien'): 0.03162277660168379,
#  ('chien', 'inviolate'): 0.03162277660168379,
#  ('inviolate', 'chien'): 0.03162277660168379,
#  ('chien', 'Idea'): 0.03162277660168379,
#  ('Idea', 'chien'): 0.03162277660168379,
#  ('chien', 'Actor-Crooner'): 0.03162277660168379,
#  ('Actor-Crooner', 'chien'): 0.03162277660168379,
#  ('chien', 'October'): 0.03162277660168379,
#  ('October', 'chien'): 0.03162277660168379,
#  ('chien', 'Romans'): 0.03162277660168379,
#  ('Romans', 'chien'): 0.03162277660168379,
#  ('chien', 'Lounge'): 0.03162277660168379,
#  ('Lounge', 'chien'): 0.03162277660168379,
#  ('chien', 'motivated'): 0.03162277660168379,
#  ('motivated', 'chien'): 0.03162277660168379,
#  ('chien', 'administered'): 0.03162277660168379,
#  ('administered', 'chien'): 0.03162277660168379,
#  ('chien', '1913'): 0.03162277660168379,
#  ('1913', 'chien'): 0.03162277660168379,
#  ('chien', 'toward'): 0.03162277660168379,
#  ('toward', 'chien'): 0.03162277660168379,
#  ('chien', "people's"): 0.03162277660168379,
#  ("people's", 'chien'): 0.03162277660168379,
#  ('chien', 'entered'): 0.03162277660168379,
#  ('entered', 'chien'): 0.03162277660168379,
#  ('chien', 'Quell'): 0.03162277660168379,
#  ('Quell', 'chien'): 0.03162277660168379,
#  ('chien', '52-year'): 0.03162277660168379,
#  ('52-year', 'chien'): 0.03162277660168379,
#  ('chien', 'Caroline'): 0.03162277660168379,
#  ('Caroline', 'chien'): 0.03162277660168379,
#  ('chien', 'Skylark'): 0.03162277660168379,
#  ('Skylark', 'chien'): 0.03162277660168379,
#  ('chien', 'surrender'): 0.03162277660168379,
#  ('surrender', 'chien'): 0.03162277660168379,
#  ('chien', 'simultaneous'): 0.03162277660168379,
#  ('simultaneous', 'chien'): 0.03162277660168379,
#  ('chien', 'diminutive'): 0.03162277660168379,
#  ('diminutive', 'chien'): 0.03162277660168379,
#  ('chien', 'alleged'): 0.03162277660168379,
#  ('alleged', 'chien'): 0.03162277660168379,
#  ('chien', 'dissent'): 0.03162277660168379,
#  ('dissent', 'chien'): 0.03162277660168379,
#  ('chien', 'airlines'): 0.03162277660168379,
#  ('airlines', 'chien'): 0.03162277660168379,
#  ('chien', 'June'): 0.03162277660168379,
#  ('June', 'chien'): 0.03162277660168379,
#  ('chien', 'Times-Picayune'): 0.03162277660168379,
#  ('Times-Picayune', 'chien'): 0.03162277660168379,
#  ('chien', 'laying'): 0.03162277660168379,
#  ('laying', 'chien'): 0.03162277660168379,
#  ('chien', 'stew'): 0.03162277660168379,
#  ('stew', 'chien'): 0.03162277660168379,
#  ('chien', 'Woodyard'): 0.03162277660168379,
#  ('Woodyard', 'chien'): 0.03162277660168379,
#  ('chien', 'Voters'): 0.03162277660168379,
#  ('Voters', 'chien'): 0.03162277660168379,
#  ('chien', 'Eugene'): 0.03162277660168379,
#  ('Eugene', 'chien'): 0.03162277660168379,
#  ('chien', 'Dunbar'): 0.03162277660168379,
#  ('Dunbar', 'chien'): 0.03162277660168379,
#  ('chien', 'distance'): 0.03162277660168379,
#  ('distance', 'chien'): 0.03162277660168379,
#  ('chien', 'tests'): 0.03162277660168379,
#  ('tests', 'chien'): 0.03162277660168379,
#  ('chien', 'laborers'): 0.03162277660168379,
#  ('laborers', 'chien'): 0.03162277660168379,
#  ('chien', '7034'): 0.03162277660168379,
#  ('7034', 'chien'): 0.03162277660168379,
#  ('chien', 'foot'): 0.03162277660168379,
#  ('foot', 'chien'): 0.03162277660168379,
#  ('chien', 'wonderful'): 0.03162277660168379,
#  ('wonderful', 'chien'): 0.03162277660168379,
#  ('chien', 'go'): 0.03162277660168379,
#  ('go', 'chien'): 0.03162277660168379,
#  ('chien', 'carcass'): 0.03162277660168379,
#  ('carcass', 'chien'): 0.03162277660168379,
#  ('chien', '3.98'): 0.03162277660168379,
#  ...}

# %%
batch_size = 2
#convert our skipgrams to id
skip_grams_id = [(word2index[skip_gram[0]], word2index[skip_gram[1]]) for skip_gram in skip_grams]
x, y, cooc, weighting = random_batch(batch_size, corpus, skip_grams_id, X_ik, weighting_dic)

# %%
type(x[0][0])
# Out:
# numpy.int64

# %%
y
# Out:
# array([[11106],
#        [  156]])

# %%
cooc
# Out:
# array([[1.60943791],
#        [7.27517232]])

# %%
weighting
# Out:
# array([[0.10573713],
#        [1.        ]])

# %% [markdown]
# ## 4. Model
#
# <img src ="../figures/glove.png" width=400>

# %%
class Glove(nn.Module):
    
    def __init__(self, voc_size, emb_size, word2index):
        super(Glove, self).__init__()
        self.center_embedding  = nn.Embedding(voc_size, emb_size)
        self.outside_embedding = nn.Embedding(voc_size, emb_size)
        
        self.center_bias       = nn.Embedding(voc_size, 1) 
        self.outside_bias      = nn.Embedding(voc_size, 1)

        self.word2index = word2index


    def forward(self, center, outside, coocs, weighting):
        center_embeds  = self.center_embedding(center) #(batch_size, 1, emb_size)
        outside_embeds = self.outside_embedding(outside) #(batch_size, 1, emb_size)
        
        center_bias    = self.center_bias(center).squeeze(1)
        target_bias    = self.outside_bias(outside).squeeze(1)
        
        inner_product  = outside_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        #(batch_size, 1, emb_size) @ (batch_size, emb_size, 1) = (batch_size, 1, 1) = (batch_size, 1)
        
        loss = weighting * torch.pow(inner_product + center_bias + target_bias - coocs, 2)
        
        return torch.sum(loss)
    
    #let's write a function to get embedding given a word
    def get_embed(self, word):
        word2index = self.word2index
        
        try:
            index = word2index[word]
        except:
            index = word2index['<UNK>']
            
        word = torch.LongTensor([index])
        
        embed_c = self.center_embedding(word)
        embed_o = self.outside_embedding(word)
        embed   = (embed_c + embed_o) / 2
        
        return embed[0][0].item(), embed[0][1].item()

# %%
#test our system
voc_size = len(vocab)
emb_size = 2
model = Glove(voc_size, emb_size, word2index)

# %%
x_tensor = torch.LongTensor(x)
y_tensor = torch.LongTensor(y)
cooc_tensor = torch.FloatTensor(cooc)
weighting_tensor = torch.FloatTensor(weighting)

# %%
loss = model(x_tensor, y_tensor, cooc_tensor, weighting_tensor)

# %%
loss
# Out:
# tensor(45.4687, grad_fn=<SumBackward0>)

# %% [markdown]
# ## 5. Training

# %%
batch_size     = 10 # mini-batch size
embedding_size = 2 #so we can later plot
model          = Glove(voc_size, embedding_size, word2index)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
import time

# Training
num_epochs = 1000

total_start = time.time()
start = time.time()
for epoch in range(num_epochs):
    
    input_batch, target_batch, cooc_batch, weighting_batch = random_batch(batch_size, corpus, skip_grams_id, X_ik, weighting_dic)
    input_batch  = torch.LongTensor(input_batch)         #[batch_size, 1]
    target_batch = torch.LongTensor(target_batch)        #[batch_size, 1]
    cooc_batch   = torch.FloatTensor(cooc_batch)         #[batch_size, 1]
    weighting_batch = torch.FloatTensor(weighting_batch) #[batch_size, 1]
    
    optimizer.zero_grad()
    loss = model(input_batch, target_batch, cooc_batch, weighting_batch)
    
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 100 == 0:
        
        end = time.time()
        epoch_mins, epoch_secs = epoch_time(start, end)
        
        print(f"Epoch: {epoch + 1} | cost: {loss:.6f} | time: {epoch_mins}m {epoch_secs}s")
        start = end

total_end = time.time()
training_time_total = total_end - total_start
min, sec = epoch_time(total_start, total_end)

print(f"\nComplete: \nTotal Loss: {loss:2.2f} | Time Taken: {min} minutes and {sec} seconds")
# Out:
# Epoch: 100 | cost: 8.663046 | time: 0m 4s
# Epoch: 200 | cost: 3.549200 | time: 0m 4s
# Epoch: 300 | cost: 69.170227 | time: 0m 4s
# Epoch: 400 | cost: 7.458392 | time: 0m 4s
# Epoch: 500 | cost: 18.753832 | time: 0m 4s
# Epoch: 600 | cost: 8.309074 | time: 0m 4s
# Epoch: 700 | cost: 4.043787 | time: 0m 4s
# Epoch: 800 | cost: 135.150360 | time: 0m 4s
# Epoch: 900 | cost: 5.158092 | time: 0m 4s
# Epoch: 1000 | cost: 44.368946 | time: 0m 4s
#
# Complete:
# Total Loss: 44.37 | Time Taken: 0 minutes and 42 seconds

# %% [markdown]
# # 6. Testing

# %%
def open_file(path_to_file):
    # Open the file in read mode
    try:
        with open(path_to_file, 'r') as file:
            content = file.readlines()
    except FileNotFoundError:
        print(f"The file {path_to_file} does not exist.")
    except Exception as e:
        print(f"An error occurred: {e}")

    return content

# %%
file_path = "test/word-test.v1.min.txt"

content = open_file(file_path)

semantic = []
syntatic = []

current_test = semantic
for sent in content:
    if sent[0] == ':':
        current_test = syntatic
        continue
    
    current_test.append(sent.strip())

# %%
vector_space = []

for word in vocab:
    vector_space.append(model.get_embed(word))

vector_space = np.array(vector_space)

# %%
#scipy version
from scipy import spatial

def cos_sim(a, b):
    cos_sim = 1 - spatial.distance.cosine(a, b)  #distance = 1 - similarlity, because scipy only gives distance
    return cos_sim

def cos_sim_scores(vector_space, target_vector):
    scores = []
    for each_vect in vector_space:
        each_vect = tuple(each_vect)
        target_vector=tuple(target_vector)
        scores.append(cos_sim(target_vector, each_vect))

    return np.array(scores)

# %%
def similarity(model, test_data):
    words = test_data.split(" ")

    embed0 = np.array(model.get_embed(words[0]))
    embed1 = np.array(model.get_embed(words[1]))
    embed2 = np.array(model.get_embed(words[2]))

    similar_vector = embed1 - embed0 + embed2

    similarity_scores = cos_sim_scores(vector_space, similar_vector)
    max_score_idx = np.argmax(similarity_scores)
    similar_word = index2word[max_score_idx]

    result = False
    if similar_word == words[3]:
        result = True

    return result

# %% [markdown]
# ## Semantic Accuracy

# %%
sem_total = len(semantic)
sem_correct = 0
for sent in semantic:
    if similarity(model, sent):
        sem_correct += 1

# %%
sem_accuracy = sem_correct / sem_total
print(f"Semantic accuracy: {sem_accuracy:2.2f}")
# Out:
# Semantic accuracy: 0.00

# %% [markdown]
# ## Syntactic Accuracy

# %%
syn_total = len(syntatic)
syn_correct = 0
for sent in syntatic:
    if similarity(model, sent):
        syn_correct += 1

# %%
syn_accuracy = syn_correct / syn_total
print(f"Syntatic accuracy: {syn_accuracy:2.2f}")
# Out:
# Syntatic accuracy: 0.00

# %% [markdown]
# ## Similarity Accuracy

# %%
file_path = "test/wordsim_similarity_goldstandard.txt"

content = open_file(file_path)

sim_data = []

for sent in content:
    sim_data.append(sent.strip())

# %%
def compute_similarity(model, test_data):
    words = test_data.split("\t")

    embed0 = np.array(model.get_embed(words[0].strip()))
    embed1 = np.array(model.get_embed(words[1].strip()))

    similarity_model = embed1 @ embed0.T
    similarity_provided = float(words[2].strip())

    return similarity_provided, similarity_model

# %%
ds_scores = []
model_scores = []
for sent in sim_data:
    ds_score, model_score = compute_similarity(model, sent)

    ds_scores.append(ds_score)
    model_scores.append(model_score)

# %%
from scipy.stats import spearmanr

corr = spearmanr(ds_scores, model_scores)[0]

print(f"Correlation between the dataset metrics and model scores is {corr:2.2f}.")
# Out:
# Correlation between the dataset metrics and model scores is -0.02.

# %% [markdown]
# # 7. Save the model and meta data

# %%
import pickle

torch.save(model.state_dict(), '../app/models/glove.model')

glove_args = {
    'voc_size': voc_size,
    'emb_size': emb_size,
    'word2index': word2index,
}

pickle.dump(glove_args, open('../app/models/glove.args', 'wb'))

# %%
glove_args = pickle.load(open('../app/models/glove.args', 'rb'))
model_glove = Glove(**glove_args)
model_glove.load_state_dict(torch.load('../app/models/glove.model'))

# Test the model
model_glove.get_embed('sad')
# Out:
# (0.2447531521320343, -0.15323737263679504)
